# %%
import pandas as pd
import numpy as np
# No warnings about setting value on copy of slice
pd.options.mode.chained_assignment = None

# Display up to 60 columns of a dataframe
pd.set_option('display.max_columns', 60)

# Matplotlib visualization
import matplotlib.pyplot as plt
from matplotlib import rcParams
# %matplotlib inline

# Internal ipython tool for setting figure size
from IPython.core.pylabtools import figsize

# Seaborn for visualization
import seaborn as sns

import warnings

warnings.filterwarnings('ignore')

config = {
    "mathtext.fontset": 'stix',
    "font.family":'DejaVu Sans',
    "font.family": 'serif',
    "font.serif": ['Arial'],
    "font.size": 24,
    'axes.unicode_minus': False
}
rcParams.update(config)
plt.rcParams['axes.unicode_minus'] = False
large = 22
med = 16
small = 12
params = {
    'axes.titlesize': large,
    'legend.fontsize': med,
    'figure.figsize': (8, 6),
    'axes.labelsize': med,
    'axes.titlesize': med,
    'xtick.labelsize': med,
    'ytick.labelsize': med,
    'figure.titlesize': large
}
plt.rcParams.update(params)
plt.rcParams['figure.dpi'] = 300
seed = 42

# %%
dp = pd.read_csv('./data/db_cn.csv')

# %%
count_lt_0025 = (dp['energy_above_hull'] <= 0.02).sum()
count_gte_0025 = (dp['energy_above_hull'] > 0.02).sum()

print(f"Number equal to 0.02: {count_lt_0025}")
print(f"Number greater than 0.02: {count_gte_0025}")
# Out:
# Number equal to 0.02: 427
# Number greater than 0.02: 864

# %%
dp['marker'] = dp['energy_above_hull'].apply(lambda x: 1 if x <= 0.02 else 0)
dp
# Out:
#      material_id formula_pretty  formation_energy_per_atom  energy_above_hull  \
# 0     mp-1113578     Cs2AgAsBr6                  -1.374468           0.000000
# 1     mp-1113543     Cs2AgAsCl6                  -1.562978           0.008312
# 2     mp-1114305      Cs2AgAsF6                  -2.436756           0.055656
# 3     mp-1113575     Cs2AgAuBr6                  -1.255402           0.024743
# 4      mp-568448     Cs2AgAuCl6                  -1.395263           0.054055
# ...          ...            ...                        ...                ...
# 1286  mp-1114193       Rb2YHgI6                  -1.377484           0.104343
# 1287  mp-1114129      Rb2YInBr6                  -1.954103           0.016794
# 1288  mp-1114045      Rb2YInCl6                  -2.216514           0.041253
# 1289  mp-1113931       Rb2YInF6                  -3.290900           0.045683
# 1290  mp-1114186       Rb2YInI6                  -1.480278           0.043320
#
#       is_gap_direct  band_gap  spacegroup_number  \
# 0             False    1.1161                225
# 1             False    1.5886                225
# 2             False    2.4428                225
# 3             False    0.0000                225
# 4             False    0.0000                225
# ...             ...       ...                ...
# 1286          False    0.0000                225
# 1287           True    2.8332                225
# 1288          False    3.3242                225
# 1289          False    3.6730                225
# 1290           True    2.6542                225
#
#                                               structure     formula  \
# 0     Full Formula (Cs2 Ag1 As1 Br6)\nReduced Formul...  Cs2AgAsBr6
# 1     Full Formula (Cs2 Ag1 As1 Cl6)\nReduced Formul...  Cs2AgAsCl6
# 2     Full Formula (Cs2 Ag1 As1 F6)\nReduced Formula...   Cs2AgAsF6
# 3     Full Formula (Cs2 Ag1 Au1 Br6)\nReduced Formul...  Cs2AgAuBr6
# 4     Full Formula (Cs2 Ag1 Au1 Cl6)\nReduced Formul...  Cs2AgAuCl6
# ...                                                 ...         ...
# 1286  Full Formula (Rb2 Y1 Hg1 I6)\nReduced Formula:...    Rb2YHgI6
# 1287  Full Formula (Rb2 Y1 In1 Br6)\nReduced Formula...   Rb2YInBr6
# 1288  Full Formula (Rb2 Y1 In1 Cl6)\nReduced Formula...   Rb2YInCl6
# 1289  Full Formula (Rb2 Y1 In1 F6)\nReduced Formula:...    Rb2YInF6
# 1290  Full Formula (Rb2 Y1 In1 I6)\nReduced Formula:...    Rb2YInI6
#
#           composition  is_GGA_U  marker
# 0     Cs2 Ag1 As1 Br6         0       1
# 1     Cs2 Ag1 As1 Cl6         0       1
# 2      Cs2 Ag1 As1 F6         0       0
# 3     Cs2 Ag1 Au1 Br6         0       0
# 4     Cs2 Ag1 Au1 Cl6         0       0
# ...               ...       ...     ...
# 1286    Rb2 Y1 Hg1 I6         0       0
# 1287   Rb2 Y1 In1 Br6         0       1
# 1288   Rb2 Y1 In1 Cl6         0       0
# 1289    Rb2 Y1 In1 F6         0       0
# 1290    Rb2 Y1 In1 I6         0       0
#
# [1291 rows x 12 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

y_counts = dp['marker'].value_counts()
y_counts.plot(kind='bar', color=['#31A09A', '#D58686'],edgecolor='black')
plt.ylabel('Number', fontsize='22')
#plt.xticks(ticks=[0, 1], labels=['eh > 0.02', 'eh <= 0.02'], rotation=0, fontsize='22')
plt.xticks(ticks=[0, 1], 
           labels=[r'$E_{\mathrm{h}} > 0.02$', r'$E_{\mathrm{h}} \leq 0.02$'], 
           rotation=0, 
           fontsize=22)

ax = plt.gca()  
ax.spines['top'].set_linewidth(1.5)
ax.spines['bottom'].set_linewidth(1.5)
ax.spines['left'].set_linewidth(1.5)
ax.spines['right'].set_linewidth(1.5)
ax.tick_params(axis='both', which='major', labelsize=20) 
ax.set_xlabel('') 
plt.savefig('./picture/eh_distribution.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Feature Engineering

# %%
X = pd.read_csv('./data/features_cn.csv')

# %%
y = dp['marker']

# %%
from scipy.stats import spearmanr
def remove_collinear_features(x, y,threshold):
    '''
    Objective:
        Remove collinear features in a dataframe with a correlation coefficient
        greater than the threshold. Removing collinear features can help a model
        to generalize and improves the interpretability of the model.
        
    Inputs: 
        threshold: any features with correlations greater than this value are removed
    
    Output: 
        dataframe that contains only the non-highly-collinear features
    '''  
    # Calculate the correlation matrix
    corr_matrix = x.corr()
    iters = range(len(corr_matrix.columns) - 1)
    drop_cols = []

    # Iterate through the correlation matrix and compare correlations
    for i in iters:
        for j in range(i):
            item = corr_matrix.iloc[j:(j+1), (i+1):(i+2)]
            col = item.columns
            row = item.index
            val = abs(item.values)
            
            # If correlation exceeds the threshold
            if val >= threshold:
                # Print the correlated features and the correlation value
#                 print(col.values[0], "|", row.values[0], "|", round(val[0][0], 2))
                x1 = x[col.values[0]]
                x2 = x[row.values[0]]
                corr1,p1 = spearmanr(x1, y)
                corr2,p2 = spearmanr(x2, y)
                if np.abs(corr1) < np.abs(corr2):
                    drop_cols.append(col.values[0])
                else:
                    drop_cols.append(row.values[0])
    # Drop one of each pair of correlated columns
    drops = set(drop_cols)
    x = x.drop(columns = drops)
    return x

# %%
from sklearn.model_selection import train_test_split
X = remove_collinear_features(X, y, 0.8)
#X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,shuffle=True,random_state=0)
print(X.shape)
# Out:
# (1291, 29)

# %% [markdown]
# ## Model Construction

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from lightgbm import LGBMClassifier 
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.naive_bayes import GaussianNB

seed =42
kn = KNeighborsClassifier()
dt = DecisionTreeClassifier(random_state=seed)
rf = RandomForestClassifier(n_jobs=-1,random_state=seed)
mlp = MLPClassifier(alpha=1, max_iter=1000,random_state=seed)
lgbm = LGBMClassifier(random_state=seed,verbose=0)
xb = XGBClassifier(random_state=seed,n_jobs=-1)
ext = ExtraTreesClassifier(n_jobs=-1,random_state=seed) 
gbc = GradientBoostingClassifier(random_state=seed)
gnb = GaussianNB()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.model_selection import StratifiedKFold
from imblearn.over_sampling import SMOTE
from collections import Counter
def fold5_ensemble(model, X, y, name='', is_plot=True):
    kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    models = []  
    accuracies = []
    f1s = []
    mccs = []
    roc_aucs = []
    recalls = []
    fig, ax = plt.subplots()
    for i, (train_index, test_index) in enumerate(kf.split(X, y)):
        try:
            X = X.values
            y = y.values
        except:
            pass
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]

        model.fit(X_train, y_train)
        models.append(model)
        y_pred = model.predict(X_test)
        y_prob = model.predict_proba(X_test)[:, 1]
        
        accuracy = metrics.accuracy_score(y_test, y_pred)
        f1 = metrics.f1_score(y_test, y_pred)
        mcc = metrics.matthews_corrcoef(y_test, y_pred)
        fpr, tpr, _ = metrics.roc_curve(y_test, y_prob)
        roc_auc = metrics.auc(fpr, tpr)
        recall = metrics.recall_score(y_test, y_pred)
        print(f"Fold {i+ 1} Accuracy: {accuracy} F1_Score: {f1}  ROC_AUC: {roc_auc}")
        accuracies.append(accuracy)
        f1s.append(f1)
        mccs.append(mcc)
        roc_aucs.append(roc_auc)
        recalls.append(recall)

        if is_plot:
            ax.plot(fpr, tpr, label=f"Fold {i+1} (AUC = {roc_auc:.3f})", lw=1.7, linestyle="-.", alpha=0.75)
            ax.plot([0, 1], [0, 1], "r--", lw=1, alpha=0.8)
            ax.set_xlim([-0.02, 1.0])
            ax.set_ylim([0.0, 1.05])
            ax.set_xlabel("False Positive Rate", fontsize=22)
            ax.set_ylabel("True Positive Rate", fontsize=22)
            ax.legend(loc="lower right" ,fontsize=17)
            ax.grid(True, linestyle="--", linewidth=1, alpha=0.5)
            ax.spines["top"].set_linewidth(1.5)
            ax.spines["bottom"].set_linewidth(1.5)
            ax.spines["left"].set_linewidth(1.5)
            ax.spines["right"].set_linewidth(1.5)
            ax.tick_params(axis='both', which='major', labelsize=20)
            ax.grid(False)  

    result = {
        'accuracy': np.mean(accuracies),
        'f1-score': np.mean(f1s),
        'mcc': np.mean(mccs),
        'roc_auc': np.mean(roc_aucs),
        'recall': np.mean(recalls)        }
    if is_plot:
        #plt.savefig('./picture/eh_class.png', dpi=300, bbox_inches='tight')
        plt.show()
    return result, models

# %%
fold5_ensemble(dt, X, y)
# Out:
# Fold 1 Accuracy: 0.8494208494208494 F1_Score: 0.7796610169491525  ROC_AUC: 0.8375789756687726
# Fold 2 Accuracy: 0.7790697674418605 F1_Score: 0.6545454545454547  ROC_AUC: 0.7412790697674418
# Fold 3 Accuracy: 0.7906976744186046 F1_Score: 0.6666666666666666  ROC_AUC: 0.751173070384223
# Fold 4 Accuracy: 0.8333333333333334 F1_Score: 0.7393939393939394  ROC_AUC: 0.803910234614077
# Fold 5 Accuracy: 0.7248062015503876 F1_Score: 0.6033519553072626  ROC_AUC: 0.7020401224073445
# ({'accuracy': 0.7954655652330072,
#   'f1-score': 0.6887238065724951,
#   'mcc': 0.5375804169620656,
#   'roc_auc': 0.7671962945683718,
#   'recall': 0.6836935704514364},
#  [DecisionTreeClassifier(random_state=42),
#   DecisionTreeClassifier(random_state=42),
#   DecisionTreeClassifier(random_state=42),
#   DecisionTreeClassifier(random_state=42),
#   DecisionTreeClassifier(random_state=42)])

# %%
fold5_ensemble(rf, X, y)
# Out:
# Fold 1 Accuracy: 0.8803088803088803 F1_Score: 0.8098159509202453  ROC_AUC: 0.9405498050813281
# Fold 2 Accuracy: 0.8372093023255814 F1_Score: 0.7439024390243903  ROC_AUC: 0.9223904813412654
# Fold 3 Accuracy: 0.8565891472868217 F1_Score: 0.7672955974842768  ROC_AUC: 0.9307718463107785
# Fold 4 Accuracy: 0.8643410852713178 F1_Score: 0.7770700636942675  ROC_AUC: 0.9139748384903092
# Fold 5 Accuracy: 0.8294573643410853 F1_Score: 0.7317073170731707  ROC_AUC: 0.9127507650459028
# ({'accuracy': 0.8535811559067372,
#   'f1-score': 0.7659582736392702,
#   'mcc': 0.6625472826235816,
#   'roc_auc': 0.9240875472539167,
#   'recall': 0.7235841313269494},
#  [RandomForestClassifier(n_jobs=-1, random_state=42),
#   RandomForestClassifier(n_jobs=-1, random_state=42),
#   RandomForestClassifier(n_jobs=-1, random_state=42),
#   RandomForestClassifier(n_jobs=-1, random_state=42),
#   RandomForestClassifier(n_jobs=-1, random_state=42)])

# %%
fold5_ensemble(lgbm, X, y)
# Out:
# Fold 1 Accuracy: 0.8687258687258688 F1_Score: 0.7976190476190477  ROC_AUC: 0.94293587847829
# Fold 2 Accuracy: 0.8565891472868217 F1_Score: 0.7757575757575758  ROC_AUC: 0.9278664142779881
# Fold 3 Accuracy: 0.8643410852713178 F1_Score: 0.7928994082840236  ROC_AUC: 0.9390683441006461
# Fold 4 Accuracy: 0.875968992248062 F1_Score: 0.8048780487804879  ROC_AUC: 0.9381842910574635
# Fold 5 Accuracy: 0.8488372093023255 F1_Score: 0.7664670658682634  ROC_AUC: 0.917783066984019
# ({'accuracy': 0.8628924605668791,
#   'f1-score': 0.7875242292618797,
#   'mcc': 0.6870334808019539,
#   'roc_auc': 0.9331675989796814,
#   'recall': 0.7681805745554036},
#  [LGBMClassifier(random_state=42, verbose=0),
#   LGBMClassifier(random_state=42, verbose=0),
#   LGBMClassifier(random_state=42, verbose=0),
#   LGBMClassifier(random_state=42, verbose=0),
#   LGBMClassifier(random_state=42, verbose=0)])

# %%
fold5_ensemble(xb, X, y)
# Out:
# Fold 1 Accuracy: 0.8918918918918919 F1_Score: 0.8352941176470589  ROC_AUC: 0.9451539185374378
# Fold 2 Accuracy: 0.8682170542635659 F1_Score: 0.7951807228915662  ROC_AUC: 0.9362493239588967
# Fold 3 Accuracy: 0.8488372093023255 F1_Score: 0.7745664739884393  ROC_AUC: 0.9334240054403263
# Fold 4 Accuracy: 0.875968992248062 F1_Score: 0.8072289156626505  ROC_AUC: 0.9336960217613057
# Fold 5 Accuracy: 0.8372093023255814 F1_Score: 0.7529411764705881  ROC_AUC: 0.907514450867052
# ({'accuracy': 0.8644248900062852,
#   'f1-score': 0.7930422813320606,
#   'mcc': 0.692641668340341,
#   'roc_auc': 0.9312075441130038,
#   'recall': 0.7844870041039671},
#  [XGBClassifier(base_score=None, booster=None, callbacks=None,
#                 colsample_bylevel=None, colsample_bynode=None,
#                 colsample_bytree=None, device=None, early_stopping_rounds=None,
#                 enable_categorical=False, eval_metric=None, feature_types=None,
#                 gamma=None, grow_policy=None, importance_type=None,
#                 interaction_constraints=None, learning_rate=None, max_bin=None,
#                 max_cat_threshold=None, max_cat_to_onehot=None,
#                 max_delta_step=None, max_depth=None, max_leaves=None,
#                 min_child_weight=None, missing=nan, monotone_constraints=None,
#                 multi_strategy=None, n_estimators=None, n_jobs=-1,
#                 num_parallel_tree=None, random_state=42, ...),
#   XGBClassifier(base_score=None, booster=None, callbacks=None,
#                 colsample_bylevel=None, colsample_bynode=None,
#                 colsample_bytree=None, device=None, early_stopping_rounds=None,
#                 enable_categorical=False, eval_metric=None, feature_types=None,
#                 gamma=None, grow_policy=None, importance_type=None,
#                 interaction_constraints=None, learning_rate=None, max_bin=None,
#                 max_cat_threshold=None, max_cat_to_onehot=None,
#                 max_delta_step=None, max_depth=None, max_leaves=None,
#                 min_child_weight=None, missing=nan, monotone_constraints=None,
#                 multi_strategy=None, n_estimators=None, n_jobs=-1,
#                 num_parallel_tree=None, random_state=42, ...),
#   XGBClassifier(base_score=None, booster=None, callbacks=None,
#                 colsample_bylevel=None, colsample_bynode=None,
#                 colsample_bytree=None, device=None, early_stopping_rounds=None,
#                 enable_categorical=False, eval_metric=None, feature_types=None,
#                 gamma=None, grow_policy=None, importance_type=None,
#                 interaction_constraints=None, learning_rate=None, max_bin=None,
#                 max_cat_threshold=None, max_cat_to_onehot=None,
#                 max_delta_step=None, max_depth=None, max_leaves=None,
#                 min_child_weight=None, missing=nan, monotone_constraints=None,
#                 multi_strategy=None, n_estimators=None, n_jobs=-1,
#                 num_parallel_tree=None, random_state=42, ...),
#   XGBClassifier(base_score=None, booster=None, callbacks=None,
#                 colsample_bylevel=None, colsample_bynode=None,
#                 colsample_bytree=None, device=None, early_stopping_rounds=None,
#                 enable_categorical=False, eval_metric=None, feature_types=None,
#                 gamma=None, grow_policy=None, importance_type=None,
#                 interaction_constraints=None, learning_rate=None, max_bin=None,
#                 max_cat_threshold=None, max_cat_to_onehot=None,
#                 max_delta_step=None, max_depth=None, max_leaves=None,
#                 min_child_weight=None, missing=nan, monotone_constraints=None,
#                 multi_strategy=None, n_estimators=None, n_jobs=-1,
#                 num_parallel_tree=None, random_state=42, ...),
#   XGBClassifier(base_score=None, booster=None, callbacks=None,
#                 colsample_bylevel=None, colsample_bynode=None,
#                 colsample_bytree=None, device=None, early_stopping_rounds=None,
#                 enable_categorical=False, eval_metric=None, feature_types=None,
#                 gamma=None, grow_policy=None, importance_type=None,
#                 interaction_constraints=None, learning_rate=None, max_bin=None,
#                 max_cat_threshold=None, max_cat_to_onehot=None,
#                 max_delta_step=None, max_depth=None, max_leaves=None,
#                 min_child_weight=None, missing=nan, monotone_constraints=None,
#                 multi_strategy=None, n_estimators=None, n_jobs=-1,
#                 num_parallel_tree=None, random_state=42, ...)])

# %%
fold5_ensemble(ext, X, y)
# Out:
# Fold 1 Accuracy: 0.8957528957528957 F1_Score: 0.8363636363636363  ROC_AUC: 0.9412219384325851
# Fold 2 Accuracy: 0.8488372093023255 F1_Score: 0.7664670658682634  ROC_AUC: 0.9168807463493781
# Fold 3 Accuracy: 0.8255813953488372 F1_Score: 0.7169811320754716  ROC_AUC: 0.9162189731383883
# Fold 4 Accuracy: 0.8604651162790697 F1_Score: 0.7777777777777777  ROC_AUC: 0.9080584835090105
# Fold 5 Accuracy: 0.8410852713178295 F1_Score: 0.7657142857142857  ROC_AUC: 0.9086025161509691
# ({'accuracy': 0.8543443776001916,
#   'f1-score': 0.7726607795598869,
#   'mcc': 0.667252504069903,
#   'roc_auc': 0.9181965315160662,
#   'recall': 0.7493023255813953},
#  [ExtraTreesClassifier(n_jobs=-1, random_state=42),
#   ExtraTreesClassifier(n_jobs=-1, random_state=42),
#   ExtraTreesClassifier(n_jobs=-1, random_state=42),
#   ExtraTreesClassifier(n_jobs=-1, random_state=42),
#   ExtraTreesClassifier(n_jobs=-1, random_state=42)])

# %%
fold5_ensemble(gbc, X, y)
# Out:
# Fold 1 Accuracy: 0.861003861003861 F1_Score: 0.783132530120482  ROC_AUC: 0.9354751982793387
# Fold 2 Accuracy: 0.8217054263565892 F1_Score: 0.7124999999999999  ROC_AUC: 0.9115738236884803
# Fold 3 Accuracy: 0.8837209302325582 F1_Score: 0.8148148148148148  ROC_AUC: 0.9414484869092147
# Fold 4 Accuracy: 0.8682170542635659 F1_Score: 0.7976190476190476  ROC_AUC: 0.9180550833049982
# Fold 5 Accuracy: 0.8410852713178295 F1_Score: 0.7544910179640718  ROC_AUC: 0.9065283917035022
# ({'accuracy': 0.8551465086348806,
#   'f1-score': 0.7725114821036831,
#   'mcc': 0.6678859678066247,
#   'roc_auc': 0.9226161967771068,
#   'recall': 0.7448974008207934},
#  [GradientBoostingClassifier(random_state=42),
#   GradientBoostingClassifier(random_state=42),
#   GradientBoostingClassifier(random_state=42),
#   GradientBoostingClassifier(random_state=42),
#   GradientBoostingClassifier(random_state=42)])

# %%
xbmodels = fold5_ensemble(xb, X, y)
# Out:
# Fold 1 Accuracy: 0.8918918918918919 F1_Score: 0.8352941176470589  ROC_AUC: 0.9451539185374378
# Fold 2 Accuracy: 0.8682170542635659 F1_Score: 0.7951807228915662  ROC_AUC: 0.9362493239588967
# Fold 3 Accuracy: 0.8488372093023255 F1_Score: 0.7745664739884393  ROC_AUC: 0.9334240054403263
# Fold 4 Accuracy: 0.875968992248062 F1_Score: 0.8072289156626505  ROC_AUC: 0.9336960217613057
# Fold 5 Accuracy: 0.8372093023255814 F1_Score: 0.7529411764705881  ROC_AUC: 0.907514450867052

# %%
df1 = pd.concat([X, y],axis=1)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.model_selection import StratifiedKFold
from imblearn.over_sampling import SMOTE
from collections import Counter
def fold5_ensemble_smote(model, X, y, name='', is_plot=True):
    if hasattr(X, "columns"):
        feature_columns = X.columns.tolist()
    else:
        feature_columns = [f"feature_{i}" for i in range(X.shape[1])]
    label_column = "target"  
    kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    models = []  
    accuracies = []
    f1s = []
    mccs = []
    roc_aucs = []
    recalls = []
    fig, ax = plt.subplots()
    for i, (train_index, test_index) in enumerate(kf.split(X, y)):
        try:
            X = X.values
            y = y.values
        except:
            pass
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]
        # SMOTE
        smote = SMOTE(random_state=42)
        X_train_balanced, y_train_balanced = smote.fit_resample(X_train, y_train)

        test_df = pd.DataFrame(X_test, columns=feature_columns)
        test_df[label_column] = y_test
        test_df.to_csv(f"./data/ml_eh_data/slme_eh_eh_test[{i}].csv", index=False)

        model.fit(X_train_balanced, y_train_balanced)
        models.append(model)

        y_pred = model.predict(X_test)
        y_prob = model.predict_proba(X_test)[:, 1]
  
        df_prob = pd.DataFrame({
            'true_label': y_test,
            'pred_label': y_pred,
            'predict_proba': [f"{p:.2f}" for p in y_prob]  
        })

        df_prob.to_csv(f'./data/ml_eh_data/fold{i}_predict_prob.csv', index=False)

        accuracy = metrics.accuracy_score(y_test, y_pred)
        f1 = metrics.f1_score(y_test, y_pred)
        mcc = metrics.matthews_corrcoef(y_test, y_pred)
        fpr, tpr, _ = metrics.roc_curve(y_test, y_prob)
        roc_auc = metrics.auc(fpr, tpr)
        recall = metrics.recall_score(y_test, y_pred)
  
        print(f"Fold {i+ 1} Accuracy: {accuracy} F1_Score: {f1}  ROC_AUC: {roc_auc}")
     
        accuracies.append(accuracy)
        f1s.append(f1)
        mccs.append(mcc)
        roc_aucs.append(roc_auc)
        recalls.append(recall)
   
        if is_plot:
            ax.plot(fpr, tpr, label=f"Fold {i+1} (AUC = {roc_auc:.3f})", lw=1.7, linestyle="-.", alpha=0.75)
            ax.plot([0, 1], [0, 1], "r--", lw=1, alpha=0.8)
            ax.set_xlim([-0.02, 1.0])
            ax.set_ylim([0.0, 1.05])
            ax.set_xlabel("False Positive Rate", fontsize=22)
            ax.set_ylabel("True Positive Rate", fontsize=22)
            ax.legend(loc="lower right" ,fontsize=17)
            ax.grid(True, linestyle="--", linewidth=1, alpha=0.5)
            ax.spines["top"].set_linewidth(1.5)
            ax.spines["bottom"].set_linewidth(1.5)
            ax.spines["left"].set_linewidth(1.5)
            ax.spines["right"].set_linewidth(1.5)
            ax.tick_params(axis='both', which='major', labelsize=20)
            ax.grid(False)  
    result = {
        'accuracy': np.mean(accuracies),
        'f1-score': np.mean(f1s),
        'mcc': np.mean(mccs),
        'roc_auc': np.mean(roc_aucs),
        'recall': np.mean(recalls)        }
    if is_plot:
        #plt.savefig('./picture/eh_class_smote.png', dpi=300, bbox_inches='tight')
        plt.show()
    return result, models

# %%
dt_result, dt_models = fold5_ensemble_smote(dt, X, y)
dt_result
# Out:
# Fold 1 Accuracy: 0.8494208494208494 F1_Score: 0.7796610169491525  ROC_AUC: 0.8375789756687726
# Fold 2 Accuracy: 0.7790697674418605 F1_Score: 0.6545454545454547  ROC_AUC: 0.7412790697674418
# Fold 3 Accuracy: 0.7906976744186046 F1_Score: 0.6666666666666666  ROC_AUC: 0.751173070384223
# Fold 4 Accuracy: 0.8333333333333334 F1_Score: 0.7393939393939394  ROC_AUC: 0.803910234614077
# Fold 5 Accuracy: 0.7248062015503876 F1_Score: 0.6033519553072626  ROC_AUC: 0.7020401224073445
# {'accuracy': 0.7954655652330072,
#  'f1-score': 0.6887238065724951,
#  'mcc': 0.5375804169620656,
#  'roc_auc': 0.7671962945683718,
#  'recall': 0.6836935704514364}

# %%
rf_result, rf_models = fold5_ensemble_smote(rf, X, y)
rf_result
# Out:
# Fold 1 Accuracy: 0.8803088803088803 F1_Score: 0.8187134502923977  ROC_AUC: 0.9432719451539185
# Fold 2 Accuracy: 0.8527131782945736 F1_Score: 0.7738095238095238  ROC_AUC: 0.9375
# Fold 3 Accuracy: 0.8488372093023255 F1_Score: 0.7636363636363637  ROC_AUC: 0.9245494729683781
# Fold 4 Accuracy: 0.872093023255814 F1_Score: 0.8  ROC_AUC: 0.911764705882353
# Fold 5 Accuracy: 0.8565891472868217 F1_Score: 0.7861271676300577  ROC_AUC: 0.916763005780347
# {'accuracy': 0.8621082876896831,
#  'f1-score': 0.7884573010736686,
#  'mcc': 0.6866396133447379,
#  'roc_auc': 0.9267698259569993,
#  'recall': 0.7774829001367989}

# %%
kn_result, kn_models = fold5_ensemble_smote(kn, X, y)
kn_result
# Out:
# Fold 1 Accuracy: 0.7992277992277992 F1_Score: 0.7450980392156863  ROC_AUC: 0.8680602231482726
# Fold 2 Accuracy: 0.7674418604651163 F1_Score: 0.7  ROC_AUC: 0.8603975121687399
# Fold 3 Accuracy: 0.7868217054263565 F1_Score: 0.717948717948718  ROC_AUC: 0.8571574294457668
# Fold 4 Accuracy: 0.7790697674418605 F1_Score: 0.7076923076923078  ROC_AUC: 0.8405644338660319
# Fold 5 Accuracy: 0.7325581395348837 F1_Score: 0.6532663316582914  ROC_AUC: 0.8017001020061203
# {'accuracy': 0.7730238544192033,
#  'f1-score': 0.7048010793030006,
#  'mcc': 0.5401589769278304,
#  'roc_auc': 0.8455759401269862,
#  'recall': 0.8195348837209302}

# %%
mlp_result, mlp_models = fold5_ensemble_smote(mlp, X, y)
mlp_result
# Out:
# Fold 1 Accuracy: 0.7258687258687259 F1_Score: 0.6952789699570815  ROC_AUC: 0.8826455168705472
# Fold 2 Accuracy: 0.7596899224806202 F1_Score: 0.6836734693877551  ROC_AUC: 0.8701325040562466
# Fold 3 Accuracy: 0.8023255813953488 F1_Score: 0.7182320441988951  ROC_AUC: 0.8757565453927236
# Fold 4 Accuracy: 0.7015503875968992 F1_Score: 0.6637554585152838  ROC_AUC: 0.848826929615777
# Fold 5 Accuracy: 0.7635658914728682 F1_Score: 0.6163522012578617  ROC_AUC: 0.8041482488949337
# {'accuracy': 0.7506001017628925,
#  'f1-score': 0.6754584286633755,
#  'mcc': 0.505894269681898,
#  'roc_auc': 0.8563019489660457,
#  'recall': 0.7912448700410396}

# %%
ext_result, ext_models = fold5_ensemble_smote(ext, X, y)
ext_result
# Out:
# Fold 1 Accuracy: 0.8841698841698842 F1_Score: 0.8214285714285714  ROC_AUC: 0.940785051754268
# Fold 2 Accuracy: 0.8604651162790697 F1_Score: 0.783132530120482  ROC_AUC: 0.9211060032449974
# Fold 3 Accuracy: 0.8333333333333334 F1_Score: 0.7425149700598803  ROC_AUC: 0.9104046242774567
# Fold 4 Accuracy: 0.8682170542635659 F1_Score: 0.7926829268292683  ROC_AUC: 0.9098945936756204
# Fold 5 Accuracy: 0.8333333333333334 F1_Score: 0.7542857142857142  ROC_AUC: 0.9168650119007141
# {'accuracy': 0.8559037442758373,
#  'f1-score': 0.7788089425447833,
#  'mcc': 0.6726959168972693,
#  'roc_auc': 0.9198110569706113,
#  'recall': 0.7657455540355678}

# %%
lgbm_result, lgbm_models = fold5_ensemble_smote(lgbm, X, y)
lgbm_result
# Out:
# Fold 1 Accuracy: 0.8841698841698842 F1_Score: 0.8255813953488372  ROC_AUC: 0.947708025272214
# Fold 2 Accuracy: 0.8604651162790697 F1_Score: 0.7954545454545455  ROC_AUC: 0.9401027582477015
# Fold 3 Accuracy: 0.8449612403100775 F1_Score: 0.761904761904762  ROC_AUC: 0.9302278136688201
# Fold 4 Accuracy: 0.8837209302325582 F1_Score: 0.8170731707317074  ROC_AUC: 0.9326079564773886
# Fold 5 Accuracy: 0.8643410852713178 F1_Score: 0.7904191616766466  ROC_AUC: 0.9207752465147908
# {'accuracy': 0.8675316512525815,
#  'f1-score': 0.7980866070232998,
#  'mcc': 0.699903923534636,
#  'roc_auc': 0.934284360036183,
#  'recall': 0.791436388508892}

# %% [markdown]
# ## Optimal feature subset and model

# %%
from joblib import Parallel, delayed
from time import time
import numpy as np
import math
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
from lightgbm import LGBMClassifier
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import StratifiedKFold

def init_population(n, c):
    return np.array([[math.ceil(e) for e in pop] for pop in (np.random.rand(n, c) - 0.5)]), np.zeros((2, c)) - 1
def single_point_crossover(population):
    r,c, n = population.shape[0], population.shape[1], np.random.randint(1,population.shape[1])         
    for i in range(0,r,2):                
        population[i], population[i+1] = np.append(population[i][0:n],population[i+1][n:c]),np.append(population[i+1][0:n],population[i][n:c])        
    return population
def flip_mutation(population):
    return population.max() - population
def random_selection(population):
    r = population.shape[0]
    new_population = population.copy()    
    for i in range(r):        
        new_population[i] = population[np.random.randint(0, r)]
    return new_population
def predictive_model_cv(X, y, model, selected_features):
    kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    scores = []
    # 5-fold CV
    for train_index, test_index in kf.split(X, y):
        X_train, X_test = X.iloc[train_index][selected_features], X.iloc[test_index][selected_features]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
        # SMOTE
        smote = SMOTE(random_state=42)
        X_train_balanced, y_train_balanced = smote.fit_resample(X_train, y_train)
        mdl = model
        mdl.fit(X_train_balanced, y_train_balanced)
        y_pred = mdl.predict(X_test)
        score = accuracy_score(y_test, y_pred)
        scores.append(score)
    return np.mean(scores)
def individual_fitness_cv(individual, data, feature_list, target, model):
    # based on individual selection characteristics
    selected_features = [feature_list[j] for j in range(individual.shape[0]) if individual[j] == 1]
    # evaluate the performance of individual models
    return predictive_model_cv(data[selected_features], data[target], model, selected_features)
def get_fitness_cv(data, feature_list, target, population, model):
    fitness = Parallel(n_jobs=-1)(delayed(individual_fitness_cv)(individual, data, feature_list, target, model) for individual in population)
    return np.array(fitness)

def memorize(pop, memory):      
    return np.append(memory, pop.reshape(1, memory.shape[1]), axis=0)

def replace_duplicate(population, memory):    
    for i in range(population.shape[0]):         
        counter = 0                
        while any(np.all(memory == population[i], axis=1)) and (counter < 100): 
            population[i] = np.array([math.ceil(k) for k in (np.random.rand(population.shape[1]) - 0.5)])                    
            counter += 1                    
        memory = memorize(population[i], memory)   
    return population, memory

def ga(data, feature_list, target, n, max_iter, model):
    c = len(feature_list)
    population, memory = init_population(n, c)
    population, memory = replace_duplicate(population, memory)
    
    fitness = get_fitness_cv(data, feature_list, target, population, model)
    optimal_value = max(fitness)
    optimal_solution = population[np.where(fitness == optimal_value)][0]
    
    for i in range(max_iter): 
        start = time()
        population = random_selection(population)
        population = single_point_crossover(population)
        if np.random.rand() < 0.3:
            population = flip_mutation(population)
        
        population, memory = replace_duplicate(population, memory)
        fitness = get_fitness_cv(data, feature_list, target, population, model)
        
        if max(fitness) > optimal_value:
            optimal_value = max(fitness)
            optimal_solution = population[np.where(fitness == optimal_value)][0]
        end = time()
        print(f"The {i+1}th iteration T = {end - start:.4f}second")
    return optimal_solution, optimal_value

# %%
model = XGBClassifier( n_jobs=-1, random_state=42)
target = 'marker'
feature_list = [i for i in df1.columns if i not in target]

from time import time
start = time()
feature_set, optimize_accuracy = ga(df1, feature_list, target, 10, 1000, model)
end = time()
print(f"operating time T = %0.4f" % (end - start))

feature_set = [feature_list[i] for i in range(len(feature_list)) if feature_set[i] == 1]
print('Optimal Feature Set\n', feature_set, '\nOptimal Accuracy =', round(optimize_accuracy * 100), '%')
# Out:
# The 1th iteration T = 1.4899second
# The 2th iteration T = 1.5530second
# The 3th iteration T = 1.6018second
# The 4th iteration T = 1.5534second
# The 5th iteration T = 1.4223second
# The 6th iteration T = 1.6285second
# The 7th iteration T = 1.5515second
# The 8th iteration T = 1.6787second
# The 9th iteration T = 1.5965second
# The 10th iteration T = 1.3430second
# The 11th iteration T = 0.9001second
# The 12th iteration T = 0.8057second
# The 13th iteration T = 1.1875second
# The 14th iteration T = 0.7988second
# The 15th iteration T = 0.7845second
# The 16th iteration T = 0.7315second
# The 17th iteration T = 0.7379second
# The 18th iteration T = 0.7024second
# The 19th iteration T = 1.4911second
# The 20th iteration T = 0.9364second
# The 21th iteration T = 0.8928second
# The 22th iteration T = 0.7474second
# The 23th iteration T = 0.9680second
# The 24th iteration T = 0.8871second
# The 25th iteration T = 0.8881second
# The 26th iteration T = 0.8561second
# The 27th iteration T = 0.8454second
# The 28th iteration T = 0.9352second
# The 29th iteration T = 0.8110second
# The 30th iteration T = 0.6845second
# The 31th iteration T = 0.8197second
# The 32th iteration T = 0.8204second
# The 33th iteration T = 0.8460second
# The 34th iteration T = 0.9460second
# The 35th iteration T = 0.8340second
# The 36th iteration T = 0.8086second
# The 37th iteration T = 0.8658second
# The 38th iteration T = 0.7761second
# The 39th iteration T = 0.7362second
# The 40th iteration T = 0.8552second
# The 41th iteration T = 0.7978second
# The 42th iteration T = 0.8441second
# The 43th iteration T = 0.6512second
# The 44th iteration T = 0.7155second
# The 45th iteration T = 0.7583second
# The 46th iteration T = 0.7981second
# The 47th iteration T = 0.8439second
# The 48th iteration T = 0.7131second
# The 49th iteration T = 0.8457second
# The 50th iteration T = 0.7348second
# The 51th iteration T = 0.7372second
# The 52th iteration T = 0.7451second
# The 53th iteration T = 0.8062second
# The 54th iteration T = 0.9191second
# The 55th iteration T = 0.7172second
# The 56th iteration T = 0.7204second
# The 57th iteration T = 0.8679second
# The 58th iteration T = 0.6928second
# The 59th iteration T = 0.9008second
# The 60th iteration T = 0.8652second
# The 61th iteration T = 0.7990second
# The 62th iteration T = 0.8143second
# The 63th iteration T = 0.8216second
# The 64th iteration T = 0.7312second
# The 65th iteration T = 0.7335second
# The 66th iteration T = 0.7145second
# The 67th iteration T = 0.7148second
# The 68th iteration T = 0.7149second
# The 69th iteration T = 0.7306second
# The 70th iteration T = 0.8304second
# The 71th iteration T = 0.7493second
# The 72th iteration T = 0.7016second
# The 73th iteration T = 0.6859second
# The 74th iteration T = 0.7536second
# The 75th iteration T = 0.7296second
# The 76th iteration T = 0.7106second
# The 77th iteration T = 0.7813second
# The 85th iteration T = 0.8657second
# The 86th iteration T = 0.7295second
# The 87th iteration T = 0.6751second
# The 88th iteration T = 0.7386second
# The 89th iteration T = 0.7581second
# The 90th iteration T = 0.7190second
# The 91th iteration T = 0.8019second
# The 92th iteration T = 0.7612second
# The 93th iteration T = 0.7167second
# The 94th iteration T = 0.6963second
# The 95th iteration T = 0.6543second
# The 96th iteration T = 0.7549second
# The 97th iteration T = 0.7038second
# The 98th iteration T = 0.6909second
# The 99th iteration T = 0.8300second
# The 100th iteration T = 0.6777second
# The 101th iteration T = 0.7499second
# The 102th iteration T = 0.6915second
# The 103th iteration T = 0.6271second
# The 104th iteration T = 0.6134second
# The 105th iteration T = 0.5927second
# The 106th iteration T = 0.6775second
# The 107th iteration T = 0.7188second
# The 108th iteration T = 0.6604second
# The 109th iteration T = 0.7178second
# The 110th iteration T = 0.6851second
# The 111th iteration T = 0.6780second
# The 112th iteration T = 0.7037second
# The 113th iteration T = 0.6655second
# The 114th iteration T = 0.7250second
# The 115th iteration T = 0.6966second
# The 116th iteration T = 0.6878second
# The 117th iteration T = 0.7399second
# The 118th iteration T = 0.7564second
# The 119th iteration T = 0.7161second
# The 120th iteration T = 0.7490second
# The 121th iteration T = 0.6716second
# The 122th iteration T = 0.6723second
# The 123th iteration T = 0.8300second
# The 124th iteration T = 0.7610second
# The 125th iteration T = 0.7418second
# The 126th iteration T = 0.7828second
# The 127th iteration T = 0.7484second
# The 128th iteration T = 0.6832second
# The 129th iteration T = 0.7168second
# The 130th iteration T = 0.6978second
# The 131th iteration T = 0.7625second
# The 132th iteration T = 0.7885second
# The 133th iteration T = 0.6850second
# The 134th iteration T = 0.7181second
# The 135th iteration T = 0.7147second
# The 136th iteration T = 0.7384second
# The 137th iteration T = 0.6590second
# The 138th iteration T = 0.7398second
# The 139th iteration T = 0.9099second
# The 140th iteration T = 0.7417second
# The 141th iteration T = 0.7456second
# The 142th iteration T = 0.7128second
# The 143th iteration T = 0.7446second
# The 144th iteration T = 0.7006second
# The 145th iteration T = 0.7918second
# The 146th iteration T = 0.6953second
# The 147th iteration T = 0.6830second
# The 148th iteration T = 0.7328second
# The 149th iteration T = 0.7685second
# The 150th iteration T = 0.7205second
# The 151th iteration T = 0.7353second
# The 152th iteration T = 0.7015second
# The 153th iteration T = 0.7529second
# The 154th iteration T = 0.7516second
# The 155th iteration T = 0.7464second
# The 156th iteration T = 0.7217second
# The 157th iteration T = 0.7782second
# The 158th iteration T = 0.7239second
# The 159th iteration T = 0.7547second
# The 160th iteration T = 0.7285second
# The 161th iteration T = 0.6631second
# The 162th iteration T = 0.7119second
# The 163th iteration T = 0.6501second
# The 164th iteration T = 0.6701second
# The 165th iteration T = 0.6986second
# The 166th iteration T = 0.6916second
# The 167th iteration T = 0.6897second
# The 168th iteration T = 0.7447second
# The 169th iteration T = 0.6795second
# The 170th iteration T = 0.7594second
# The 171th iteration T = 0.7337second
# The 172th iteration T = 0.7811second
# The 173th iteration T = 0.7257second
# The 174th iteration T = 0.7239second
# The 175th iteration T = 0.7583second
# The 176th iteration T = 0.7043second
# The 177th iteration T = 0.6862second
# The 178th iteration T = 0.7070second
# The 179th iteration T = 0.6574second
# The 180th iteration T = 0.7334second
# The 181th iteration T = 0.7834second
# The 182th iteration T = 0.7564second
# The 183th iteration T = 0.7505second
# The 184th iteration T = 0.7378second
# The 185th iteration T = 0.6993second
# The 186th iteration T = 0.6891second
# The 187th iteration T = 0.6580second
# The 188th iteration T = 0.7022second
# The 189th iteration T = 0.7244second
# The 190th iteration T = 0.7458second
# The 191th iteration T = 0.7171second
# The 192th iteration T = 0.7186second
# The 193th iteration T = 0.7341second
# The 194th iteration T = 0.7448second
# The 195th iteration T = 0.7660second
# The 196th iteration T = 0.8518second
# The 197th iteration T = 0.7727second
# The 198th iteration T = 0.7244second
# The 199th iteration T = 0.6840second
# The 200th iteration T = 0.7233second
# The 201th iteration T = 0.7244second
# The 202th iteration T = 0.7615second
# The 203th iteration T = 0.7236second
# The 204th iteration T = 0.7024second
# The 205th iteration T = 0.7444second
# The 206th iteration T = 0.7423second
# The 207th iteration T = 0.7094second
# The 208th iteration T = 0.6815second
# The 209th iteration T = 0.7196second
# The 210th iteration T = 0.7394second
# The 211th iteration T = 0.7340second
# The 212th iteration T = 0.7120second
# The 213th iteration T = 0.7368second
# The 214th iteration T = 0.7266second
# The 215th iteration T = 0.7375second
# The 216th iteration T = 0.8120second
# The 217th iteration T = 0.7229second
# The 218th iteration T = 0.6787second
# The 219th iteration T = 0.6665second
# The 220th iteration T = 0.7404second
# The 221th iteration T = 0.7213second
# The 222th iteration T = 0.7151second
# The 223th iteration T = 0.8033second
# The 224th iteration T = 0.7037second
# The 225th iteration T = 0.7967second
# The 226th iteration T = 0.8383second
# The 227th iteration T = 0.7651second
# The 228th iteration T = 0.7543second
# The 229th iteration T = 0.7242second
# The 230th iteration T = 0.6700second
# The 231th iteration T = 0.6941second
# The 232th iteration T = 0.6789second
# The 233th iteration T = 0.7274second
# The 234th iteration T = 0.7719second
# The 235th iteration T = 0.7598second
# The 236th iteration T = 0.6965second
# The 237th iteration T = 0.7374second
# The 238th iteration T = 0.7897second
# The 239th iteration T = 0.7518second
# The 240th iteration T = 0.8413second
# The 241th iteration T = 0.7123second
# The 242th iteration T = 0.7281second
# The 243th iteration T = 0.7063second
# The 244th iteration T = 0.6665second
# The 245th iteration T = 0.7112second
# The 246th iteration T = 0.8251second
# The 247th iteration T = 0.7993second
# The 248th iteration T = 0.7535second
# The 249th iteration T = 0.8020second
# The 250th iteration T = 0.7629second
# The 251th iteration T = 0.6582second
# The 252th iteration T = 0.6487second
# The 253th iteration T = 0.7930second
# The 254th iteration T = 0.7356second
# The 255th iteration T = 0.7556second
# The 256th iteration T = 0.7162second
# The 257th iteration T = 0.7491second
# The 258th iteration T = 0.7839second
# The 259th iteration T = 0.7200second
# The 260th iteration T = 0.7323second
# The 261th iteration T = 0.7503second
# The 262th iteration T = 0.7311second
# The 263th iteration T = 0.7663second
# The 264th iteration T = 0.7635second
# The 265th iteration T = 0.7729second
# The 266th iteration T = 0.8078second
# The 267th iteration T = 0.7440second
# The 268th iteration T = 0.7577second
# The 269th iteration T = 0.7332second
# The 270th iteration T = 0.6769second
# The 271th iteration T = 0.7003second
# The 272th iteration T = 0.6985second
# The 273th iteration T = 0.7514second
# The 274th iteration T = 0.8058second
# The 275th iteration T = 0.7548second
# The 276th iteration T = 0.7191second
# The 277th iteration T = 0.7331second
# The 278th iteration T = 0.7352second
# The 279th iteration T = 0.8257second
# The 280th iteration T = 0.7235second
# The 281th iteration T = 0.7509second
# The 282th iteration T = 0.7067second
# The 283th iteration T = 0.7226second
# The 284th iteration T = 0.7126second
# The 285th iteration T = 0.7422second
# The 286th iteration T = 0.7376second
# The 287th iteration T = 0.7316second
# The 288th iteration T = 0.7524second
# The 289th iteration T = 0.7131second
# The 290th iteration T = 0.7038second
# The 291th iteration T = 0.7032second
# The 292th iteration T = 0.6643second
# The 293th iteration T = 0.7595second
# The 294th iteration T = 0.7423second
# The 295th iteration T = 0.7652second
# The 296th iteration T = 0.7224second
# The 297th iteration T = 0.6739second
# The 298th iteration T = 0.7317second
# The 299th iteration T = 0.7368second
# The 300th iteration T = 0.7105second
# The 301th iteration T = 0.7391second
# The 302th iteration T = 0.7076second
# The 303th iteration T = 0.7321second
# The 304th iteration T = 0.7356second
# The 305th iteration T = 0.7242second
# The 306th iteration T = 0.7220second
# The 307th iteration T = 0.7709second
# The 308th iteration T = 0.7926second
# The 309th iteration T = 0.7089second
# The 310th iteration T = 0.7404second
# The 311th iteration T = 0.7546second
# The 312th iteration T = 0.7599second
# The 313th iteration T = 0.7110second
# The 314th iteration T = 0.7228second
# The 315th iteration T = 0.6980second
# The 316th iteration T = 0.7432second
# The 317th iteration T = 0.6778second
# The 318th iteration T = 0.7482second
# The 319th iteration T = 0.7563second
# The 320th iteration T = 0.7374second
# The 321th iteration T = 0.7290second
# The 322th iteration T = 0.6840second
# The 323th iteration T = 0.7275second
# The 324th iteration T = 0.7691second
# The 325th iteration T = 0.7129second
# The 326th iteration T = 0.7091second
# The 327th iteration T = 0.7587second
# The 328th iteration T = 0.7511second
# The 329th iteration T = 0.7164second
# The 330th iteration T = 0.7030second
# The 331th iteration T = 0.7563second
# The 332th iteration T = 0.7243second
# The 333th iteration T = 0.7216second
# The 334th iteration T = 0.7442second
# The 335th iteration T = 0.7330second
# The 336th iteration T = 0.7366second
# The 337th iteration T = 0.7244second
# The 338th iteration T = 0.7417second
# The 339th iteration T = 0.7474second
# The 340th iteration T = 0.6941second
# The 341th iteration T = 0.7063second
# The 342th iteration T = 0.7389second
# The 343th iteration T = 0.7663second
# The 344th iteration T = 0.7459second
# The 345th iteration T = 0.7145second
# The 346th iteration T = 0.6836second
# The 347th iteration T = 0.7167second
# The 348th iteration T = 0.6734second
# The 349th iteration T = 0.6683second
# The 350th iteration T = 0.7168second
# The 351th iteration T = 0.6662second
# The 352th iteration T = 0.7187second
# The 353th iteration T = 0.6911second
# The 354th iteration T = 0.7095second
# The 355th iteration T = 0.7378second
# The 356th iteration T = 0.7049second
# The 357th iteration T = 0.7344second
# The 358th iteration T = 0.7417second
# The 359th iteration T = 0.7114second
# The 360th iteration T = 0.6978second
# The 361th iteration T = 0.7233second
# The 362th iteration T = 0.7682second
# The 363th iteration T = 0.7905second
# The 364th iteration T = 0.7626second
# The 365th iteration T = 0.7467second
# The 366th iteration T = 0.7735second
# The 367th iteration T = 0.8127second
# The 368th iteration T = 0.7419second
# The 369th iteration T = 0.7183second
# The 370th iteration T = 0.6768second
# The 371th iteration T = 0.7283second
# The 372th iteration T = 0.7260second
# The 373th iteration T = 0.7109second
# The 374th iteration T = 0.7004second
# The 375th iteration T = 0.7607second
# The 376th iteration T = 0.7473second
# The 377th iteration T = 0.7128second
# The 378th iteration T = 0.6778second
# The 379th iteration T = 0.7439second
# The 380th iteration T = 0.7363second
# The 381th iteration T = 0.7357second
# The 382th iteration T = 0.7377second
# The 383th iteration T = 0.8389second
# The 384th iteration T = 0.7393second
# The 385th iteration T = 0.7378second
# The 386th iteration T = 0.7288second
# The 387th iteration T = 0.7660second
# The 388th iteration T = 0.7593second
# The 389th iteration T = 0.8003second
# The 390th iteration T = 0.8033second
# The 391th iteration T = 0.7179second
# The 392th iteration T = 0.7457second
# The 393th iteration T = 0.7602second
# The 394th iteration T = 0.7725second
# The 395th iteration T = 0.6894second
# The 396th iteration T = 0.6616second
# The 397th iteration T = 0.7949second
# The 398th iteration T = 0.6976second
# The 399th iteration T = 0.8161second
# The 400th iteration T = 0.7328second
# The 401th iteration T = 0.7117second
# The 402th iteration T = 0.7426second
# The 403th iteration T = 0.7313second
# The 404th iteration T = 0.7334second
# The 405th iteration T = 0.7296second
# The 406th iteration T = 0.7582second
# The 407th iteration T = 0.7185second
# The 408th iteration T = 0.7244second
# The 409th iteration T = 0.7393second
# The 410th iteration T = 0.8083second
# The 411th iteration T = 0.7252second
# The 412th iteration T = 0.6462second
# The 413th iteration T = 0.6855second
# The 414th iteration T = 0.7034second
# The 415th iteration T = 0.7096second
# The 416th iteration T = 0.6750second
# The 417th iteration T = 0.7578second
# The 418th iteration T = 0.7416second
# The 419th iteration T = 0.7373second
# The 420th iteration T = 0.7305second
# The 421th iteration T = 0.8046second
# The 422th iteration T = 0.7938second
# The 423th iteration T = 0.6873second
# The 424th iteration T = 0.7601second
# The 425th iteration T = 0.6783second
# The 426th iteration T = 0.7253second
# The 427th iteration T = 0.7306second
# The 428th iteration T = 0.7688second
# The 429th iteration T = 0.7092second
# The 430th iteration T = 0.7676second
# The 431th iteration T = 0.7509second
# The 432th iteration T = 0.7479second
# The 433th iteration T = 0.7291second
# The 434th iteration T = 0.7187second
# The 435th iteration T = 0.6998second
# The 436th iteration T = 0.6770second
# The 437th iteration T = 0.7291second
# The 438th iteration T = 0.6978second
# The 439th iteration T = 0.7944second
# The 440th iteration T = 0.6889second
# The 441th iteration T = 0.7995second
# The 442th iteration T = 0.7200second
# The 443th iteration T = 0.7139second
# The 444th iteration T = 0.7788second
# The 445th iteration T = 0.7400second
# The 446th iteration T = 0.7502second
# The 447th iteration T = 0.7391second
# The 448th iteration T = 0.6897second
# The 449th iteration T = 0.7594second
# The 450th iteration T = 0.7490second
# The 451th iteration T = 0.7085second
# The 452th iteration T = 0.7616second
# The 453th iteration T = 0.6870second
# The 454th iteration T = 0.7601second
# The 455th iteration T = 0.7086second
# The 456th iteration T = 0.7205second
# The 457th iteration T = 0.7518second
# The 458th iteration T = 0.6580second
# The 459th iteration T = 0.6491second
# The 460th iteration T = 0.7716second
# The 461th iteration T = 0.6908second
# The 462th iteration T = 0.6948second
# The 463th iteration T = 0.7102second
# The 464th iteration T = 0.7151second
# The 465th iteration T = 0.6876second
# The 466th iteration T = 0.6599second
# The 467th iteration T = 0.6941second
# The 468th iteration T = 0.7025second
# The 469th iteration T = 0.7386second
# The 470th iteration T = 0.7039second
# The 471th iteration T = 0.7084second
# The 472th iteration T = 0.7881second
# The 473th iteration T = 0.7696second
# The 474th iteration T = 0.6695second
# The 475th iteration T = 0.7194second
# The 476th iteration T = 0.7526second
# The 477th iteration T = 0.6810second
# The 478th iteration T = 0.7371second
# The 479th iteration T = 0.7088second
# The 480th iteration T = 0.6720second
# The 481th iteration T = 0.7843second
# The 482th iteration T = 0.7098second
# The 483th iteration T = 0.7357second
# The 484th iteration T = 0.7245second
# The 485th iteration T = 0.7216second
# The 486th iteration T = 0.6934second
# The 487th iteration T = 0.7389second
# The 488th iteration T = 0.7190second
# The 489th iteration T = 0.7152second
# The 490th iteration T = 0.8182second
# The 491th iteration T = 0.7107second
# The 492th iteration T = 0.7794second
# The 493th iteration T = 0.7411second
# The 494th iteration T = 0.7045second
# The 495th iteration T = 0.6732second
# The 496th iteration T = 0.7008second
# The 497th iteration T = 0.6764second
# The 498th iteration T = 0.6828second
# The 499th iteration T = 0.6884second
# The 500th iteration T = 0.7161second
# The 501th iteration T = 0.6608second
# The 502th iteration T = 0.6689second
# The 503th iteration T = 0.7244second
# The 504th iteration T = 0.7009second
# The 505th iteration T = 0.7436second
# The 506th iteration T = 0.6944second
# The 507th iteration T = 0.7102second
# The 508th iteration T = 0.7425second
# The 509th iteration T = 0.7465second
# The 510th iteration T = 0.7510second
# The 511th iteration T = 0.7801second
# The 512th iteration T = 0.7993second
# The 513th iteration T = 0.7890second
# The 514th iteration T = 0.7415second
# The 515th iteration T = 0.7309second
# The 516th iteration T = 0.7130second
# The 517th iteration T = 0.7098second
# The 518th iteration T = 0.7588second
# The 519th iteration T = 0.7473second
# The 520th iteration T = 0.8301second
# The 521th iteration T = 0.6919second
# The 522th iteration T = 0.7399second
# The 523th iteration T = 0.7122second
# The 524th iteration T = 0.7379second
# The 525th iteration T = 0.7451second
# The 526th iteration T = 0.6868second
# The 527th iteration T = 0.6821second
# The 528th iteration T = 0.7246second
# The 529th iteration T = 0.7071second
# The 530th iteration T = 0.7694second
# The 531th iteration T = 0.7488second
# The 532th iteration T = 0.7296second
# The 533th iteration T = 0.7543second
# The 534th iteration T = 0.7736second
# The 535th iteration T = 0.7698second
# The 536th iteration T = 0.7715second
# The 537th iteration T = 0.7205second
# The 538th iteration T = 0.7471second
# The 539th iteration T = 0.7167second
# The 540th iteration T = 0.6661second
# The 541th iteration T = 0.6999second
# The 542th iteration T = 0.6873second
# The 543th iteration T = 0.7029second
# The 544th iteration T = 0.7367second
# The 545th iteration T = 0.6903second
# The 546th iteration T = 0.7141second
# The 547th iteration T = 0.7185second
# The 548th iteration T = 0.6984second
# The 549th iteration T = 0.7345second
# The 550th iteration T = 0.7050second
# The 551th iteration T = 0.6823second
# The 552th iteration T = 0.8245second
# The 553th iteration T = 0.7450second
# The 554th iteration T = 0.7764second
# The 555th iteration T = 0.7463second
# The 556th iteration T = 0.7321second
# The 557th iteration T = 0.7122second
# The 558th iteration T = 0.7835second
# The 559th iteration T = 0.7259second
# The 560th iteration T = 0.7614second
# The 561th iteration T = 0.7874second
# The 562th iteration T = 0.7448second
# The 563th iteration T = 0.7086second
# The 564th iteration T = 0.6547second
# The 565th iteration T = 0.7329second
# The 566th iteration T = 0.7004second
# The 567th iteration T = 0.7610second
# The 568th iteration T = 0.6876second
# The 569th iteration T = 0.7290second
# The 570th iteration T = 0.6785second
# The 571th iteration T = 0.7442second
# The 572th iteration T = 0.7032second
# The 573th iteration T = 0.7506second
# The 574th iteration T = 0.7050second
# The 575th iteration T = 0.6997second
# The 576th iteration T = 0.6974second
# The 577th iteration T = 0.7849second
# The 578th iteration T = 0.7220second
# The 579th iteration T = 0.7200second
# The 580th iteration T = 0.7016second
# The 581th iteration T = 0.6819second
# The 582th iteration T = 0.6981second
# The 583th iteration T = 0.6990second
# The 584th iteration T = 0.7386second
# The 585th iteration T = 0.6846second
# The 586th iteration T = 0.6726second
# The 587th iteration T = 0.7992second
# The 588th iteration T = 0.7288second
# The 589th iteration T = 0.6877second
# The 590th iteration T = 0.7159second
# The 591th iteration T = 0.6900second
# The 592th iteration T = 0.6733second
# The 593th iteration T = 0.7372second
# The 594th iteration T = 0.7300second
# The 595th iteration T = 0.7521second
# The 596th iteration T = 0.7353second
# The 597th iteration T = 0.7644second
# The 598th iteration T = 0.7198second
# The 599th iteration T = 0.7772second
# The 600th iteration T = 0.6950second
# The 601th iteration T = 0.7372second
# The 602th iteration T = 0.7353second
# The 603th iteration T = 0.7029second
# The 604th iteration T = 0.7734second
# The 605th iteration T = 0.7578second
# The 606th iteration T = 0.6599second
# The 607th iteration T = 0.7411second
# The 608th iteration T = 0.7235second
# The 609th iteration T = 0.7090second
# The 610th iteration T = 0.6996second
# The 611th iteration T = 0.6951second
# The 612th iteration T = 0.7328second
# The 613th iteration T = 0.6686second
# The 614th iteration T = 0.7624second
# The 615th iteration T = 0.8028second
# The 616th iteration T = 0.7173second
# The 617th iteration T = 0.7636second
# The 618th iteration T = 0.7543second
# The 619th iteration T = 0.7050second
# The 620th iteration T = 0.7261second
# The 621th iteration T = 0.6535second
# The 622th iteration T = 0.6872second
# The 623th iteration T = 0.6951second
# The 624th iteration T = 0.7247second
# The 625th iteration T = 0.6820second
# The 626th iteration T = 0.7849second
# The 627th iteration T = 0.8078second
# The 628th iteration T = 0.7846second
# The 629th iteration T = 0.7172second
# The 630th iteration T = 0.7849second
# The 631th iteration T = 0.6865second
# The 632th iteration T = 0.7473second
# The 633th iteration T = 0.7726second
# The 634th iteration T = 0.6998second
# The 635th iteration T = 0.7121second
# The 636th iteration T = 0.6886second
# The 637th iteration T = 0.7227second
# The 638th iteration T = 0.7464second
# The 639th iteration T = 0.7583second
# The 640th iteration T = 0.7011second
# The 641th iteration T = 0.6918second
# The 642th iteration T = 0.7342second
# The 643th iteration T = 0.8150second
# The 644th iteration T = 0.7312second
# The 645th iteration T = 0.7696second
# The 646th iteration T = 0.7237second
# The 647th iteration T = 0.6958second
# The 648th iteration T = 0.7233second
# The 649th iteration T = 0.7560second
# The 650th iteration T = 0.7850second
# The 651th iteration T = 0.6651second
# The 652th iteration T = 0.8277second
# The 653th iteration T = 0.7475second
# The 654th iteration T = 0.7116second
# The 655th iteration T = 0.7586second
# The 656th iteration T = 0.6855second
# The 657th iteration T = 0.7506second
# The 658th iteration T = 0.7480second
# The 659th iteration T = 0.7728second
# The 660th iteration T = 0.7624second
# The 661th iteration T = 0.7636second
# The 662th iteration T = 0.8078second
# The 663th iteration T = 0.7529second
# The 664th iteration T = 0.7605second
# The 665th iteration T = 0.7377second
# The 666th iteration T = 0.7328second
# The 667th iteration T = 0.7396second
# The 668th iteration T = 0.6939second
# The 669th iteration T = 0.6748second
# The 670th iteration T = 0.7529second
# The 671th iteration T = 0.6924second
# The 672th iteration T = 0.7227second
# The 673th iteration T = 0.7753second
# The 674th iteration T = 0.7294second
# The 675th iteration T = 0.7014second
# The 676th iteration T = 0.7379second
# The 677th iteration T = 0.7407second
# The 678th iteration T = 0.6422second
# The 679th iteration T = 0.8004second
# The 680th iteration T = 0.7131second
# The 681th iteration T = 0.7926second
# The 682th iteration T = 0.7326second
# The 683th iteration T = 0.7560second
# The 684th iteration T = 0.7355second
# The 685th iteration T = 0.7133second
# The 686th iteration T = 0.7239second
# The 687th iteration T = 0.7419second
# The 688th iteration T = 0.8068second
# The 689th iteration T = 0.7539second
# The 690th iteration T = 0.7513second
# The 691th iteration T = 0.7298second
# The 692th iteration T = 0.8522second
# The 693th iteration T = 0.8281second
# The 694th iteration T = 0.6996second
# The 695th iteration T = 0.7800second
# The 696th iteration T = 0.6793second
# The 697th iteration T = 0.7313second
# The 698th iteration T = 0.6653second
# The 699th iteration T = 0.6635second
# The 700th iteration T = 0.7858second
# The 701th iteration T = 0.7120second
# The 702th iteration T = 0.7853second
# The 703th iteration T = 0.8542second
# The 704th iteration T = 0.7145second
# The 705th iteration T = 0.7588second
# The 706th iteration T = 0.7437second
# The 707th iteration T = 0.7280second
# The 708th iteration T = 0.7799second
# The 709th iteration T = 0.7146second
# The 710th iteration T = 0.8080second
# The 711th iteration T = 0.7399second
# The 712th iteration T = 0.7941second
# The 713th iteration T = 0.7553second
# The 714th iteration T = 0.7261second
# The 715th iteration T = 0.7620second
# The 716th iteration T = 0.7584second
# The 717th iteration T = 0.8704second
# The 718th iteration T = 0.7382second
# The 719th iteration T = 0.7670second
# The 720th iteration T = 0.7990second
# The 721th iteration T = 0.7237second
# The 722th iteration T = 0.7493second
# The 723th iteration T = 0.7850second
# The 724th iteration T = 0.8694second
# The 725th iteration T = 0.8058second
# The 726th iteration T = 0.7036second
# The 727th iteration T = 0.7274second
# The 728th iteration T = 0.8346second
# The 729th iteration T = 0.8345second
# The 730th iteration T = 0.7231second
# The 731th iteration T = 0.7240second
# The 732th iteration T = 0.6880second
# The 733th iteration T = 0.7284second
# The 734th iteration T = 0.7790second
# The 735th iteration T = 0.6867second
# The 736th iteration T = 0.6753second
# The 737th iteration T = 0.8152second
# The 738th iteration T = 0.7321second
# The 739th iteration T = 0.7234second
# The 740th iteration T = 0.7272second
# The 741th iteration T = 0.7766second
# The 742th iteration T = 0.7128second
# The 743th iteration T = 0.7670second
# The 744th iteration T = 0.7386second
# The 745th iteration T = 0.7076second
# The 746th iteration T = 0.7113second
# The 747th iteration T = 0.7904second
# The 748th iteration T = 0.6799second
# The 749th iteration T = 0.7622second
# The 750th iteration T = 0.7659second
# The 751th iteration T = 0.7513second
# The 752th iteration T = 0.7589second
# The 753th iteration T = 0.7637second
# The 754th iteration T = 0.7841second
# The 755th iteration T = 0.6909second
# The 756th iteration T = 0.7712second
# The 757th iteration T = 0.7520second
# The 758th iteration T = 0.7267second
# The 759th iteration T = 0.7302second
# The 760th iteration T = 0.6635second
# The 761th iteration T = 0.7654second
# The 762th iteration T = 0.7765second
# The 763th iteration T = 0.7149second
# The 764th iteration T = 0.7154second
# The 765th iteration T = 0.7681second
# The 766th iteration T = 0.8014second
# The 767th iteration T = 0.7675second
# The 768th iteration T = 0.7385second
# The 769th iteration T = 0.7171second
# The 770th iteration T = 0.7473second
# The 771th iteration T = 0.6998second
# The 772th iteration T = 0.7931second
# The 773th iteration T = 0.6922second
# The 774th iteration T = 0.7694second
# The 775th iteration T = 0.6821second
# The 776th iteration T = 0.7709second
# The 777th iteration T = 0.7883second
# The 939th iteration T = 0.7338second
# The 940th iteration T = 0.7702second
# The 941th iteration T = 0.7167second
# The 942th iteration T = 0.6639second
# The 943th iteration T = 0.7129second
# The 944th iteration T = 0.7284second
# The 945th iteration T = 0.6949second
# The 946th iteration T = 0.7690second
# The 947th iteration T = 0.6557second
# The 948th iteration T = 0.6872second
# The 949th iteration T = 0.7024second
# The 950th iteration T = 0.6844second
# The 951th iteration T = 0.6662second
# The 952th iteration T = 0.7384second
# The 953th iteration T = 0.7687second
# The 954th iteration T = 0.7304second
# The 955th iteration T = 0.6590second
# The 956th iteration T = 0.7751second
# The 957th iteration T = 0.7366second
# The 958th iteration T = 0.7905second
# The 959th iteration T = 0.7401second
# The 960th iteration T = 0.7742second
# The 961th iteration T = 0.7779second
# The 962th iteration T = 0.7012second
# The 963th iteration T = 0.7867second
# The 964th iteration T = 0.7860second
# The 965th iteration T = 0.7539second
# The 966th iteration T = 0.7184second
# The 967th iteration T = 0.6937second
# The 968th iteration T = 0.7274second
# The 969th iteration T = 0.7751second
# The 970th iteration T = 0.8166second
# The 971th iteration T = 0.7773second
# The 972th iteration T = 0.7072second
# The 973th iteration T = 0.8466second
# The 974th iteration T = 0.8004second
# The 975th iteration T = 0.8114second
# The 976th iteration T = 0.6651second
# The 977th iteration T = 0.7321second
# The 978th iteration T = 0.7578second
# The 979th iteration T = 0.6973second
# The 980th iteration T = 0.8375second
# The 981th iteration T = 0.6969second
# The 982th iteration T = 0.6391second
# The 983th iteration T = 0.7544second
# The 984th iteration T = 0.7475second
# The 985th iteration T = 0.7348second
# The 986th iteration T = 0.7108second
# The 987th iteration T = 0.7092second
# The 988th iteration T = 0.7078second
# The 989th iteration T = 0.7088second
# The 990th iteration T = 0.7345second
# The 991th iteration T = 0.7501second
# The 992th iteration T = 0.7141second
# The 993th iteration T = 0.7724second
# The 994th iteration T = 0.7438second
# The 995th iteration T = 0.7540second
# The 996th iteration T = 0.7362second
# The 997th iteration T = 0.7596second
# The 998th iteration T = 0.7699second
# The 999th iteration T = 0.7541second
# The 1000th iteration T = 0.7527second
# operating time T = 750.7070
# Optimal Feature Set
#  ['B_Density', 'C_atomic Radius', 'A_number of Valence Electrons', 'C_number', 'A_number of s+p Electrons', 'B_number of s+p Electrons', 'C_number of s+p Electrons', 'C_Mulliken EN', 'A-C_Density', '(A+B+C)-X_dipole Polarizability', '(A+B+C)-X_atomic Radius', 'A-C_number of Valence Electrons', '(A+B+C)-X_number of Valence Electrons', 'A-C_number', 'A-B_Period', 'A-C_Period', 'A-C_number of s+p Electrons', 'A-C_number of d Electrons', '(A+B+C)-X_number of d Electrons', 'A-C_Mulliken EN']
# Optimal Accuracy = 88 %

# %%
#Optimal Feature Set
feature_xb =  ['B_Density', 'C_dipole Polarizability', 'C_atomic Radius', 'C_number', 'A_number of s+p Electrons', 'C_number of s+p Electrons',
               'A-C_Density', '(A+B+C)-X_dipole Polarizability', '(A+B+C)-X_atomic Radius', '(A+B+C)-X_number of Valence Electrons',
               'A-C_number', 'A-B_Period', 'A-C_Electronegativity', 'A-C_number of s+p Electrons', 'A-C_number of d Electrons', '(A+B+C)-X_number of d Electrons', 'A-C_Mulliken EN']  
#Optimal Accuracy = 88 %

# %%
X_xgb = X[feature_xb]

print(X_xgb.shape)
# Out:
# (1291, 17)

# %%
from sklearn.ensemble import ExtraTreesClassifier
#nosmote
xgb2_result, xgb2_models = fold5_ensemble(xb, X_xgb, y)
xgb2_result
# Out:
# Fold 1 Accuracy: 0.8803088803088803 F1_Score: 0.8143712574850299  ROC_AUC: 0.9460276918940718
# Fold 2 Accuracy: 0.8527131782945736 F1_Score: 0.7738095238095238  ROC_AUC: 0.9332071389940508
# Fold 3 Accuracy: 0.872093023255814 F1_Score: 0.8023952095808382  ROC_AUC: 0.9429445766746005
# Fold 4 Accuracy: 0.8837209302325582 F1_Score: 0.8192771084337349  ROC_AUC: 0.9344440666439987
# Fold 5 Accuracy: 0.8372093023255814 F1_Score: 0.7469879518072289  ROC_AUC: 0.9109146548792928
# {'accuracy': 0.8652090628834814,
#  'f1-score': 0.7913682102232712,
#  'mcc': 0.6923437004706993,
#  'roc_auc': 0.933507625817203,
#  'recall': 0.7728317373461012}

# %%
#!!!!!!！！！！！Best model！！
from sklearn.ensemble import ExtraTreesClassifier

xgb_result, xgb_models = fold5_ensemble_smote(xb, X_xgb, y)
xgb_result
# Out:
# Fold 1 Accuracy: 0.8996138996138996 F1_Score: 0.8470588235294119  ROC_AUC: 0.9523457453958866
# Fold 2 Accuracy: 0.8914728682170543 F1_Score: 0.8333333333333333  ROC_AUC: 0.9342212006489994
# Fold 3 Accuracy: 0.875968992248062 F1_Score: 0.8117647058823529  ROC_AUC: 0.9377082624957498
# Fold 4 Accuracy: 0.8953488372093024 F1_Score: 0.8383233532934131  ROC_AUC: 0.9369602176130568
# Fold 5 Accuracy: 0.872093023255814 F1_Score: 0.8092485549132947  ROC_AUC: 0.9177830669840191
# {'accuracy': 0.8868995241088264,
#  'f1-score': 0.8279457541903612,
#  'mcc': 0.7439518872499773,
#  'roc_auc': 0.9358036986275422,
#  'recall': 0.8219972640218878}

# %% [markdown]
# ## Model effect and interpretability

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv('./data/ml_eh_data/fold0_predict_prob.csv')  
pos_probs = df[df['true_label'] == 1]['predict_proba'].values
neg_probs = df[df['true_label'] == 0]['predict_proba'].values

bins = np.linspace(0, 1, 21)
neg_counts, bin_edges = np.histogram(neg_probs, bins=bins)
pos_counts, _ = np.histogram(pos_probs, bins=bins)

bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2
width = 0.045  
offset = width * 0.5  

fig, ax = plt.subplots()
ax.axvspan(0, 0.5, facecolor='#ffecec', alpha=0.5)   
ax.axvspan(0.5, 1, facecolor='#e6f7f2', alpha=0.5)  

ax.bar(bin_centers - offset, neg_counts, width=width, alpha=0.8, 
        color='#d43d3d', linewidth=0.7, 
        label='Negatives')
ax.bar(bin_centers + offset, pos_counts, width=width, alpha=0.8, 
        color='#2a9c88', linewidth=0.7, 
        label='Positives')
ax.axvline(0.5, color='blue', linestyle='--', linewidth=2, label='Boundary')

ax.set_xlabel('Positive Probability (predicted)', fontsize=22)
ax.set_ylabel('Number', fontsize=22)

ax.legend(loc='upper right', frameon=True, framealpha=0.9, fontsize=18)
ax.set_xlim(0, 1)

ax.spines['top'].set_linewidth(1.5)
ax.spines['bottom'].set_linewidth(1.5)
ax.spines['left'].set_linewidth(1.5)
ax.spines['right'].set_linewidth(1.5)
ax.tick_params(axis='both', which='major', labelsize=22)

#plt.savefig('./picture/eh_probability_distribution.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
import joblib
joblib.dump(xgb_models, './data/eh_xgb.joblib')
# Out:
# ['./data/eh_xgb.joblib']

# %%
features_xgb =  ['B_Density', 'C_dipole Polarizability', 'C_atomic Radius', 'C_number', 'A_number of s+p Electrons', 'C_number of s+p Electrons',
               'A-C_Density', '(A+B+C)-X_dipole Polarizability', '(A+B+C)-X_atomic Radius', '(A+B+C)-X_number of Valence Electrons',
               'A-C_number', 'A-B_Period', 'A-C_Electronegativity', 'A-C_number of s+p Electrons', 'A-C_number of d Electrons', '(A+B+C)-X_number of d Electrons', 'A-C_Mulliken EN']

# %%
shap.summary_plot(shap_values, test, plot_type="dot", show=False,max_display=5,color_bar=True)
plt.gca().set_position([0.2, 0.2, 0.65, 0.65]) 

ax1 = plt.gca()
ax2 = ax1.twiny()
shap.summary_plot(shap_values, test, plot_type="bar", show=False,max_display=5)
plt.gca().set_position([0.2, 0.2, 0.65, 0.65])  
ax2.axhline(y=5, color='gray', linestyle='-', linewidth=1.5) 
bars = ax2.patches  

for bar in bars:    
    bar.set_alpha(0.2)  
ax1.set_xlabel('Shapley Value Contribution (Bee Swarm)', fontsize=12)
ax2.set_xlabel('Mean Shapley Value (Feature Importance)', fontsize=12)
ax2.xaxis.set_ticks_position('top') 
ax2.xaxis.set_label_position('top')
plt.subplots_adjust(
    left=0.2,   
    right=0.75,  
    top=0.85,    
    bottom=0.15  
)

ax1.set_ylabel('Features', fontsize=12)
plt.tight_layout()
plt.savefig('./picture/eh_shap.png', bbox_inches='tight')
plt.show()

# %%
shap.plots.scatter(shap_values[:, 'A-B_Period'], hist=False,show=False)
ax = plt.gca()
for spine in ax.spines.values():
    spine.set_linewidth(1.5)
ax.tick_params(axis='both', which='major', labelsize=30)
plt.setp(ax.get_xticklabels(), fontweight=550,color='black')  # x轴加粗
plt.setp(ax.get_yticklabels(), fontweight=550,color='black')
ax.set_ylabel("SHAP value for \n $P_{\mathrm{A-B}}$", fontsize=30,fontweight=550,color='black')
ax.set_xlabel(r"$P_{\mathrm{A-B}}$", fontsize=30,fontweight=550,color='black')
plt.tight_layout()
ax.axhline(y=0,color='black',linestyle='--',linewidth=1,zorder=3)
ax.axvline(x=5,color='black',linestyle='--',linewidth=1,zorder=3)
plt.savefig("./picture/eh_shap1.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
shap.plots.scatter(shap_values[:, '(A+B+C)-X_atomic Radius'], hist=False,show=False)
ax = plt.gca()
for spine in ax.spines.values():
    spine.set_linewidth(1.5)
ax.tick_params(axis='both', which='major', labelsize=30)
plt.setp(ax.get_xticklabels(), fontweight=550,color='black')  # x轴加粗
plt.setp(ax.get_yticklabels(), fontweight=550,color='black')
ax.set_ylabel("SHAP value for \n $AR_{\mathrm{(A+B+B')-X}}$", fontsize=30, fontweight=550,color='black')
ax.set_xlabel(r"$AR_{\mathrm{(A+B+B')-X}}$", fontsize=30, fontweight=550,color='black')
plt.tight_layout()
ax.axhline(y=0,color='black',linestyle='--',linewidth=1,zorder=3)
ax.axvline(x=1.5,color='black',linestyle='--',linewidth=1,zorder=3)
plt.savefig("./picture/eh_shap2.png", dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# # predict Eh and screen materials

# %%
data = pd.read_csv('./data/data_tf.csv')
data
# Out:
#         formula  number  A_Density  B_Density  C_Density  X_Density  \
# 0      Li2NaBF6       1      1.068      0.971    2.34000     0.0102
# 1      Li2NaNF6       1      1.068      0.971    0.00125     0.0102
# 2     Li2CuAlF6       1      1.068      8.960    2.70000     0.0102
# 3      Li2CuPF6       1      1.068      8.960    1.82000     0.0102
# 4     Li2CuCrF6       1      1.068      8.960    7.15000     0.0102
# ...         ...     ...        ...        ...        ...        ...
# 9081  Nd2LiCuF6       3     14.020      0.534    8.96000     0.0102
# 9082  Nd2NaCuF6       3     14.020      0.971    8.96000     0.0102
# 9083  Eu2LiCuF6       3     10.480      0.534    8.96000     0.0102
# 9084  Tm2LiCuF6       3     18.640      0.534    8.96000     0.0102
# 9085  Yb2LiCuF6       3     13.940      0.534    8.96000     0.0102
#
#       A_dipole Polarizability  B_dipole Polarizability  \
# 0                     328.225                 162.7000
# 1                     328.225                 162.7000
# 2                     328.225                  46.5000
# 3                     328.225                  46.5000
# 4                     328.225                  46.5000
# ...                       ...                      ...
# 9081                  416.000                 164.1125
# 9082                  416.000                 162.7000
# 9083                  368.000                 164.1125
# 9084                  288.000                 164.1125
# 9085                  278.000                 164.1125
#
#       C_dipole Polarizability  X_dipole Polarizability  A_covalent Radius  \
# 0                        20.5                    22.44                266
# 1                         7.4                    22.44                266
# 2                        57.8                    22.44                266
# 3                        25.0                    22.44                266
# 4                        83.0                    22.44                266
# ...                       ...                      ...                ...
# 9081                     46.5                    22.44                348
# 9082                     46.5                    22.44                348
# 9083                     46.5                    22.44                336
# 9084                     46.5                    22.44                328
# 9085                     46.5                    22.44                340
#
#       B_covalent Radius  C_covalent Radius  X_covalent Radius  \
# 0                   155                 85                384
# 1                   155                 71                384
# 2                   112                126                384
# 3                   112                111                384
# 4                   112                122                384
# ...                 ...                ...                ...
# 9081                133                112                384
# 9082                155                112                384
# 9083                133                112                384
# 9084                133                112                384
# 9085                133                112                384
#
#       A_atomic Radius  B_atomic Radius  C_atomic Radius  X_atomic Radius  \
# 0                 2.9             1.80             0.85              3.0
# 1                 2.9             1.80             0.65              3.0
# 2                 2.9             1.35             1.25              3.0
# 3                 2.9             1.35             1.00              3.0
# 4                 2.9             1.35             1.40              3.0
# ...               ...              ...              ...              ...
# 9081              3.7             1.45             1.35              3.0
# 9082              3.7             1.80             1.35              3.0
# 9083              3.7             1.45             1.35              3.0
# 9084              3.5             1.45             1.35              3.0
# 9085              3.5             1.45             1.35              3.0
#
#       A_FirstIonization  B_FirstIonization  C_FirstIonization  \
# 0                1040.4              495.8              800.6
# 1                1040.4              495.8             1402.3
# 2                1040.4              745.5              577.5
# 3                1040.4              745.5             1011.8
# 4                1040.4              745.5              652.9
# ...                 ...                ...                ...
# 9081             1066.2              520.2              745.5
# 9082             1066.2              495.8              745.5
# 9083             1094.2              520.2              745.5
# 9084             1193.4              520.2              745.5
# 9085             1206.8              520.2              745.5
#
#       X_FirstIonization  A_number of Valence Electrons  \
# 0               10086.0                              2
# 1               10086.0                              2
# 2               10086.0                              2
# 3               10086.0                              2
# 4               10086.0                              2
# ...                 ...                            ...
# 9081            10086.0                              6
# 9082            10086.0                              6
# 9083            10086.0                              6
# 9084            10086.0                              6
# 9085            10086.0                              6
#
#       B_number of Valence Electrons  C_number of Valence Electrons  \
# 0                                 1                              3
# 1                                 1                              5
# 2                                11                              3
# 3                                11                              5
# 4                                11                              6
# ...                             ...                            ...
# 9081                              1                             11
# 9082                              1                             11
# 9083                              1                             11
# 9084                              1                             11
# 9085                              1                             11
#
#       X_number of Valence Electrons  A_number  B_number  C_number  X_number  \
# 0                                42         6        11         5        54
# 1                                42         6        11         7        54
# 2                                42         6        29        13        54
# 3                                42         6        29        15        54
# 4                                42         6        29        24        54
# ...                             ...       ...       ...       ...       ...
# 9081                             42       120         3        29        54
# 9082                             42       120        11        29        54
# 9083                             42       126         3        29        54
# 9084                             42       138         3        29        54
# 9085                             42       140         3        29        54
#
#       ...  A-B_covalent Radius  A-C_covalent Radius  \
# 0     ...                  111                  181
# 1     ...                  111                  195
# 2     ...                  154                  140
# 3     ...                  154                  155
# 4     ...                  154                  144
# ...   ...                  ...                  ...
# 9081  ...                  215                  236
# 9082  ...                  193                  236
# 9083  ...                  203                  224
# 9084  ...                  195                  216
# 9085  ...                  207                  228
#
#       (A+B+C)-X_covalent Radius  A-B_atomic Radius  A-C_atomic Radius  \
# 0                           122               1.10               2.05
# 1                           108               1.10               2.25
# 2                           120               1.55               1.65
# 3                           105               1.55               1.90
# 4                           116               1.55               1.50
# ...                         ...                ...                ...
# 9081                        209               2.25               2.35
# 9082                        231               1.90               2.35
# 9083                        197               2.25               2.35
# 9084                        189               2.05               2.15
# 9085                        201               2.05               2.15
#
#       (A+B+C)-X_atomic Radius  A-B_FirstIonization  A-C_FirstIonization  \
# 0                        2.55                544.6                239.8
# 1                        2.35                544.6                361.9
# 2                        2.50                294.9                462.9
# 3                        2.25                294.9                 28.6
# 4                        2.65                294.9                387.5
# ...                       ...                  ...                  ...
# 9081                     3.50                546.0                320.7
# 9082                     3.85                570.4                320.7
# 9083                     3.50                574.0                348.7
# 9084                     3.30                673.2                447.9
# 9085                     3.30                686.6                461.3
#
#       (A+B+C)-X_FirstIonization  A-B_number of Valence Electrons  \
# 0                        7749.2                                1
# 1                        7147.5                                1
# 2                        7722.6                                9
# 3                        7288.3                                9
# 4                        7647.2                                9
# ...                         ...                              ...
# 9081                     7754.1                                5
# 9082                     7778.5                                5
# 9083                     7726.1                                5
# 9084                     7626.9                                5
# 9085                     7613.5                                5
#
#       A-C_number of Valence Electrons  (A+B+C)-X_number of Valence Electrons  \
# 0                                   1                                     36
# 1                                   3                                     34
# 2                                   1                                     26
# 3                                   3                                     24
# 4                                   4                                     23
# ...                               ...                                    ...
# 9081                                5                                     24
# 9082                                5                                     24
# 9083                                5                                     24
# 9084                                5                                     24
# 9085                                5                                     24
#
#       A-B_number  A-C_number  (A+B+C)-X_number  A-B_Period  A-C_Period  \
# 0              5           1                32           1           2
# 1              5           1                30           1           2
# 2             23           7                 6           0           1
# 3             23           9                 4           0           1
# 4             23          18                 5           0           0
# ...          ...         ...               ...         ...         ...
# 9081         117          91                98          10           8
# 9082         109          91               106           9           8
# 9083         123          97               104          10           8
# 9084         135         109               116          10           8
# 9085         137         111               118          10           8
#
#       (A+B+C)-X_Period  A-B_Electronegativity  A-C_Electronegativity  \
# 0                    3                   1.03                   0.08
# 1                    3                   1.03                   1.08
# 2                    1                   0.06                   0.35
# 3                    1                   0.06                   0.23
# 4                    0                   0.06                   0.30
# ...                ...                    ...                    ...
# 9081                 6                   1.30                   0.38
# 9082                 7                   1.35                   0.38
# 9083                 6                   1.42                   0.50
# 9084                 6                   1.52                   0.60
# 9085                 6                   1.22                   0.30
#
#       (A+B+C)-X_Electronegativity  A-B_number of s+p Electrons  \
# 0                           18.95                            1
# 1                           17.95                            1
# 2                           18.41                            1
# 3                           17.83                            1
# 4                           18.36                            1
# ...                           ...                          ...
# 9081                        18.72                            3
# 9082                        18.77                            3
# 9083                        18.60                            3
# 9084                        18.50                            3
# 9085                        18.80                            3
#
#       A-C_number of s+p Electrons  (A+B+C)-X_number of s+p Electrons  \
# 0                               1                                 36
# 1                               3                                 34
# 2                               1                                 36
# 3                               3                                 34
# 4                               1                                 38
# ...                           ...                                ...
# 9081                            3                                 36
# 9082                            3                                 36
# 9083                            3                                 36
# 9084                            3                                 36
# 9085                            3                                 36
#
#       A-B_number of d Electrons  A-C_number of d Electrons  \
# 0                             0                          0
# 1                             0                          0
# 2                            10                          0
# 3                            10                          0
# 4                            10                          5
# ...                         ...                        ...
# 9081                          0                         10
# 9082                          0                         10
# 9083                          0                         10
# 9084                          0                         10
# 9085                          0                         10
#
#       (A+B+C)-X_number of d Electrons  A-B_Mulliken EN  A-C_Mulliken EN  \
# 0                                   0             3.17             1.73
# 1                                   0             3.17             1.28
# 2                                  10             1.54             2.79
# 3                                  10             1.54             0.40
# 4                                  15             1.54             2.30
# ...                               ...              ...              ...
# 9081                               10             3.19             1.72
# 9082                               10             3.35             1.72
# 9083                               10             3.19             1.72
# 9084                               10             3.19             1.72
# 9085                               10             3.19             1.72
#
#       (A+B+C)-X_Mulliken EN
# 0                     49.30
# 1                     46.29
# 2                     48.73
# 3                     46.34
# 4                     48.24
# ...                     ...
# 9081                  48.77
# 9082                  48.93
# 9083                  48.77
# 9084                  48.77
# 9085                  48.77
#
# [9086 rows x 86 columns]

# %%
screen2 = pd.read_csv('./data/screen_bandgap1.csv')

# %%
screen2 = pd.merge(screen2, data, on=['formula','number'], how='left')
screen2
# Out:
#         formula  number  band_gap  A_Density  B_Density  C_Density  X_Density  \
# 0    Rb2NaMoBr6       1  1.475700       3.06      0.971      10.20      18.72
# 1    Rb2NaIrBr6       1  1.404644       3.06      0.971      22.60      18.72
# 2     Rb2KIrBr6       1  1.409481       3.06      0.862      22.60      18.72
# 3    Rb2AgTiBr6       1  1.129527       3.06     10.500       4.54      18.72
# 4    Rb2AgMoBr6       1  0.647062       3.06     10.500      10.20      18.72
# ..          ...     ...       ...        ...        ...        ...        ...
# 158   Tl2CaVBr6       2  1.160604      23.80      1.540       6.11      18.72
# 159  Tl2CaCrBr6       2  1.166823      23.80      1.540       7.15      18.72
# 160  Tl2CaGeBr6       2  0.936388      23.80      1.540       5.32      18.72
# 161  Tl2CaNbBr6       2  1.161236      23.80      1.540       8.57      18.72
# 162  Tl2CaTmBr6       2  1.411247      23.80      1.540       9.32      18.72
#
#      A_dipole Polarizability  B_dipole Polarizability  \
# 0                      639.6                    162.7
# 1                      639.6                    162.7
# 2                      639.6                    289.7
# 3                      639.6                     55.0
# 4                      639.6                     55.0
# ..                       ...                      ...
# 158                    100.0                    160.8
# 159                    100.0                    160.8
# 160                    100.0                    160.8
# 161                    100.0                    160.8
# 162                    100.0                    160.8
#
#      C_dipole Polarizability  X_dipole Polarizability  A_covalent Radius  \
# 0                       87.0                    126.0                420
# 1                       54.0                    126.0                420
# 2                       54.0                    126.0                420
# 3                      100.0                    126.0                420
# 4                       87.0                    126.0                420
# ..                       ...                      ...                ...
# 158                     87.0                    126.0                288
# 159                     83.0                    126.0                288
# 160                     40.0                    126.0                288
# 161                     98.0                    126.0                288
# 162                    144.0                    126.0                288
#
#      B_covalent Radius  C_covalent Radius  X_covalent Radius  A_atomic Radius  \
# 0                  155                138                684              4.7
# 1                  155                122                684              4.7
# 2                  196                122                684              4.7
# 3                  128                136                684              4.7
# 4                  128                138                684              4.7
# ..                 ...                ...                ...              ...
# 158                171                134                684              3.8
# 159                171                122                684              3.8
# 160                171                121                684              3.8
# 161                171                147                684              3.8
# 162                171                164                684              3.8
#
#      B_atomic Radius  C_atomic Radius  X_atomic Radius  A_FirstIonization  \
# 0                1.8             1.45              6.9              806.0
# 1                1.8             1.35              6.9              806.0
# 2                2.2             1.35              6.9              806.0
# 3                1.6             1.40              6.9              806.0
# 4                1.6             1.45              6.9              806.0
# ..               ...              ...              ...                ...
# 158              1.8             1.35              6.9             1178.8
# 159              1.8             1.40              6.9             1178.8
# 160              1.8             1.25              6.9             1178.8
# 161              1.8             1.45              6.9             1178.8
# 162              1.8             1.75              6.9             1178.8
#
#      B_FirstIonization  C_FirstIonization  X_FirstIonization  \
# 0                495.8              684.3             6839.4
# 1                495.8              880.0             6839.4
# 2                418.8              880.0             6839.4
# 3                731.0              658.8             6839.4
# 4                731.0              684.3             6839.4
# ..                 ...                ...                ...
# 158              589.8              650.9             6839.4
# 159              589.8              652.9             6839.4
# 160              589.8              762.0             6839.4
# 161              589.8              652.1             6839.4
# 162              589.8              596.7             6839.4
#
#      A_number of Valence Electrons  B_number of Valence Electrons  \
# 0                                2                              1
# 1                                2                              1
# 2                                2                              1
# 3                                2                             11
# 4                                2                             11
# ..                             ...                            ...
# 158                              6                              2
# 159                              6                              2
# 160                              6                              2
# 161                              6                              2
# 162                              6                              2
#
#      C_number of Valence Electrons  X_number of Valence Electrons  A_number  \
# 0                                6                             42        74
# 1                                9                             42        74
# 2                                9                             42        74
# 3                                4                             42        74
# 4                                6                             42        74
# ..                             ...                            ...       ...
# 158                              5                             42       162
# 159                              6                             42       162
# 160                              4                             42       162
# 161                              5                             42       162
# 162                              3                             42       162
#
#      B_number  C_number  ...  A-B_covalent Radius  A-C_covalent Radius  \
# 0          11        42  ...                  265                  282
# 1          11        77  ...                  265                  298
# 2          19        77  ...                  224                  298
# 3          47        22  ...                  292                  284
# 4          47        42  ...                  292                  282
# ..        ...       ...  ...                  ...                  ...
# 158        20        23  ...                  117                  154
# 159        20        24  ...                  117                  166
# 160        20        32  ...                  117                  167
# 161        20        41  ...                  117                  141
# 162        20        69  ...                  117                  124
#
#      (A+B+C)-X_covalent Radius  A-B_atomic Radius  A-C_atomic Radius  \
# 0                           29                2.9               3.25
# 1                           13                2.9               3.35
# 2                           54                2.5               3.35
# 3                            0                3.1               3.30
# 4                            2                3.1               3.25
# ..                         ...                ...                ...
# 158                         91                2.0               2.45
# 159                        103                2.0               2.40
# 160                        104                2.0               2.55
# 161                         78                2.0               2.35
# 162                         61                2.0               2.05
#
#      (A+B+C)-X_atomic Radius  A-B_FirstIonization  A-C_FirstIonization  \
# 0                       1.05                310.2                121.7
# 1                       0.95                310.2                 74.0
# 2                       1.35                387.2                 74.0
# 3                       0.80                 75.0                147.2
# 4                       0.85                 75.0                121.7
# ..                       ...                  ...                  ...
# 158                     0.05                589.0                527.9
# 159                     0.10                589.0                525.9
# 160                     0.05                589.0                416.8
# 161                     0.15                589.0                526.7
# 162                     0.45                589.0                582.1
#
#      (A+B+C)-X_FirstIonization  A-B_number of Valence Electrons  \
# 0                       4853.3                                1
# 1                       4657.6                                1
# 2                       4734.6                                1
# 3                       4643.6                                9
# 4                       4618.1                                9
# ..                         ...                              ...
# 158                     4419.9                                4
# 159                     4417.9                                4
# 160                     4308.8                                4
# 161                     4418.7                                4
# 162                     4474.1                                4
#
#      A-C_number of Valence Electrons  (A+B+C)-X_number of Valence Electrons  \
# 0                                  4                                     33
# 1                                  7                                     30
# 2                                  7                                     30
# 3                                  2                                     25
# 4                                  4                                     23
# ..                               ...                                    ...
# 158                                1                                     29
# 159                                0                                     28
# 160                                2                                     30
# 161                                1                                     29
# 162                                3                                     31
#
#      A-B_number  A-C_number  (A+B+C)-X_number  A-B_Period  A-C_Period  \
# 0            63          32                83           7           5
# 1            63           3                48           7           4
# 2            55           3                40           6           4
# 3            27          52                67           5           6
# 4            27          32                47           5           5
# ..          ...         ...               ...         ...         ...
# 158         142         139                 5           8           8
# 159         142         138                 4           8           8
# 160         142         130                 4           8           8
# 161         142         121                13           8           7
# 162         142          93                41           8           6
#
#      (A+B+C)-X_Period  A-B_Electronegativity  A-C_Electronegativity  \
# 0                   6                   0.71                   0.52
# 1                   5                   0.71                   0.56
# 2                   4                   0.82                   0.56
# 3                   5                   0.29                   0.10
# 4                   4                   0.29                   0.52
# ..                ...                    ...                    ...
# 158                 4                   3.08                   2.45
# 159                 4                   3.08                   2.42
# 160                 4                   3.08                   2.07
# 161                 3                   3.08                   2.48
# 162                 2                   3.08                   2.83
#
#      (A+B+C)-X_Electronegativity  A-B_number of s+p Electrons  \
# 0                          13.03                            1
# 1                          12.99                            1
# 2                          13.10                            1
# 3                          12.65                            1
# 4                          12.03                            1
# ..                           ...                          ...
# 158                        11.05                            4
# 159                        11.02                            4
# 160                        10.67                            4
# 161                        11.08                            4
# 162                        11.43                            4
#
#      A-C_number of s+p Electrons  (A+B+C)-X_number of s+p Electrons  \
# 0                              1                                 38
# 1                              0                                 37
# 2                              0                                 37
# 3                              0                                 37
# 4                              1                                 38
# ..                           ...                                ...
# 158                            4                                 32
# 159                            5                                 33
# 160                            2                                 30
# 161                            5                                 33
# 162                            4                                 32
#
#      A-B_number of d Electrons  A-C_number of d Electrons  \
# 0                            0                          5
# 1                            0                          7
# 2                            0                          7
# 3                           10                          2
# 4                           10                          5
# ..                         ...                        ...
# 158                         20                         17
# 159                         20                         15
# 160                         20                         20
# 161                         20                         16
# 162                         20                         20
#
#      (A+B+C)-X_number of d Electrons  A-B_Mulliken EN  A-C_Mulliken EN  \
# 0                                  5             1.83             0.78
# 1                                  7             1.83             0.72
# 2                                  7             2.26             0.72
# 3                                 12             0.24             1.23
# 4                                 15             0.24             0.78
# ..                               ...              ...              ...
# 158                               23             4.20             2.80
# 159                               25             4.20             2.68
# 160                               20             4.20             1.80
# 161                               24             4.20             2.40
# 162                               20             4.20             3.30
#
#      (A+B+C)-X_Mulliken EN
# 0                    34.11
# 1                    32.61
# 2                    33.04
# 3                    32.97
# 4                    32.52
# ..                     ...
# 158                  33.34
# 159                  33.22
# 160                  32.34
# 161                  32.94
# 162                  33.84
#
# [163 rows x 87 columns]

# %%
features_xgb =  ['B_Density', 'C_dipole Polarizability', 'C_atomic Radius', 'C_number', 'A_number of s+p Electrons', 'C_number of s+p Electrons',
               'A-C_Density', '(A+B+C)-X_dipole Polarizability', '(A+B+C)-X_atomic Radius', '(A+B+C)-X_number of Valence Electrons',
               'A-C_number', 'A-B_Period', 'A-C_Electronegativity', 'A-C_number of s+p Electrons', 'A-C_number of d Electrons', '(A+B+C)-X_number of d Electrons', 'A-C_Mulliken EN']

# %%
X2 = screen2[features_xgb]
X2.columns
# Out:
# Index(['B_Density', 'C_dipole Polarizability', 'C_atomic Radius', 'C_number',
#        'A_number of s+p Electrons', 'C_number of s+p Electrons', 'A-C_Density',
#        '(A+B+C)-X_dipole Polarizability', '(A+B+C)-X_atomic Radius',
#        '(A+B+C)-X_number of Valence Electrons', 'A-C_number', 'A-B_Period',
#        'A-C_Electronegativity', 'A-C_number of s+p Electrons',
#        'A-C_number of d Electrons', '(A+B+C)-X_number of d Electrons',
#        'A-C_Mulliken EN'],
#       dtype='object')

# %%
from joblib import load
eh_xgb = load('./model/eh_xgb.joblib')

# %%
eh3 = pd.DataFrame(columns=['formula','number'])
eh3['formula'] = screen2['formula']
eh3['number'] = screen2['number']

# %%
# %%time
# 使用所有模型进行集成预测
y_pred_ensemble = np.array([model.predict(X2) for model in eh_xgb]).T
eh3['eh'] = np.apply_along_axis(lambda x: np.argmax(np.bincount(x)), axis=1, arr=y_pred_ensemble)
# Out:
# CPU times: user 25.2 s, sys: 9.73 ms, total: 25.2 s
# Wall time: 267 ms

# %%
#!!!!!!!!!!
screen_pbe3 = eh3.loc[eh3['eh']==1, ['formula', 'number']]

# %%
screen_pbe3.to_csv('./data/final.csv')
