# %%
import pandas as pd
import numpy as np
# No warnings about setting value on copy of slice
pd.options.mode.chained_assignment = None

# Display up to 60 columns of a dataframe
pd.set_option('display.max_columns', 60)

# Matplotlib visualization
import matplotlib.pyplot as plt
from matplotlib import rcParams
# %matplotlib inline

# Internal ipython tool for setting figure size
from IPython.core.pylabtools import figsize

# Seaborn for visualization
import seaborn as sns

import warnings

warnings.filterwarnings('ignore')

config = {
    "mathtext.fontset": 'stix',
    "font.family":'DejaVu Sans',
    "font.family": 'serif',
    "font.serif": ['Arial'],
    "font.size": 24,
    'axes.unicode_minus': False
}
rcParams.update(config)
plt.rcParams['axes.unicode_minus'] = False
large = 22
med = 16
small = 12
params = {
    'axes.titlesize': large,
    'legend.fontsize': med,
    'figure.figsize': (8, 6),
    'axes.labelsize': med,
    'axes.titlesize': med,
    'xtick.labelsize': med,
    'ytick.labelsize': med,
    'figure.titlesize': large
}
plt.rcParams.update(params)
plt.rcParams['figure.dpi'] = 300
seed = 42

# %%
dp = pd.read_csv('./data/db_cn.csv').reset_index(drop=True)
dp
# Out:
#      material_id formula_pretty  formation_energy_per_atom  energy_above_hull  \
# 0     mp-1113578     Cs2AgAsBr6                  -1.374468           0.000000
# 1     mp-1113543     Cs2AgAsCl6                  -1.562978           0.008312
# 2     mp-1114305      Cs2AgAsF6                  -2.436756           0.055656
# 3     mp-1113575     Cs2AgAuBr6                  -1.255402           0.024743
# 4      mp-568448     Cs2AgAuCl6                  -1.395263           0.054055
# ...          ...            ...                        ...                ...
# 1286  mp-1114193       Rb2YHgI6                  -1.377484           0.104343
# 1287  mp-1114129      Rb2YInBr6                  -1.954103           0.016794
# 1288  mp-1114045      Rb2YInCl6                  -2.216514           0.041253
# 1289  mp-1113931       Rb2YInF6                  -3.290900           0.045683
# 1290  mp-1114186       Rb2YInI6                  -1.480278           0.043320
#
#       is_gap_direct  band_gap  spacegroup_number  \
# 0             False    1.1161                225
# 1             False    1.5886                225
# 2             False    2.4428                225
# 3             False    0.0000                225
# 4             False    0.0000                225
# ...             ...       ...                ...
# 1286          False    0.0000                225
# 1287           True    2.8332                225
# 1288          False    3.3242                225
# 1289          False    3.6730                225
# 1290           True    2.6542                225
#
#                                               structure     formula  \
# 0     Full Formula (Cs2 Ag1 As1 Br6)\nReduced Formul...  Cs2AgAsBr6
# 1     Full Formula (Cs2 Ag1 As1 Cl6)\nReduced Formul...  Cs2AgAsCl6
# 2     Full Formula (Cs2 Ag1 As1 F6)\nReduced Formula...   Cs2AgAsF6
# 3     Full Formula (Cs2 Ag1 Au1 Br6)\nReduced Formul...  Cs2AgAuBr6
# 4     Full Formula (Cs2 Ag1 Au1 Cl6)\nReduced Formul...  Cs2AgAuCl6
# ...                                                 ...         ...
# 1286  Full Formula (Rb2 Y1 Hg1 I6)\nReduced Formula:...    Rb2YHgI6
# 1287  Full Formula (Rb2 Y1 In1 Br6)\nReduced Formula...   Rb2YInBr6
# 1288  Full Formula (Rb2 Y1 In1 Cl6)\nReduced Formula...   Rb2YInCl6
# 1289  Full Formula (Rb2 Y1 In1 F6)\nReduced Formula:...    Rb2YInF6
# 1290  Full Formula (Rb2 Y1 In1 I6)\nReduced Formula:...    Rb2YInI6
#
#           composition  is_GGA_U
# 0     Cs2 Ag1 As1 Br6         0
# 1     Cs2 Ag1 As1 Cl6         0
# 2      Cs2 Ag1 As1 F6         0
# 3     Cs2 Ag1 Au1 Br6         0
# 4     Cs2 Ag1 Au1 Cl6         0
# ...               ...       ...
# 1286    Rb2 Y1 Hg1 I6         0
# 1287   Rb2 Y1 In1 Br6         0
# 1288   Rb2 Y1 In1 Cl6         0
# 1289    Rb2 Y1 In1 F6         0
# 1290    Rb2 Y1 In1 I6         0
#
# [1291 rows x 11 columns]

# %%
counts = dp['is_gap_direct'].value_counts()
counts
# Out:
# is_gap_direct
# False    837
# True     454
# Name: count, dtype: int64

# %%
dp['is_gap_direct'] = dp['is_gap_direct'].replace({True: 1, False: 0})

# %%
import pandas as pd
import matplotlib.pyplot as plt

y_counts = dp['is_gap_direct'].value_counts()
y_counts.plot(kind='bar', color=['#31A09A', '#D58686'],edgecolor='black')
plt.ylabel('Number', fontsize=22)
plt.xticks(ticks=[0, 1], labels=['Indirect', 'Direct'], rotation=0, fontsize=22)

ax = plt.gca() 
ax.spines['top'].set_linewidth(1.5)
ax.spines['bottom'].set_linewidth(1.5)
ax.spines['left'].set_linewidth(1.5)
ax.spines['right'].set_linewidth(1.5)
ax.tick_params(axis='both', which='major', labelsize=20)
ax.set_xlabel('') 
plt.savefig('./picture/bg_distribution.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Feature Engineering

# %%
X = pd.read_csv('./data/features_cn.csv').reset_index(drop=True)
X
# Out:
#       A_Density  B_Density  C_Density  X_Density  A_dipole Polarizability  \
# 0          3.74      10.50       5.78   18.72000                    801.8
# 1          3.74      10.50       5.78    0.01926                    801.8
# 2          3.74      10.50       5.78    0.01020                    801.8
# 3          3.74      10.50      19.30   18.72000                    801.8
# 4          3.74      10.50      19.30    0.01926                    801.8
# ...         ...        ...        ...        ...                      ...
# 1286       3.06       4.47      13.50   29.58000                    639.6
# 1287       3.06       4.47       7.31   18.72000                    639.6
# 1288       3.06       4.47       7.31    0.01926                    639.6
# 1289       3.06       4.47       7.31    0.01020                    639.6
# 1290       3.06       4.47       7.31   29.58000                    639.6
#
#       B_dipole Polarizability  C_dipole Polarizability  \
# 0                        55.0                    30.00
# 1                        55.0                    30.00
# 2                        55.0                    30.00
# 3                        55.0                    36.00
# 4                        55.0                    36.00
# ...                       ...                      ...
# 1286                    162.0                    33.91
# 1287                    162.0                    65.00
# 1288                    162.0                    65.00
# 1289                    162.0                    65.00
# 1290                    162.0                    65.00
#
#       X_dipole Polarizability  A_covalent Radius  B_covalent Radius  \
# 0                      126.00                464                128
# 1                       87.60                464                128
# 2                       22.44                464                128
# 3                      126.00                464                128
# 4                       87.60                464                128
# ...                       ...                ...                ...
# 1286                   197.40                420                163
# 1287                   126.00                420                163
# 1288                    87.60                420                163
# 1289                    22.44                420                163
# 1290                   197.40                420                163
#
#       C_covalent Radius  X_covalent Radius  A_atomic Radius  B_atomic Radius  \
# 0                   121                684              5.2              1.6
# 1                   121                594              5.2              1.6
# 2                   121                384              5.2              1.6
# 3                   124                684              5.2              1.6
# 4                   124                594              5.2              1.6
# ...                 ...                ...              ...              ...
# 1286                133                798              4.7              1.8
# 1287                142                684              4.7              1.8
# 1288                142                594              4.7              1.8
# 1289                142                384              4.7              1.8
# 1290                142                798              4.7              1.8
#
#       C_atomic Radius  X_atomic Radius  A_FirstIonization  B_FirstIonization  \
# 0                1.15              6.9              751.4              731.0
# 1                1.15              6.0              751.4              731.0
# 2                1.15              3.0              751.4              731.0
# 3                1.35              6.9              751.4              731.0
# 4                1.35              6.0              751.4              731.0
# ...               ...              ...                ...                ...
# 1286             1.50              8.4              806.0              600.0
# 1287             1.55              6.9              806.0              600.0
# 1288             1.55              6.0              806.0              600.0
# 1289             1.55              3.0              806.0              600.0
# 1290             1.55              8.4              806.0              600.0
#
#       C_FirstIonization  X_FirstIonization  A_number of Valence Electrons  \
# 0                 947.0             6839.4                              2
# 1                 947.0             7507.2                              2
# 2                 947.0            10086.0                              2
# 3                 890.1             6839.4                              2
# 4                 890.1             7507.2                              2
# ...                 ...                ...                            ...
# 1286             1007.1             6050.4                              2
# 1287              558.3             6839.4                              2
# 1288              558.3             7507.2                              2
# 1289              558.3            10086.0                              2
# 1290              558.3             6050.4                              2
#
#       B_number of Valence Electrons  C_number of Valence Electrons  \
# 0                                11                              5
# 1                                11                              5
# 2                                11                              5
# 3                                11                             11
# 4                                11                             11
# ...                             ...                            ...
# 1286                              3                             12
# 1287                              3                              3
# 1288                              3                              3
# 1289                              3                              3
# 1290                              3                              3
#
#       X_number of Valence Electrons  A_number  B_number  C_number  X_number  \
# 0                                42       110        47        33       210
# 1                                42       110        47        33       102
# 2                                42       110        47        33        54
# 3                                42       110        47        79       210
# 4                                42       110        47        79       102
# ...                             ...       ...       ...       ...       ...
# 1286                             42        74        39        80       318
# 1287                             42        74        39        49       210
# 1288                             42        74        39        49       102
# 1289                             42        74        39        49        54
# 1290                             42        74        39        49       318
#
#       A_Period  B_Period  ...  A-B_covalent Radius  A-C_covalent Radius  \
# 0           12         5  ...                  336                  343
# 1           12         5  ...                  336                  343
# 2           12         5  ...                  336                  343
# 3           12         5  ...                  336                  340
# 4           12         5  ...                  336                  340
# ...        ...       ...  ...                  ...                  ...
# 1286        10         5  ...                  257                  287
# 1287        10         5  ...                  257                  278
# 1288        10         5  ...                  257                  278
# 1289        10         5  ...                  257                  278
# 1290        10         5  ...                  257                  278
#
#       (A+B+C)-X_covalent Radius  A-B_atomic Radius  A-C_atomic Radius  \
# 0                            29                3.6               4.05
# 1                           119                3.6               4.05
# 2                           329                3.6               4.05
# 3                            32                3.6               3.85
# 4                           122                3.6               3.85
# ...                         ...                ...                ...
# 1286                         82                2.9               3.20
# 1287                         41                2.9               3.15
# 1288                        131                2.9               3.15
# 1289                        341                2.9               3.15
# 1290                         73                2.9               3.15
#
#       (A+B+C)-X_atomic Radius  A-B_FirstIonization  A-C_FirstIonization  \
# 0                        1.05                 20.4                195.6
# 1                        1.95                 20.4                195.6
# 2                        4.95                 20.4                195.6
# 3                        1.25                 20.4                138.7
# 4                        2.15                 20.4                138.7
# ...                       ...                  ...                  ...
# 1286                     0.40                206.0                201.1
# 1287                     1.15                206.0                247.7
# 1288                     2.05                206.0                247.7
# 1289                     5.05                206.0                247.7
# 1290                     0.35                206.0                247.7
#
#       (A+B+C)-X_FirstIonization  A-B_number of Valence Electrons  \
# 0                        4410.0                                9
# 1                        5077.8                                9
# 2                        7656.6                                9
# 3                        4466.9                                9
# 4                        5134.7                                9
# ...                         ...                              ...
# 1286                     3637.3                                1
# 1287                     4875.1                                1
# 1288                     5542.9                                1
# 1289                     8121.7                                1
# 1290                     4086.1                                1
#
#       A-C_number of Valence Electrons  (A+B+C)-X_number of Valence Electrons  \
# 0                                   3                                     24
# 1                                   3                                     24
# 2                                   3                                     24
# 3                                   9                                     18
# 4                                   9                                     18
# ...                               ...                                    ...
# 1286                               10                                     25
# 1287                                1                                     34
# 1288                                1                                     34
# 1289                                1                                     34
# 1290                                1                                     34
#
#       A-B_number  A-C_number  (A+B+C)-X_number  A-B_Period  A-C_Period  \
# 0             63          77                20           7           8
# 1             63          77                88           7           8
# 2             63          77               136           7           8
# 3             63          31                26           7           6
# 4             63          31               134           7           6
# ...          ...         ...               ...         ...         ...
# 1286          35           6               125           5           4
# 1287          35          25                48           5           5
# 1288          35          25                60           5           5
# 1289          35          25               108           5           5
# 1290          35          25               156           5           5
#
#       (A+B+C)-X_Period  A-B_Electronegativity  A-C_Electronegativity  \
# 0                    3                   0.35                   0.60
# 1                    3                   0.35                   0.60
# 2                    9                   0.35                   0.60
# 3                    1                   0.35                   0.96
# 4                    5                   0.35                   0.96
# ...                ...                    ...                    ...
# 1286                 9                   0.42                   0.36
# 1287                 4                   0.42                   0.14
# 1288                 2                   0.42                   0.14
# 1289                 8                   0.42                   0.14
# 1290                10                   0.42                   0.14
#
#       (A+B+C)-X_Electronegativity  A-B_number of s+p Electrons  \
# 0                           12.07                            1
# 1                           13.27                            1
# 2                           18.19                            1
# 3                           11.71                            1
# 4                           12.91                            1
# ...                           ...                          ...
# 1286                        11.10                            0
# 1287                        13.12                            0
# 1288                        14.32                            0
# 1289                        19.24                            0
# 1290                        11.32                            0
#
#       A-C_number of s+p Electrons  (A+B+C)-X_number of s+p Electrons  \
# 0                               3                                 34
# 1                               3                                 34
# 2                               3                                 34
# 3                               1                                 38
# 4                               1                                 38
# ...                           ...                                ...
# 1286                            0                                 36
# 1287                            1                                 35
# 1288                            1                                 35
# 1289                            1                                 35
# 1290                            1                                 35
#
#       A-B_number of d Electrons  A-C_number of d Electrons  \
# 0                            10                          0
# 1                            10                          0
# 2                            10                          0
# 3                            10                         10
# 4                            10                         10
# ...                         ...                        ...
# 1286                          1                         10
# 1287                          1                         10
# 1288                          1                         10
# 1289                          1                         10
# 1290                          1                         10
#
#       (A+B+C)-X_number of d Electrons  A-B_Mulliken EN  A-C_Mulliken EN  \
# 0                                  10             0.08             0.94
# 1                                  10             0.08             0.94
# 2                                  10             0.08             0.94
# 3                                  20             0.08             1.41
# 4                                  20             0.08             1.41
# ...                               ...              ...              ...
# 1286                               49             1.49             0.23
# 1287                               11             1.49             1.58
# 1288                               11             1.49             1.58
# 1289                               11             1.49             1.58
# 1290                               49             1.49             1.58
#
#       (A+B+C)-X_Mulliken EN
# 0                     31.44
# 1                     35.70
# 2                     48.36
# 3                     30.97
# 4                     35.23
# ...                     ...
# 1286                  27.78
# 1287                  34.57
# 1288                  38.83
# 1289                  51.49
# 1290                  29.59
#
# [1291 rows x 84 columns]

# %%
y = dp['is_gap_direct']

# %%
from scipy.stats import spearmanr
def remove_collinear_features(x, y,threshold):
    '''
    Objective:
        Remove collinear features in a dataframe with a correlation coefficient
        greater than the threshold. Removing collinear features can help a model
        to generalize and improves the interpretability of the model.
        
    Inputs: 
        threshold: any features with correlations greater than this value are removed
    
    Output: 
        dataframe that contains only the non-highly-collinear features
    '''  
    # Calculate the correlation matrix
    corr_matrix = x.corr()
    iters = range(len(corr_matrix.columns) - 1)
    drop_cols = []

    # Iterate through the correlation matrix and compare correlations
    for i in iters:
        for j in range(i):
            item = corr_matrix.iloc[j:(j+1), (i+1):(i+2)]
            col = item.columns
            row = item.index
            val = abs(item.values)
            
            # If correlation exceeds the threshold
            if val >= threshold:
                # Print the correlated features and the correlation value
#                 print(col.values[0], "|", row.values[0], "|", round(val[0][0], 2))
                x1 = x[col.values[0]]
                x2 = x[row.values[0]]
                corr1,p1 = spearmanr(x1, y)
                corr2,p2 = spearmanr(x2, y)
                if np.abs(corr1) < np.abs(corr2):
                    drop_cols.append(col.values[0])
                else:
                    drop_cols.append(row.values[0])
    # Drop one of each pair of correlated columns
    drops = set(drop_cols)
    x = x.drop(columns = drops)
    return x

# %%
from sklearn.model_selection import train_test_split
X = remove_collinear_features(X, y, 0.8)
#X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,shuffle=True,random_state=0)
print(X.shape)
# Out:
# (1291, 28)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

corr_matrix = X.corr()

# 画热力图
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, 
            annot=False,        # 显示数值
            cmap='coolwarm',   # 颜色
            fmt=".2f",
            square=True)
plt.savefig('./picture/feature2.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
X_columns = X.columns

# %% [markdown]
# ## Model Construction

# %%
from sklearn.metrics import roc_auc_score,accuracy_score,f1_score,matthews_corrcoef,classification_report,roc_curve, auc,precision_score,recall_score
from sklearn.model_selection import StratifiedKFold
def fold5(model, X, y,name='',is_plot=True):
    kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    accuracies = []
    f1s = []
    mccs = []
    roc_aucs = []
    roc_curves = []  
    recalls = []
    fig, ax = plt.subplots() 
    for i, (train_index, test_index) in enumerate(kf.split(X, y)):
        try:
            X = X.values
            y = y.values
        except:
            pass
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        y_prob = model.predict_proba(X_test)[:, 1]
        fpr, tpr, thresholds = roc_curve(y_test, y_prob)
        roc_auc = auc(fpr, tpr)
        if is_plot:
            roc_curve_obj, = ax.plot(fpr, tpr, label='Fold %d (area = %0.3f)' % (i + 1, roc_auc), lw=2,linestyle='-.',alpha=0.75)
            roc_curves.append(roc_curve_obj)  
            handles, labels = ax.get_legend_handles_labels()
            ax.legend(handles[:5], labels[:5], loc="lower right")

            ax.plot([0, 1], [0, 1], 'r--', lw=1, alpha=0.8)  
            ax.set_xlim([-0.025, 1.0])  
            ax.set_ylim([0.0, 1.05])  
            ax.set_xlabel('False Positive Rate')  
            ax.set_ylabel('True Positive Rate')  
            ax.set_title(f'ROC Curve: {name}') 
            ax.set_axisbelow(True)
            ax.grid(True, linestyle='--', linewidth=0.5, alpha=0.5)
        accuracies.append(accuracy_score(y_test, y_pred))
        f1s.append(f1_score(y_test, y_pred))
        mccs.append(matthews_corrcoef(y_test, y_pred))
        roc_aucs.append(roc_auc)
        report = classification_report(y_test, y_pred)
        recall = float(report.split()[11])
        recalls.append(recall)
        result = {
        'accuracy': np.mean(accuracies),
        'f1-score': np.mean(f1s),
        'mcc': np.mean(mccs),
        'roc_auc': np.mean(roc_aucs),
        'recall':np.mean(recalls),
        'accuracy_std': np.std(accuracies),
        'f1-score_std': np.std(f1s),
        'mcc_std': np.std(mccs),
        'roc_auc_std': np.std(roc_aucs),
        'recall_std':np.std(recalls),
    }
    if is_plot:
        # 坐标轴标题（加粗加大）
        ax.set_xlabel('False Positive Rate', fontsize=16, fontweight='bold')
        ax.set_ylabel('True Positive Rate', fontsize=16, fontweight='bold')

        # 标题加粗加大
        #ax.set_title(f'ROC Curve: {name}', fontsize=18, fontweight='bold')

        # 坐标刻度加粗加大
        ax.tick_params(axis='both', labelsize=16)
        for label in ax.get_xticklabels() + ax.get_yticklabels():
            label.set_fontweight('bold')

        # 图例加粗加大（右下角）
        legend = ax.legend(loc="lower right",
                           fontsize=18,
                           frameon=True)

        for text in legend.get_texts():
            text.set_fontweight('bold')

        ax.grid(True, linestyle='--', linewidth=0.7, alpha=0.6)
        plt.savefig('./picture/bg_xgb.png', dpi=300, bbox_inches='tight')
        plt.show()
    return result

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from lightgbm import LGBMClassifier 
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.naive_bayes import GaussianNB
seed =42
kn = KNeighborsClassifier()
dt = DecisionTreeClassifier(random_state=seed)
rf = RandomForestClassifier(n_jobs=-1,random_state=seed)
mlp = MLPClassifier(alpha=1, max_iter=1000,random_state=seed)
lgbm = LGBMClassifier(random_state=seed,verbose=0)
xb = XGBClassifier(random_state=seed,n_jobs=-1)
ext = ExtraTreesClassifier(n_jobs=-1,random_state=seed) 
gbc = GradientBoostingClassifier(random_state=seed)
gnb = GaussianNB()

# %%
fold5(dt,X,y)
# Out:
# {'accuracy': 0.9008560055071682,
#  'f1-score': 0.8585820609394956,
#  'mcc': 0.7826460384904622,
#  'roc_auc': 0.8908088036381449,
#  'recall': 0.858,
#  'accuracy_std': 0.010242654473334814,
#  'f1-score_std': 0.015639628275855137,
#  'mcc_std': 0.02295348700106652,
#  'roc_auc_std': 0.013565086551840742,
#  'recall_std': 0.029257477676655576}

# %%
fold5(rf,X,y)
# Out:
# {'accuracy': 0.9264254287510101,
#  'f1-score': 0.8935460691094865,
#  'mcc': 0.8379197060856326,
#  'roc_auc': 0.9669949030075206,
#  'recall': 0.8800000000000001,
#  'accuracy_std': 0.015041145427366974,
#  'f1-score_std': 0.021979030673771986,
#  'mcc_std': 0.033056822318482615,
#  'roc_auc_std': 0.012200304280384147,
#  'recall_std': 0.026076809620810618}

# %%
fold5(kn,X,y)
# Out:
# {'accuracy': 0.7660680614168986,
#  'f1-score': 0.633715089941505,
#  'mcc': 0.47060632982399875,
#  'roc_auc': 0.7702310941521805,
#  'recall': 0.578,
#  'accuracy_std': 0.013854011450854666,
#  'f1-score_std': 0.03668063078350408,
#  'mcc_std': 0.03669538510807167,
#  'roc_auc_std': 0.020371147426736652,
#  'recall_std': 0.06013318551349164}

# %%
fold5(mlp,X,y)
# Out:
# {'accuracy': 0.7622010715033971,
#  'f1-score': 0.6441523428032654,
#  'mcc': 0.49583095510727515,
#  'roc_auc': 0.8310683133993656,
#  'recall': 0.6719999999999999,
#  'accuracy_std': 0.020137036116026318,
#  'f1-score_std': 0.10854316572437306,
#  'mcc_std': 0.07927435130846779,
#  'roc_auc_std': 0.019569182420413493,
#  'recall_std': 0.2188515478583599}

# %%
fold5(lgbm,X,y)
# Out:
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# {'accuracy': 0.9279758163479093,
#  'f1-score': 0.8953886028604201,
#  'mcc': 0.8415553754576667,
#  'roc_auc': 0.9724487019333041,
#  'recall': 0.8779999999999999,
#  'accuracy_std': 0.014751598004265839,
#  'f1-score_std': 0.021058165109312656,
#  'mcc_std': 0.03200913917484332,
#  'roc_auc_std': 0.009271865241826395,
#  'recall_std': 0.027129319932501096}

# %%
fold5(xb,X,y)
# Out:
# {'accuracy': 0.9318428062614108,
#  'f1-score': 0.9005809776885039,
#  'mcc': 0.8497788443039266,
#  'roc_auc': 0.9721484512224461,
#  'recall': 0.8799999999999999,
#  'accuracy_std': 0.013519756988997152,
#  'f1-score_std': 0.020035352350473275,
#  'mcc_std': 0.029794085365138705,
#  'roc_auc_std': 0.008214676736477513,
#  'recall_std': 0.027568097504180468}

# %%
fold5(ext,X,y)
# Out:
# {'accuracy': 0.9279638442429141,
#  'f1-score': 0.8970038703021153,
#  'mcc': 0.8421959503944196,
#  'roc_auc': 0.9731013304805007,
#  'recall': 0.8940000000000001,
#  'accuracy_std': 0.008692134714197343,
#  'f1-score_std': 0.014188016683231646,
#  'mcc_std': 0.019657288565087104,
#  'roc_auc_std': 0.007059189379028912,
#  'recall_std': 0.029393876913398165}

# %%
fold5(gbc,X,y)
# Out:
# {'accuracy': 0.9271976295232107,
#  'f1-score': 0.8923934157255902,
#  'mcc': 0.8389354450242479,
#  'roc_auc': 0.9567781087049692,
#  'recall': 0.86,
#  'accuracy_std': 0.021806391888336028,
#  'f1-score_std': 0.032840592254219605,
#  'mcc_std': 0.04853219515359866,
#  'roc_auc_std': 0.019818871377774265,
#  'recall_std': 0.039496835316263}

# %%
df1 = pd.concat([X,y],axis=1)

# %%
from joblib import Parallel, delayed
from time import time
import numpy as np
import math
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
from lightgbm import LGBMClassifier
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import StratifiedKFold

# %%
from joblib import Parallel, delayed
from time import time
import numpy as np
import math
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
from lightgbm import LGBMClassifier
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import StratifiedKFold

def init_population(n, c):
    return np.array([[math.ceil(e) for e in pop] for pop in (np.random.rand(n, c) - 0.5)]), np.zeros((2, c)) - 1

def single_point_crossover(population):
    r, c = population.shape
    n = np.random.randint(1, c)         
    for i in range(0, r, 2):                
        population[i], population[i+1] = np.append(population[i][0:n], population[i+1][n:c]), np.append(population[i+1][0:n], population[i][n:c])        
    return population

def flip_mutation(population):
    return population.max() - population

def random_selection(population):
    r = population.shape[0]
    new_population = population.copy()    
    for i in range(r):        
        new_population[i] = population[np.random.randint(0, r)]
    return new_population

def predictive_model_cv(X, y, model, selected_features):
    kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    scores = []
    # 5-fold CV
    for train_index, test_index in kf.split(X, y):
        X_train, X_test = X.iloc[train_index][selected_features], X.iloc[test_index][selected_features]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
        
        mdl = model
        mdl.fit(X_train, y_train)
        y_pred = mdl.predict(X_test)
        score = accuracy_score(y_test, y_pred)
        scores.append(score)

    return np.mean(scores)

def individual_fitness_cv(individual, data, feature_list, target, model):

    selected_features = [feature_list[j] for j in range(individual.shape[0]) if individual[j] == 1]
    return predictive_model_cv(data[selected_features], data[target], model, selected_features)

def get_fitness_cv(data, feature_list, target, population, model):
    fitness = Parallel(n_jobs=-1)(delayed(individual_fitness_cv)(individual, data, feature_list, target, model) for individual in population)
    return np.array(fitness)

def memorize(pop, memory):      
    return np.append(memory, pop.reshape(1, memory.shape[1]), axis=0)

def replace_duplicate(population, memory):    
    for i in range(population.shape[0]):         
        counter = 0                
        while any(np.all(memory == population[i], axis=1)) and (counter < 100): 
            population[i] = np.array([math.ceil(k) for k in (np.random.rand(population.shape[1]) - 0.5)])                    
            counter += 1                    
        memory = memorize(population[i], memory)   
    return population, memory

def ga(data, feature_list, target, n, max_iter, model):
    c = len(feature_list)
    population, memory = init_population(n, c)
    population, memory = replace_duplicate(population, memory)
    
    fitness = get_fitness_cv(data, feature_list, target, population, model)
    optimal_value = max(fitness)
    optimal_solution = population[np.where(fitness == optimal_value)][0]
    
    for i in range(max_iter): 
        start = time()
        population = random_selection(population)
        population = single_point_crossover(population)
        if np.random.rand() < 0.3:
            population = flip_mutation(population)
        
        population, memory = replace_duplicate(population, memory)
        fitness = get_fitness_cv(data, feature_list, target, population, model)
        
        if max(fitness) > optimal_value:
            optimal_value = max(fitness)
            optimal_solution = population[np.where(fitness == optimal_value)][0]
        end = time()
        print(f"The {i+1}th iteration T = {end - start:.4f}second")
    return optimal_solution, optimal_value

# %%
model = XGBClassifier(n_jobs=-1, random_state=42)
target = 'is_gap_direct'
feature_list = [i for i in df1.columns if i not in target]
# execute genetic algorithms to obtain important features.
from time import time
start = time()
feature_set, optimize_accuracy = ga(df1, feature_list, target, 10, 1000, model)
end = time()
print(f"operating time T = %0.4f" % (end - start))

feature_set = [feature_list[i] for i in range(len(feature_list)) if feature_set[i] == 1]
print('Optimal Feature Set\n', feature_set, '\nOptimal Accuracy =', round(optimize_accuracy * 100), '%')
# Out:
# The 1th iteration T = 1.0134second
# The 2th iteration T = 0.9739second
# The 3th iteration T = 1.0030second
# The 4th iteration T = 0.9318second
# The 5th iteration T = 0.9151second
# The 6th iteration T = 0.9532second
# The 7th iteration T = 1.0157second
# The 8th iteration T = 0.9958second
# The 9th iteration T = 0.9339second
# The 10th iteration T = 0.8667second
# The 11th iteration T = 0.4647second
# The 12th iteration T = 0.4292second
# The 13th iteration T = 0.4723second
# The 14th iteration T = 0.4754second
# The 15th iteration T = 0.5065second
# The 16th iteration T = 0.4428second
# The 17th iteration T = 0.4693second
# The 18th iteration T = 0.4744second
# The 19th iteration T = 0.5377second
# The 20th iteration T = 0.4834second
# The 21th iteration T = 0.4938second
# The 22th iteration T = 0.4849second
# The 23th iteration T = 0.5124second
# The 24th iteration T = 0.4946second
# The 25th iteration T = 0.4985second
# The 26th iteration T = 0.4527second
# The 27th iteration T = 0.4932second
# The 28th iteration T = 0.5118second
# The 29th iteration T = 0.4828second
# The 30th iteration T = 0.4637second
# The 31th iteration T = 0.4943second
# The 32th iteration T = 0.5153second
# The 33th iteration T = 0.4851second
# The 34th iteration T = 0.4955second
# The 35th iteration T = 0.5177second
# The 36th iteration T = 0.5030second
# The 37th iteration T = 0.4803second
# The 38th iteration T = 0.4940second
# The 39th iteration T = 0.5058second
# The 40th iteration T = 0.4961second
# The 41th iteration T = 0.4938second
# The 42th iteration T = 0.4746second
# The 43th iteration T = 0.5013second
# The 44th iteration T = 0.4165second
# The 45th iteration T = 0.5031second
# The 46th iteration T = 0.4943second
# The 47th iteration T = 0.5067second
# The 48th iteration T = 0.4750second
# The 49th iteration T = 0.4859second
# The 50th iteration T = 0.5058second
# The 51th iteration T = 0.4543second
# The 52th iteration T = 0.4944second
# The 53th iteration T = 0.5039second
# The 54th iteration T = 0.5216second
# The 55th iteration T = 0.4909second
# The 56th iteration T = 0.5154second
# The 57th iteration T = 0.4618second
# The 58th iteration T = 0.4714second
# The 59th iteration T = 0.4795second
# The 60th iteration T = 0.4626second
# The 61th iteration T = 0.4904second
# The 62th iteration T = 0.4558second
# The 63th iteration T = 0.4643second
# The 64th iteration T = 0.4860second
# The 65th iteration T = 0.4929second
# The 66th iteration T = 0.4689second
# The 67th iteration T = 0.4770second
# The 68th iteration T = 0.4747second
# The 69th iteration T = 0.4756second
# The 70th iteration T = 0.4853second
# The 71th iteration T = 0.4989second
# The 72th iteration T = 0.4638second
# The 73th iteration T = 0.5163second
# The 74th iteration T = 0.4744second
# The 75th iteration T = 0.4958second
# The 76th iteration T = 0.4603second
# The 77th iteration T = 0.5007second
# The 78th iteration T = 0.4751second
# The 79th iteration T = 0.4794second
# The 80th iteration T = 0.4964second
# The 81th iteration T = 0.4752second
# The 82th iteration T = 0.4662second
# The 83th iteration T = 0.4740second
# The 84th iteration T = 0.4345second
# The 85th iteration T = 0.4756second
# The 86th iteration T = 0.5111second
# The 87th iteration T = 0.4649second
# The 88th iteration T = 0.4939second
# The 89th iteration T = 0.4577second
# The 90th iteration T = 0.5153second
# The 91th iteration T = 0.4862second
# The 92th iteration T = 0.5250second
# The 93th iteration T = 0.5594second
# The 94th iteration T = 0.4740second
# The 95th iteration T = 0.4111second
# The 96th iteration T = 0.5327second
# The 97th iteration T = 0.4685second
# The 98th iteration T = 0.4819second
# The 99th iteration T = 0.4670second
# The 100th iteration T = 0.4931second
# The 101th iteration T = 0.4469second
# The 102th iteration T = 0.4752second
# The 103th iteration T = 0.4853second
# The 104th iteration T = 0.4566second
# The 105th iteration T = 0.4242second
# The 106th iteration T = 0.4921second
# The 107th iteration T = 0.4474second
# The 108th iteration T = 0.4833second
# The 109th iteration T = 0.4655second
# The 110th iteration T = 0.5195second
# The 111th iteration T = 0.4686second
# The 112th iteration T = 0.4653second
# The 113th iteration T = 0.5086second
# The 114th iteration T = 0.4934second
# The 115th iteration T = 0.5306second
# The 116th iteration T = 0.4567second
# The 117th iteration T = 0.4699second
# The 118th iteration T = 0.4712second
# The 119th iteration T = 0.4508second
# The 120th iteration T = 0.4379second
# The 121th iteration T = 0.4595second
# The 122th iteration T = 0.4758second
# The 123th iteration T = 0.4692second
# The 124th iteration T = 0.4699second
# The 125th iteration T = 0.5144second
# The 126th iteration T = 0.4531second
# The 127th iteration T = 0.4573second
# The 128th iteration T = 0.5141second
# The 129th iteration T = 0.4659second
# The 130th iteration T = 0.5398second
# The 131th iteration T = 0.5016second
# The 132th iteration T = 0.4829second
# The 133th iteration T = 0.4566second
# The 134th iteration T = 0.4772second
# The 135th iteration T = 0.4042second
# The 136th iteration T = 0.4501second
# The 137th iteration T = 0.4410second
# The 138th iteration T = 0.4696second
# The 139th iteration T = 0.4632second
# The 140th iteration T = 0.4627second
# The 141th iteration T = 0.4826second
# The 142th iteration T = 0.5278second
# The 143th iteration T = 0.4888second
# The 144th iteration T = 0.4568second
# The 145th iteration T = 0.4787second
# The 146th iteration T = 0.4553second
# The 147th iteration T = 0.4678second
# The 148th iteration T = 0.4282second
# The 149th iteration T = 0.4597second
# The 150th iteration T = 0.4401second
# The 151th iteration T = 0.4696second
# The 152th iteration T = 0.4767second
# The 153th iteration T = 0.4163second
# The 154th iteration T = 0.5225second
# The 155th iteration T = 0.4677second
# The 156th iteration T = 0.4873second
# The 157th iteration T = 0.4487second
# The 158th iteration T = 0.4529second
# The 159th iteration T = 0.4988second
# The 160th iteration T = 0.4479second
# The 161th iteration T = 0.5007second
# The 162th iteration T = 0.4956second
# The 163th iteration T = 0.4935second
# The 164th iteration T = 0.5013second
# The 165th iteration T = 0.5101second
# The 166th iteration T = 0.5187second
# The 167th iteration T = 0.4520second
# The 168th iteration T = 0.5038second
# The 169th iteration T = 0.5167second
# The 170th iteration T = 0.4807second
# The 171th iteration T = 0.5097second
# The 172th iteration T = 0.5110second
# The 173th iteration T = 0.4893second
# The 174th iteration T = 0.4463second
# The 175th iteration T = 0.4490second
# The 176th iteration T = 0.4626second
# The 177th iteration T = 0.4818second
# The 178th iteration T = 0.5119second
# The 179th iteration T = 0.5227second
# The 180th iteration T = 0.4991second
# The 181th iteration T = 0.5188second
# The 182th iteration T = 0.4855second
# The 183th iteration T = 0.5121second
# The 184th iteration T = 0.5084second
# The 185th iteration T = 0.4614second
# The 186th iteration T = 0.5116second
# The 187th iteration T = 0.5096second
# The 188th iteration T = 0.5133second
# The 189th iteration T = 0.4722second
# The 190th iteration T = 0.4787second
# The 191th iteration T = 0.4714second
# The 192th iteration T = 0.4795second
# The 193th iteration T = 0.5074second
# The 194th iteration T = 0.4787second
# The 195th iteration T = 0.5381second
# The 196th iteration T = 0.4919second
# The 197th iteration T = 0.5199second
# The 198th iteration T = 0.5032second
# The 199th iteration T = 0.5050second
# The 200th iteration T = 0.5094second
# The 201th iteration T = 0.5207second
# The 202th iteration T = 0.5335second
# The 203th iteration T = 0.5238second
# The 204th iteration T = 0.5178second
# The 205th iteration T = 0.5048second
# The 206th iteration T = 0.5018second
# The 207th iteration T = 0.4939second
# The 208th iteration T = 0.4626second
# The 209th iteration T = 0.4815second
# The 210th iteration T = 0.4793second
# The 211th iteration T = 0.4930second
# The 212th iteration T = 0.4821second
# The 213th iteration T = 0.4729second
# The 214th iteration T = 0.5203second
# The 215th iteration T = 0.4775second
# The 216th iteration T = 0.4619second
# The 217th iteration T = 0.5173second
# The 218th iteration T = 0.5199second
# The 219th iteration T = 0.4493second
# The 220th iteration T = 0.4699second
# The 221th iteration T = 0.4706second
# The 222th iteration T = 0.4585second
# The 223th iteration T = 0.5119second
# The 224th iteration T = 0.5100second
# The 225th iteration T = 0.4910second
# The 226th iteration T = 0.4797second
# The 227th iteration T = 0.4821second
# The 228th iteration T = 0.4601second
# The 229th iteration T = 0.4687second
# The 230th iteration T = 0.4703second
# The 231th iteration T = 0.4609second
# The 232th iteration T = 0.5273second
# The 233th iteration T = 0.5212second
# The 234th iteration T = 0.5195second
# The 235th iteration T = 0.4495second
# The 236th iteration T = 0.5655second
# The 237th iteration T = 0.5306second
# The 238th iteration T = 0.5229second
# The 239th iteration T = 0.5052second
# The 240th iteration T = 0.4846second
# The 241th iteration T = 0.4545second
# The 242th iteration T = 0.4749second
# The 243th iteration T = 0.4252second
# The 244th iteration T = 0.4510second
# The 245th iteration T = 0.4915second
# The 246th iteration T = 0.4425second
# The 247th iteration T = 0.4940second
# The 248th iteration T = 0.4613second
# The 249th iteration T = 0.4703second
# The 250th iteration T = 0.4647second
# The 251th iteration T = 0.4924second
# The 252th iteration T = 0.5009second
# The 253th iteration T = 0.4708second
# The 254th iteration T = 0.5112second
# The 255th iteration T = 0.5416second
# The 256th iteration T = 0.4833second
# The 257th iteration T = 0.4887second
# The 258th iteration T = 0.4645second
# The 259th iteration T = 0.4806second
# The 260th iteration T = 0.4812second
# The 261th iteration T = 0.4631second
# The 262th iteration T = 0.5047second
# The 263th iteration T = 0.5492second
# The 264th iteration T = 0.5342second
# The 265th iteration T = 0.4853second
# The 266th iteration T = 0.4841second
# The 267th iteration T = 0.4970second
# The 268th iteration T = 0.5062second
# The 269th iteration T = 0.5101second
# The 270th iteration T = 0.5127second
# The 271th iteration T = 0.5118second
# The 272th iteration T = 0.5188second
# The 273th iteration T = 0.5219second
# The 274th iteration T = 0.4900second
# The 275th iteration T = 0.5525second
# The 276th iteration T = 0.5050second
# The 277th iteration T = 0.5023second
# The 278th iteration T = 0.4981second
# The 279th iteration T = 0.4348second
# The 280th iteration T = 0.4496second
# The 281th iteration T = 0.4318second
# The 282th iteration T = 0.4798second
# The 283th iteration T = 0.5213second
# The 284th iteration T = 0.5145second
# The 285th iteration T = 0.4804second
# The 286th iteration T = 0.5680second
# The 287th iteration T = 0.4657second
# The 288th iteration T = 0.5116second
# The 289th iteration T = 0.4515second
# The 290th iteration T = 0.4555second
# The 291th iteration T = 0.5125second
# The 292th iteration T = 0.5419second
# The 293th iteration T = 0.5243second
# The 294th iteration T = 0.4961second
# The 295th iteration T = 0.5485second
# The 296th iteration T = 0.4965second
# The 297th iteration T = 0.5346second
# The 298th iteration T = 0.4950second
# The 299th iteration T = 0.4731second
# The 300th iteration T = 0.4212second
# The 301th iteration T = 0.4724second
# The 302th iteration T = 0.4444second
# The 303th iteration T = 0.4635second
# The 304th iteration T = 0.4474second
# The 305th iteration T = 0.4851second
# The 306th iteration T = 0.4888second
# The 307th iteration T = 0.4886second
# The 308th iteration T = 0.4534second
# The 309th iteration T = 0.4809second
# The 310th iteration T = 0.5136second
# The 311th iteration T = 0.4459second
# The 312th iteration T = 0.4559second
# The 313th iteration T = 0.4971second
# The 314th iteration T = 0.4876second
# The 315th iteration T = 0.4877second
# The 316th iteration T = 0.4943second
# The 317th iteration T = 0.5247second
# The 318th iteration T = 0.5105second
# The 319th iteration T = 0.4724second
# The 320th iteration T = 0.4721second
# The 321th iteration T = 0.4720second
# The 322th iteration T = 0.4762second
# The 323th iteration T = 0.4701second
# The 324th iteration T = 0.4621second
# The 325th iteration T = 0.4641second
# The 326th iteration T = 0.4878second
# The 327th iteration T = 0.4743second
# The 328th iteration T = 0.4645second
# The 329th iteration T = 0.4563second
# The 330th iteration T = 0.4913second
# The 331th iteration T = 0.4685second
# The 332th iteration T = 0.4520second
# The 333th iteration T = 0.4561second
# The 334th iteration T = 0.4614second
# The 335th iteration T = 0.4835second
# The 336th iteration T = 0.5079second
# The 337th iteration T = 0.4834second
# The 338th iteration T = 0.4669second
# The 339th iteration T = 0.5260second
# The 340th iteration T = 0.4755second
# The 341th iteration T = 0.4775second
# The 342th iteration T = 0.4877second
# The 343th iteration T = 0.4535second
# The 344th iteration T = 0.4839second
# The 345th iteration T = 0.4967second
# The 346th iteration T = 0.5019second
# The 347th iteration T = 0.4850second
# The 348th iteration T = 0.5176second
# The 349th iteration T = 0.4953second
# The 350th iteration T = 0.4991second
# The 351th iteration T = 0.5271second
# The 352th iteration T = 0.4603second
# The 353th iteration T = 0.4567second
# The 354th iteration T = 0.5165second
# The 355th iteration T = 0.4987second
# The 356th iteration T = 0.4818second
# The 357th iteration T = 0.5069second
# The 358th iteration T = 0.5036second
# The 359th iteration T = 0.4823second
# The 360th iteration T = 0.5053second
# The 361th iteration T = 0.5581second
# The 362th iteration T = 0.5136second
# The 363th iteration T = 0.4953second
# The 364th iteration T = 0.5072second
# The 365th iteration T = 0.5308second
# The 366th iteration T = 0.4683second
# The 367th iteration T = 0.5451second
# The 368th iteration T = 0.4329second
# The 369th iteration T = 0.4509second
# The 370th iteration T = 0.4937second
# The 371th iteration T = 0.4804second
# The 372th iteration T = 0.4975second
# The 373th iteration T = 0.4858second
# The 374th iteration T = 0.4776second
# The 375th iteration T = 0.4731second
# The 376th iteration T = 0.4807second
# The 377th iteration T = 0.5023second
# The 378th iteration T = 0.4493second
# The 379th iteration T = 0.4745second
# The 380th iteration T = 0.4834second
# The 381th iteration T = 0.4934second
# The 382th iteration T = 0.4849second
# The 383th iteration T = 0.4529second
# The 384th iteration T = 0.4636second
# The 385th iteration T = 0.4771second
# The 386th iteration T = 0.5284second
# The 387th iteration T = 0.4868second
# The 388th iteration T = 0.5195second
# The 389th iteration T = 0.4049second
# The 390th iteration T = 0.4660second
# The 391th iteration T = 0.4702second
# The 392th iteration T = 0.4769second
# The 393th iteration T = 0.4764second
# The 394th iteration T = 0.4489second
# The 395th iteration T = 0.4764second
# The 396th iteration T = 0.4822second
# The 397th iteration T = 0.5082second
# The 398th iteration T = 0.5104second
# The 399th iteration T = 0.4721second
# The 400th iteration T = 0.5255second
# The 401th iteration T = 0.4613second
# The 402th iteration T = 0.5109second
# The 403th iteration T = 0.4786second
# The 404th iteration T = 0.5376second
# The 405th iteration T = 0.4656second
# The 406th iteration T = 0.4964second
# The 407th iteration T = 0.4882second
# The 408th iteration T = 0.4775second
# The 409th iteration T = 0.5002second
# The 410th iteration T = 0.4880second
# The 411th iteration T = 0.4972second
# The 412th iteration T = 0.4752second
# The 413th iteration T = 0.5016second
# The 414th iteration T = 0.4894second
# The 415th iteration T = 0.4963second
# The 416th iteration T = 0.4845second
# The 417th iteration T = 0.5153second
# The 418th iteration T = 0.4957second
# The 419th iteration T = 0.4869second
# The 420th iteration T = 0.5137second
# The 421th iteration T = 0.4717second
# The 422th iteration T = 0.5184second
# The 423th iteration T = 0.5378second
# The 424th iteration T = 0.4961second
# The 425th iteration T = 0.4889second
# The 426th iteration T = 0.4775second
# The 427th iteration T = 0.4772second
# The 428th iteration T = 0.5049second
# The 429th iteration T = 0.4677second
# The 430th iteration T = 0.4366second
# The 431th iteration T = 0.4980second
# The 432th iteration T = 0.4682second
# The 433th iteration T = 0.4855second
# The 434th iteration T = 0.4649second
# The 435th iteration T = 0.4678second
# The 436th iteration T = 0.4622second
# The 437th iteration T = 0.4762second
# The 438th iteration T = 0.5006second
# The 439th iteration T = 0.5179second
# The 440th iteration T = 0.4428second
# The 441th iteration T = 0.4774second
# The 442th iteration T = 0.5206second
# The 443th iteration T = 0.5331second
# The 444th iteration T = 0.4867second
# The 445th iteration T = 0.4496second
# The 446th iteration T = 0.4938second
# The 447th iteration T = 0.4876second
# The 448th iteration T = 0.5473second
# The 449th iteration T = 0.4867second
# The 450th iteration T = 0.4755second
# The 451th iteration T = 0.4367second
# The 452th iteration T = 0.5363second
# The 453th iteration T = 0.4994second
# The 454th iteration T = 0.5079second
# The 455th iteration T = 0.5120second
# The 456th iteration T = 0.5186second
# The 457th iteration T = 0.4909second
# The 458th iteration T = 0.5191second
# The 459th iteration T = 0.5265second
# The 460th iteration T = 0.4783second
# The 461th iteration T = 0.4959second
# The 462th iteration T = 0.5079second
# The 463th iteration T = 0.4290second
# The 464th iteration T = 0.4943second
# The 465th iteration T = 0.4609second
# The 466th iteration T = 0.4621second
# The 467th iteration T = 0.5106second
# The 468th iteration T = 0.4537second
# The 469th iteration T = 0.4849second
# The 470th iteration T = 0.4871second
# The 471th iteration T = 0.5185second
# The 472th iteration T = 0.5011second
# The 473th iteration T = 0.4865second
# The 474th iteration T = 0.5594second
# The 475th iteration T = 0.4765second
# The 476th iteration T = 0.4460second
# The 477th iteration T = 0.5465second
# The 478th iteration T = 0.5065second
# The 479th iteration T = 0.4950second
# The 480th iteration T = 0.5565second
# The 481th iteration T = 0.5878second
# The 482th iteration T = 0.4753second
# The 483th iteration T = 0.4476second
# The 484th iteration T = 0.5269second
# The 485th iteration T = 0.5109second
# The 486th iteration T = 0.4837second
# The 487th iteration T = 0.4844second
# The 488th iteration T = 0.5171second
# The 489th iteration T = 0.5292second
# The 490th iteration T = 0.4950second
# The 491th iteration T = 0.4987second
# The 492th iteration T = 0.5297second
# The 493th iteration T = 0.4903second
# The 494th iteration T = 0.5603second
# The 495th iteration T = 0.5755second
# The 496th iteration T = 0.4930second
# The 497th iteration T = 0.4654second
# The 498th iteration T = 0.4534second
# The 499th iteration T = 0.4739second
# The 500th iteration T = 0.4949second
# The 501th iteration T = 0.4959second
# The 502th iteration T = 0.4633second
# The 503th iteration T = 0.4676second
# The 504th iteration T = 0.4702second
# The 505th iteration T = 0.4784second
# The 506th iteration T = 0.4853second
# The 507th iteration T = 0.4958second
# The 508th iteration T = 0.4547second
# The 509th iteration T = 0.4675second
# The 510th iteration T = 0.4366second
# The 511th iteration T = 0.4356second
# The 512th iteration T = 0.5173second
# The 513th iteration T = 0.4289second
# The 514th iteration T = 0.4921second
# The 515th iteration T = 0.4947second
# The 516th iteration T = 0.4244second
# The 517th iteration T = 0.5520second
# The 518th iteration T = 0.4792second
# The 519th iteration T = 0.4560second
# The 520th iteration T = 0.5359second
# The 521th iteration T = 0.5091second
# The 522th iteration T = 0.5064second
# The 523th iteration T = 0.4818second
# The 524th iteration T = 0.4671second
# The 525th iteration T = 0.5275second
# The 526th iteration T = 0.4275second
# The 527th iteration T = 0.4672second
# The 528th iteration T = 0.4984second
# The 529th iteration T = 0.4883second
# The 530th iteration T = 0.5074second
# The 531th iteration T = 0.4243second
# The 532th iteration T = 0.4366second
# The 533th iteration T = 0.4602second
# The 534th iteration T = 0.4596second
# The 535th iteration T = 0.4788second
# The 536th iteration T = 0.4554second
# The 537th iteration T = 0.4977second
# The 538th iteration T = 0.4728second
# The 539th iteration T = 0.4612second
# The 540th iteration T = 0.4852second
# The 541th iteration T = 0.5053second
# The 542th iteration T = 0.4793second
# The 543th iteration T = 0.4646second
# The 544th iteration T = 0.4274second
# The 545th iteration T = 0.4612second
# The 546th iteration T = 0.4213second
# The 547th iteration T = 0.4478second
# The 548th iteration T = 0.4560second
# The 549th iteration T = 0.4956second
# The 550th iteration T = 0.4875second
# The 551th iteration T = 0.5179second
# The 552th iteration T = 0.5069second
# The 553th iteration T = 0.4926second
# The 554th iteration T = 0.4876second
# The 555th iteration T = 0.4485second
# The 556th iteration T = 0.5092second
# The 557th iteration T = 0.4574second
# The 558th iteration T = 0.4970second
# The 559th iteration T = 0.4464second
# The 560th iteration T = 0.4709second
# The 561th iteration T = 0.4511second
# The 562th iteration T = 0.4679second
# The 563th iteration T = 0.4939second
# The 564th iteration T = 0.4714second
# The 565th iteration T = 0.4676second
# The 566th iteration T = 0.5037second
# The 567th iteration T = 0.4602second
# The 568th iteration T = 0.4987second
# The 569th iteration T = 0.4891second
# The 570th iteration T = 0.4905second
# The 571th iteration T = 0.4746second
# The 572th iteration T = 0.4687second
# The 573th iteration T = 0.4676second
# The 574th iteration T = 0.4540second
# The 575th iteration T = 0.4600second
# The 576th iteration T = 0.4874second
# The 577th iteration T = 0.5040second
# The 578th iteration T = 0.4695second
# The 579th iteration T = 0.4867second
# The 580th iteration T = 0.4597second
# The 581th iteration T = 0.4651second
# The 582th iteration T = 0.4893second
# The 583th iteration T = 0.4686second
# The 584th iteration T = 0.5403second
# The 585th iteration T = 0.4624second
# The 586th iteration T = 0.5383second
# The 587th iteration T = 0.4783second
# The 588th iteration T = 0.4540second
# The 589th iteration T = 0.4668second
# The 590th iteration T = 0.5096second
# The 591th iteration T = 0.4881second
# The 592th iteration T = 0.5198second
# The 593th iteration T = 0.5309second
# The 594th iteration T = 0.5405second
# The 595th iteration T = 0.4704second
# The 596th iteration T = 0.4347second
# The 597th iteration T = 0.4702second
# The 598th iteration T = 0.4902second
# The 599th iteration T = 0.4666second
# The 600th iteration T = 0.4908second
# The 601th iteration T = 0.4767second
# The 602th iteration T = 0.4989second
# The 603th iteration T = 0.4969second
# The 604th iteration T = 0.4607second
# The 605th iteration T = 0.4927second
# The 606th iteration T = 0.5092second
# The 607th iteration T = 0.4906second
# The 608th iteration T = 0.4717second
# The 609th iteration T = 0.4214second
# The 610th iteration T = 0.5099second
# The 611th iteration T = 0.4714second
# The 612th iteration T = 0.4678second
# The 613th iteration T = 0.4579second
# The 614th iteration T = 0.4890second
# The 615th iteration T = 0.5114second
# The 616th iteration T = 0.4564second
# The 617th iteration T = 0.4719second
# The 618th iteration T = 0.4698second
# The 619th iteration T = 0.4853second
# The 620th iteration T = 0.4813second
# The 621th iteration T = 0.4597second
# The 622th iteration T = 0.4711second
# The 623th iteration T = 0.4915second
# The 624th iteration T = 0.4489second
# The 625th iteration T = 0.4754second
# The 626th iteration T = 0.4465second
# The 627th iteration T = 0.4582second
# The 628th iteration T = 0.5097second
# The 629th iteration T = 0.4797second
# The 630th iteration T = 0.4881second
# The 631th iteration T = 0.5401second
# The 632th iteration T = 0.4987second
# The 633th iteration T = 0.4697second
# The 634th iteration T = 0.4856second
# The 635th iteration T = 0.5298second
# The 636th iteration T = 0.4691second
# The 637th iteration T = 0.5049second
# The 638th iteration T = 0.4878second
# The 639th iteration T = 0.4788second
# The 640th iteration T = 0.5045second
# The 641th iteration T = 0.4711second
# The 642th iteration T = 0.4615second
# The 643th iteration T = 0.4873second
# The 644th iteration T = 0.4628second
# The 645th iteration T = 0.4603second
# The 646th iteration T = 0.4503second
# The 647th iteration T = 0.4670second
# The 648th iteration T = 0.5225second
# The 649th iteration T = 0.4952second
# The 650th iteration T = 0.4968second
# The 651th iteration T = 0.4874second
# The 652th iteration T = 0.4919second
# The 653th iteration T = 0.4596second
# The 654th iteration T = 0.5724second
# The 655th iteration T = 0.4693second
# The 656th iteration T = 0.4547second
# The 657th iteration T = 0.4893second
# The 658th iteration T = 0.4798second
# The 659th iteration T = 0.5108second
# The 660th iteration T = 0.4968second
# The 661th iteration T = 0.4671second
# The 662th iteration T = 0.4528second
# The 663th iteration T = 0.4966second
# The 664th iteration T = 0.4699second
# The 665th iteration T = 0.4858second
# The 666th iteration T = 0.5177second
# The 667th iteration T = 0.4736second
# The 668th iteration T = 0.4543second
# The 669th iteration T = 0.4632second
# The 670th iteration T = 0.4693second
# The 671th iteration T = 0.4818second
# The 672th iteration T = 0.4621second
# The 673th iteration T = 0.4614second
# The 674th iteration T = 0.4778second
# The 675th iteration T = 0.5201second
# The 676th iteration T = 0.5513second
# The 677th iteration T = 0.4668second
# The 678th iteration T = 0.5428second
# The 679th iteration T = 0.4840second
# The 680th iteration T = 0.4829second
# The 681th iteration T = 0.4855second
# The 682th iteration T = 0.4888second
# The 683th iteration T = 0.4728second
# The 684th iteration T = 0.4801second
# The 685th iteration T = 0.5101second
# The 686th iteration T = 0.5101second
# The 687th iteration T = 0.4933second
# The 688th iteration T = 0.4613second
# The 689th iteration T = 0.4753second
# The 690th iteration T = 0.4486second
# The 691th iteration T = 0.4506second
# The 692th iteration T = 0.4715second
# The 693th iteration T = 0.4882second
# The 694th iteration T = 0.4917second
# The 695th iteration T = 0.5038second
# The 696th iteration T = 0.4937second
# The 697th iteration T = 0.4968second
# The 698th iteration T = 0.4599second
# The 699th iteration T = 0.4918second
# The 700th iteration T = 0.5130second
# The 701th iteration T = 0.4717second
# The 702th iteration T = 0.4806second
# The 703th iteration T = 0.4507second
# The 704th iteration T = 0.4507second
# The 705th iteration T = 0.5127second
# The 706th iteration T = 0.4999second
# The 707th iteration T = 0.4909second
# The 708th iteration T = 0.4582second
# The 709th iteration T = 0.4587second
# The 710th iteration T = 0.4924second
# The 711th iteration T = 0.4994second
# The 712th iteration T = 0.4662second
# The 713th iteration T = 0.5022second
# The 714th iteration T = 0.4743second
# The 715th iteration T = 0.4543second
# The 716th iteration T = 0.4457second
# The 717th iteration T = 0.4413second
# The 718th iteration T = 0.4823second
# The 719th iteration T = 0.4852second
# The 720th iteration T = 0.5032second
# The 721th iteration T = 0.4909second
# The 722th iteration T = 0.5136second
# The 723th iteration T = 0.4891second
# The 724th iteration T = 0.4710second
# The 725th iteration T = 0.4610second
# The 726th iteration T = 0.4769second
# The 727th iteration T = 0.5113second
# The 728th iteration T = 0.5186second
# The 729th iteration T = 0.4778second
# The 730th iteration T = 0.4880second
# The 731th iteration T = 0.5129second
# The 732th iteration T = 0.4607second
# The 733th iteration T = 0.5305second
# The 734th iteration T = 0.4395second
# The 735th iteration T = 0.4853second
# The 736th iteration T = 0.5014second
# The 737th iteration T = 0.5107second
# The 738th iteration T = 0.5109second
# The 739th iteration T = 0.4737second
# The 740th iteration T = 0.4767second
# The 741th iteration T = 0.4526second
# The 742th iteration T = 0.4528second
# The 743th iteration T = 0.4746second
# The 744th iteration T = 0.4858second
# The 745th iteration T = 0.4932second
# The 746th iteration T = 0.4701second
# The 747th iteration T = 0.4830second
# The 748th iteration T = 0.4656second
# The 749th iteration T = 0.4964second
# The 750th iteration T = 0.4921second
# The 751th iteration T = 0.5011second
# The 752th iteration T = 0.4815second
# The 753th iteration T = 0.4723second
# The 754th iteration T = 0.4866second
# The 755th iteration T = 0.4895second
# The 756th iteration T = 0.4919second
# The 757th iteration T = 0.4962second
# The 758th iteration T = 0.5127second
# The 759th iteration T = 0.4999second
# The 760th iteration T = 0.5175second
# The 761th iteration T = 0.4763second
# The 762th iteration T = 0.4978second
# The 763th iteration T = 0.5028second
# The 764th iteration T = 0.4914second
# The 765th iteration T = 0.4902second
# The 766th iteration T = 0.4868second
# The 767th iteration T = 0.4939second
# The 768th iteration T = 0.4833second
# The 769th iteration T = 0.5006second
# The 770th iteration T = 0.4717second
# The 771th iteration T = 0.5095second
# The 772th iteration T = 0.4983second
# The 773th iteration T = 0.5032second
# The 774th iteration T = 0.4820second
# The 775th iteration T = 0.4182second
# The 776th iteration T = 0.4540second
# The 777th iteration T = 0.4726second
# The 778th iteration T = 0.4409second
# The 779th iteration T = 0.4878second
# The 780th iteration T = 0.5127second
# The 781th iteration T = 0.4991second
# The 782th iteration T = 0.4746second
# The 783th iteration T = 0.4910second
# The 784th iteration T = 0.5438second
# The 785th iteration T = 0.4515second
# The 786th iteration T = 0.4665second
# The 787th iteration T = 0.4836second
# The 788th iteration T = 0.5030second
# The 789th iteration T = 0.5120second
# The 790th iteration T = 0.5243second
# The 791th iteration T = 0.5302second
# The 792th iteration T = 0.5184second
# The 793th iteration T = 0.5414second
# The 794th iteration T = 0.4993second
# The 795th iteration T = 0.4533second
# The 796th iteration T = 0.4877second
# The 797th iteration T = 0.4939second
# The 798th iteration T = 0.4710second
# The 799th iteration T = 0.5030second
# The 800th iteration T = 0.4824second
# The 801th iteration T = 0.4968second
# The 802th iteration T = 0.4725second
# The 803th iteration T = 0.4545second
# The 804th iteration T = 0.4885second
# The 805th iteration T = 0.4717second
# The 806th iteration T = 0.4398second
# The 807th iteration T = 0.4541second
# The 808th iteration T = 0.5014second
# The 809th iteration T = 0.4606second
# The 810th iteration T = 0.4407second
# The 811th iteration T = 0.4930second
# The 812th iteration T = 0.4732second
# The 813th iteration T = 0.4823second
# The 814th iteration T = 0.4535second
# The 815th iteration T = 0.4732second
# The 816th iteration T = 0.4695second
# The 817th iteration T = 0.4591second
# The 818th iteration T = 0.4409second
# The 819th iteration T = 0.4647second
# The 820th iteration T = 0.4617second
# The 821th iteration T = 0.4768second
# The 822th iteration T = 0.5235second
# The 823th iteration T = 0.5040second
# The 824th iteration T = 0.4975second
# The 825th iteration T = 0.5236second
# The 826th iteration T = 0.4829second
# The 827th iteration T = 0.4620second
# The 828th iteration T = 0.4744second
# The 829th iteration T = 0.4224second
# The 830th iteration T = 0.4424second
# The 831th iteration T = 0.5260second
# The 832th iteration T = 0.5363second
# The 833th iteration T = 0.4525second
# The 834th iteration T = 0.4761second
# The 835th iteration T = 0.4796second
# The 836th iteration T = 0.4939second
# The 837th iteration T = 0.4937second
# The 838th iteration T = 0.5275second
# The 839th iteration T = 0.5007second
# The 840th iteration T = 0.5010second
# The 841th iteration T = 0.4672second
# The 842th iteration T = 0.4761second
# The 843th iteration T = 0.4502second
# The 844th iteration T = 0.4950second
# The 845th iteration T = 0.5005second
# The 846th iteration T = 0.4862second
# The 847th iteration T = 0.4932second
# The 848th iteration T = 0.4837second
# The 849th iteration T = 0.4813second
# The 850th iteration T = 0.4790second
# The 851th iteration T = 0.4878second
# The 852th iteration T = 0.5361second
# The 853th iteration T = 0.5101second
# The 854th iteration T = 0.4996second
# The 855th iteration T = 0.4939second
# The 856th iteration T = 0.4667second
# The 857th iteration T = 0.4947second
# The 858th iteration T = 0.5158second
# The 859th iteration T = 0.4904second
# The 860th iteration T = 0.4420second
# The 861th iteration T = 0.5017second
# The 862th iteration T = 0.4936second
# The 863th iteration T = 0.4969second
# The 864th iteration T = 0.4489second
# The 865th iteration T = 0.4741second
# The 866th iteration T = 0.4957second
# The 867th iteration T = 0.4712second
# The 868th iteration T = 0.4750second
# The 869th iteration T = 0.4742second
# The 870th iteration T = 0.4673second
# The 871th iteration T = 0.4906second
# The 872th iteration T = 0.5119second
# The 873th iteration T = 0.4722second
# The 874th iteration T = 0.4615second
# The 875th iteration T = 0.4744second
# The 876th iteration T = 0.4769second
# The 877th iteration T = 0.5336second
# The 878th iteration T = 0.5060second
# The 879th iteration T = 0.5150second
# The 880th iteration T = 0.4540second
# The 881th iteration T = 0.5263second
# The 882th iteration T = 0.4925second
# The 883th iteration T = 0.5148second
# The 884th iteration T = 0.4942second
# The 885th iteration T = 0.4618second
# The 886th iteration T = 0.4836second
# The 887th iteration T = 0.5353second
# The 888th iteration T = 0.4919second
# The 889th iteration T = 0.4784second
# The 890th iteration T = 0.4931second
# The 891th iteration T = 0.4829second
# The 892th iteration T = 0.4565second
# The 893th iteration T = 0.5183second
# The 894th iteration T = 0.5236second
# The 895th iteration T = 0.4500second
# The 896th iteration T = 0.4911second
# The 897th iteration T = 0.4953second
# The 898th iteration T = 0.5334second
# The 899th iteration T = 0.4605second
# The 900th iteration T = 0.5187second
# The 901th iteration T = 0.4651second
# The 902th iteration T = 0.4655second
# The 903th iteration T = 0.5110second
# The 904th iteration T = 0.4626second
# The 905th iteration T = 0.4863second
# The 906th iteration T = 0.4929second
# The 907th iteration T = 0.4669second
# The 908th iteration T = 0.4721second
# The 909th iteration T = 0.5036second
# The 910th iteration T = 0.4733second
# The 911th iteration T = 0.4471second
# The 912th iteration T = 0.4520second
# The 913th iteration T = 0.4741second
# The 914th iteration T = 0.4346second
# The 915th iteration T = 0.4552second
# The 916th iteration T = 0.4706second
# The 917th iteration T = 0.4938second
# The 918th iteration T = 0.4746second
# The 919th iteration T = 0.4951second
# The 920th iteration T = 0.4667second
# The 921th iteration T = 0.4630second
# The 922th iteration T = 0.4631second
# The 923th iteration T = 0.4464second
# The 924th iteration T = 0.4704second
# The 925th iteration T = 0.5189second
# The 926th iteration T = 0.5026second
# The 927th iteration T = 0.4749second
# The 928th iteration T = 0.4752second
# The 929th iteration T = 0.5256second
# The 930th iteration T = 0.4835second
# The 931th iteration T = 0.4909second
# The 932th iteration T = 0.5489second
# The 933th iteration T = 0.4940second
# The 934th iteration T = 0.5083second
# The 935th iteration T = 0.4635second
# The 936th iteration T = 0.4990second
# The 937th iteration T = 0.5233second
# The 938th iteration T = 0.5147second
# The 939th iteration T = 0.5387second
# The 940th iteration T = 0.5027second
# The 941th iteration T = 0.5054second
# The 942th iteration T = 0.4737second
# The 943th iteration T = 0.5454second
# The 944th iteration T = 0.4717second
# The 945th iteration T = 0.4403second
# The 946th iteration T = 0.4810second
# The 947th iteration T = 0.4819second
# The 948th iteration T = 0.5262second
# The 949th iteration T = 0.4784second
# The 950th iteration T = 0.4628second
# The 951th iteration T = 0.4599second
# The 952th iteration T = 0.4709second
# The 953th iteration T = 0.5512second
# The 954th iteration T = 0.4729second
# The 955th iteration T = 0.4988second
# The 956th iteration T = 0.4613second
# The 957th iteration T = 0.4893second
# The 958th iteration T = 0.4953second
# The 959th iteration T = 0.4870second
# The 960th iteration T = 0.4738second
# The 961th iteration T = 0.4853second
# The 962th iteration T = 0.4544second
# The 963th iteration T = 0.4539second
# The 964th iteration T = 0.5457second
# The 965th iteration T = 0.5162second
# The 966th iteration T = 0.4818second
# The 967th iteration T = 0.4623second
# The 968th iteration T = 0.4523second
# The 969th iteration T = 0.4764second
# The 970th iteration T = 0.4922second
# The 971th iteration T = 0.5021second
# The 972th iteration T = 0.4745second
# The 973th iteration T = 0.5135second
# The 974th iteration T = 0.4807second
# The 975th iteration T = 0.4751second
# The 976th iteration T = 0.4320second
# The 977th iteration T = 0.4422second
# The 978th iteration T = 0.4875second
# The 979th iteration T = 0.4423second
# The 980th iteration T = 0.4665second
# The 981th iteration T = 0.4853second
# The 982th iteration T = 0.5080second
# The 983th iteration T = 0.5131second
# The 984th iteration T = 0.5155second
# The 985th iteration T = 0.4841second
# The 986th iteration T = 0.4533second
# The 987th iteration T = 0.4867second
# The 988th iteration T = 0.5262second
# The 989th iteration T = 0.4822second
# The 990th iteration T = 0.4895second
# The 991th iteration T = 0.4321second
# The 992th iteration T = 0.4473second
# The 993th iteration T = 0.4762second
# The 994th iteration T = 0.4756second
# The 995th iteration T = 0.4956second
# The 996th iteration T = 0.4660second
# The 997th iteration T = 0.5150second
# The 998th iteration T = 0.4811second
# The 999th iteration T = 0.5266second
# The 1000th iteration T = 0.4759second
# operating time T = 493.8344
# Optimal Feature Set
#  ['B_Density', 'C_dipole Polarizability', 'A_number of Valence Electrons', 'X_number of Valence Electrons', 'X_number of s+p Electrons', 'A_number of d Electrons', 'C_Mulliken EN', 'X_Mulliken EN', 'A-C_number of Valence Electrons', '(A+B+C)-X_number of Valence Electrons', 'A-B_number of s+p Electrons', 'A-C_number of s+p Electrons', '(A+B+C)-X_number of d Electrons']
# Optimal Accuracy = 95 %

# %%
#Optimal Feature Set
feature_xgb =  ['B_Density', 'C_dipole Polarizability', 'A_number of Valence Electrons', 'C_Period', 'A_Electronegativity',
                'A_number of s+p Electrons', 'B_number of s+p Electrons', 'X_number of s+p Electrons', 'C_Mulliken EN', 'X_Mulliken EN',
                '(A+B+C)-X_number of Valence Electrons', 'A-B_Electronegativity', 'A-B_number of s+p Electrons', 'A-C_number of d Electrons',
                '(A+B+C)-X_number of d Electrons'] 
#Optimal Accuracy = 94 %

# %%
X_xgb = X[feature_xgb]
print(X_xgb.shape)
# Out:
# (1291, 15)

# %% [markdown]
# ## Best model effect

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.model_selection import StratifiedKFold
from imblearn.over_sampling import SMOTE
from collections import Counter
def fold5_ensemble(model, X, y, name='', is_plot=True):
    kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    models = []  
    accuracies = []
    f1s = []
    mccs = []
    roc_aucs = []
    recalls = []
    fig, ax = plt.subplots()
    for i, (train_index, test_index) in enumerate(kf.split(X, y)):
        try:
            X = X.values
            y = y.values
        except:
            pass
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]
        model.fit(X_train, y_train)
        models.append(model)

        y_pred = model.predict(X_test)
        y_prob = model.predict_proba(X_test)[:, 1]
        accuracy = metrics.accuracy_score(y_test, y_pred)
        f1 = metrics.f1_score(y_test, y_pred)
        mcc = metrics.matthews_corrcoef(y_test, y_pred)
        fpr, tpr, _ = metrics.roc_curve(y_test, y_prob)
        roc_auc = metrics.auc(fpr, tpr)
        recall = metrics.recall_score(y_test, y_pred)

        print(f"Fold {i+ 1} Accuracy: {accuracy} F1_Score: {f1}  ROC_AUC: {roc_auc}")
        accuracies.append(accuracy)
        f1s.append(f1)
        mccs.append(mcc)
        roc_aucs.append(roc_auc)
        recalls.append(recall)
        if is_plot:
            ax.plot(fpr, tpr, label=f"Fold {i+1} (AUC = {roc_auc:.3f})", lw=1.7, linestyle="-.", alpha=0.75)
            ax.plot([0, 1], [0, 1], "r--", lw=1, alpha=0.8)
            ax.set_xlim([-0.02, 1.0])
            ax.set_ylim([0.0, 1.05])
            ax.set_xlabel("False Positive Rate", fontsize=22)
            ax.set_ylabel("True Positive Rate", fontsize=22)
           # ax.set_title(f"ROC Curves: {name}", fontweight="bold")
            ax.legend(loc="lower right" ,fontsize=17)
            ax.grid(True, linestyle="--", linewidth=1, alpha=0.5)
            ax.spines["top"].set_linewidth(1.5)
            ax.spines["bottom"].set_linewidth(1.5)
            ax.spines["left"].set_linewidth(1.5)
            ax.spines["right"].set_linewidth(1.5)
            ax.tick_params(axis='both', which='major', labelsize=20)
            ax.grid(False)  

    result = {
        'accuracy': np.mean(accuracies),
        'f1-score': np.mean(f1s),
        'mcc': np.mean(mccs),
        'roc_auc': np.mean(roc_aucs),
        'recall': np.mean(recalls)        }
    if is_plot:
        #plt.savefig('./picture/bg_class.png', dpi=300, bbox_inches='tight')
        plt.show()
    return result, models

# %%
xgb_result = fold5(xgb, X_xgb, y)
xgb_result
# Out:
# {'accuracy': 0.9426925264134567,
#  'f1-score': 0.9179054186319038,
#  'mcc': 0.8740762712350797,
#  'roc_auc': 0.9795021747887447,
#  'recall': 0.908,
#  'accuracy_std': 0.01700027474677852,
#  'f1-score_std': 0.024092696166924055,
#  'mcc_std': 0.03728455838574683,
#  'roc_auc_std': 0.004052183206432025,
#  'recall_std': 0.02135415650406261}

# %%
from joblib import dump

dump(xgb_models, './model/bgclass_xgb_cn.joblib')
# loaded_model = load(model_filename)
# Out:
# ['bgclass_xgb_cn.joblib']

# %%
feature_xgb =  ['B_Density', 'C_dipole Polarizability', 'A_number of Valence Electrons', 'C_Period', 'A_Electronegativity',
                'A_number of s+p Electrons', 'B_number of s+p Electrons', 'X_number of s+p Electrons', 'C_Mulliken EN', 'X_Mulliken EN',
                '(A+B+C)-X_number of Valence Electrons', 'A-B_Electronegativity', 'A-B_number of s+p Electrons', 'A-C_number of d Electrons',
                '(A+B+C)-X_number of d Electrons']

# %%
shap.summary_plot(shap_values, test, plot_type="dot", show=False,max_display=5,color_bar=True)
plt.gca().set_position([0.2, 0.2, 0.65, 0.65]) 
ax1 = plt.gca()
ax2 = ax1.twiny()
shap.summary_plot(shap_values, test, plot_type="bar", show=False,max_display=5)
plt.gca().set_position([0.2, 0.2, 0.65, 0.65])  
ax2.axhline(y=5, color='gray', linestyle='-', linewidth=1.5) 
bars = ax2.patches  

for bar in bars:    
    bar.set_alpha(0.2)  

ax1.set_xlabel('Shapley Value Contribution (Bee Swarm)', fontsize=12)
ax2.set_xlabel('Mean Shapley Value (Feature Importance)', fontsize=12)
ax2.xaxis.set_ticks_position('top') 
ax2.xaxis.set_label_position('top')
plt.subplots_adjust(
    left=0.2,    
    right=0.75, 
    top=0.85,    
    bottom=0.15  
)

ax1.set_ylabel('Features', fontsize=12)
plt.tight_layout()
plt.savefig('./picture/bgclass_shap.png', bbox_inches='tight')
plt.show()

# %%
shap.plots.scatter(shap_values[:, 'X_Mulliken EN'], hist=False)
ax = plt.gca()
for spine in ax.spines.values():
    spine.set_linewidth(1.5)
ax.tick_params(axis='both', which='major', labelsize=30)
plt.setp(ax.get_xticklabels(), fontweight=550,color='black')  
plt.setp(ax.get_yticklabels(), fontweight=550,color='black') 
ax.set_ylabel("SHAP value for \n $MEn_{\mathrm{X}} (eV)$", fontsize=30,fontweight=550,color='black')
ax.set_xlabel(r"$MEn_{\mathrm{X}} (eV)$ ", fontsize=30,fontweight=550,color='black')
plt.tight_layout()
ax.axhline(y=0,color='black',linestyle='--',linewidth=1,zorder=3)
ax.axvline(x=43,color='black',linestyle='--',linewidth=1,zorder=3)
ax.axvline(x=52,color='black',linestyle='--',linewidth=1,zorder=3)
plt.savefig("./picture/bgclass_shap1.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
shap.plots.scatter(shap_values[:, 'B_Density'], hist=False)
ax = plt.gca()
for spine in ax.spines.values():
    spine.set_linewidth(1.5)
ax.tick_params(axis='both', which='major', labelsize=30)
plt.setp(ax.get_xticklabels(), fontweight=550,color='black')  # x轴加粗
plt.setp(ax.get_yticklabels(), fontweight=550,color='black') 
ax.set_ylabel("SHAP value for \n $D_{\mathrm{B}} (g/cm³)$", fontsize=30,fontweight=550,color='black')
ax.set_xlabel(r"$D_{\mathrm{B}} (g/cm³)$", fontsize=30,fontweight=550,color='black')
plt.tight_layout()
ax.axhline(y=0,color='black',linestyle='--',linewidth=1,zorder=3)
ax.axvline(x=4,color='black',linestyle='--',linewidth=1,zorder=3)
plt.savefig("./picture/bgclass_shap2.png", dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# # predicting bandgap type and screening candidate space

# %%
data = pd.read_csv('./data/data_tf.csv')
data
# Out:
#         formula  number  A_Density  B_Density  C_Density  X_Density  \
# 0      Li2NaBF6       1      1.068      0.971    2.34000     0.0102
# 1      Li2NaNF6       1      1.068      0.971    0.00125     0.0102
# 2     Li2CuAlF6       1      1.068      8.960    2.70000     0.0102
# 3      Li2CuPF6       1      1.068      8.960    1.82000     0.0102
# 4     Li2CuCrF6       1      1.068      8.960    7.15000     0.0102
# ...         ...     ...        ...        ...        ...        ...
# 9081  Nd2LiCuF6       3     14.020      0.534    8.96000     0.0102
# 9082  Nd2NaCuF6       3     14.020      0.971    8.96000     0.0102
# 9083  Eu2LiCuF6       3     10.480      0.534    8.96000     0.0102
# 9084  Tm2LiCuF6       3     18.640      0.534    8.96000     0.0102
# 9085  Yb2LiCuF6       3     13.940      0.534    8.96000     0.0102
#
#       A_dipole Polarizability  B_dipole Polarizability  \
# 0                     328.225                 162.7000
# 1                     328.225                 162.7000
# 2                     328.225                  46.5000
# 3                     328.225                  46.5000
# 4                     328.225                  46.5000
# ...                       ...                      ...
# 9081                  416.000                 164.1125
# 9082                  416.000                 162.7000
# 9083                  368.000                 164.1125
# 9084                  288.000                 164.1125
# 9085                  278.000                 164.1125
#
#       C_dipole Polarizability  X_dipole Polarizability  A_covalent Radius  \
# 0                        20.5                    22.44                266
# 1                         7.4                    22.44                266
# 2                        57.8                    22.44                266
# 3                        25.0                    22.44                266
# 4                        83.0                    22.44                266
# ...                       ...                      ...                ...
# 9081                     46.5                    22.44                348
# 9082                     46.5                    22.44                348
# 9083                     46.5                    22.44                336
# 9084                     46.5                    22.44                328
# 9085                     46.5                    22.44                340
#
#       B_covalent Radius  C_covalent Radius  X_covalent Radius  \
# 0                   155                 85                384
# 1                   155                 71                384
# 2                   112                126                384
# 3                   112                111                384
# 4                   112                122                384
# ...                 ...                ...                ...
# 9081                133                112                384
# 9082                155                112                384
# 9083                133                112                384
# 9084                133                112                384
# 9085                133                112                384
#
#       A_atomic Radius  B_atomic Radius  C_atomic Radius  X_atomic Radius  \
# 0                 2.9             1.80             0.85              3.0
# 1                 2.9             1.80             0.65              3.0
# 2                 2.9             1.35             1.25              3.0
# 3                 2.9             1.35             1.00              3.0
# 4                 2.9             1.35             1.40              3.0
# ...               ...              ...              ...              ...
# 9081              3.7             1.45             1.35              3.0
# 9082              3.7             1.80             1.35              3.0
# 9083              3.7             1.45             1.35              3.0
# 9084              3.5             1.45             1.35              3.0
# 9085              3.5             1.45             1.35              3.0
#
#       A_FirstIonization  B_FirstIonization  C_FirstIonization  \
# 0                1040.4              495.8              800.6
# 1                1040.4              495.8             1402.3
# 2                1040.4              745.5              577.5
# 3                1040.4              745.5             1011.8
# 4                1040.4              745.5              652.9
# ...                 ...                ...                ...
# 9081             1066.2              520.2              745.5
# 9082             1066.2              495.8              745.5
# 9083             1094.2              520.2              745.5
# 9084             1193.4              520.2              745.5
# 9085             1206.8              520.2              745.5
#
#       X_FirstIonization  A_number of Valence Electrons  \
# 0               10086.0                              2
# 1               10086.0                              2
# 2               10086.0                              2
# 3               10086.0                              2
# 4               10086.0                              2
# ...                 ...                            ...
# 9081            10086.0                              6
# 9082            10086.0                              6
# 9083            10086.0                              6
# 9084            10086.0                              6
# 9085            10086.0                              6
#
#       B_number of Valence Electrons  C_number of Valence Electrons  \
# 0                                 1                              3
# 1                                 1                              5
# 2                                11                              3
# 3                                11                              5
# 4                                11                              6
# ...                             ...                            ...
# 9081                              1                             11
# 9082                              1                             11
# 9083                              1                             11
# 9084                              1                             11
# 9085                              1                             11
#
#       X_number of Valence Electrons  A_number  B_number  C_number  X_number  \
# 0                                42         6        11         5        54
# 1                                42         6        11         7        54
# 2                                42         6        29        13        54
# 3                                42         6        29        15        54
# 4                                42         6        29        24        54
# ...                             ...       ...       ...       ...       ...
# 9081                             42       120         3        29        54
# 9082                             42       120        11        29        54
# 9083                             42       126         3        29        54
# 9084                             42       138         3        29        54
# 9085                             42       140         3        29        54
#
#       ...  A-B_covalent Radius  A-C_covalent Radius  \
# 0     ...                  111                  181
# 1     ...                  111                  195
# 2     ...                  154                  140
# 3     ...                  154                  155
# 4     ...                  154                  144
# ...   ...                  ...                  ...
# 9081  ...                  215                  236
# 9082  ...                  193                  236
# 9083  ...                  203                  224
# 9084  ...                  195                  216
# 9085  ...                  207                  228
#
#       (A+B+C)-X_covalent Radius  A-B_atomic Radius  A-C_atomic Radius  \
# 0                           122               1.10               2.05
# 1                           108               1.10               2.25
# 2                           120               1.55               1.65
# 3                           105               1.55               1.90
# 4                           116               1.55               1.50
# ...                         ...                ...                ...
# 9081                        209               2.25               2.35
# 9082                        231               1.90               2.35
# 9083                        197               2.25               2.35
# 9084                        189               2.05               2.15
# 9085                        201               2.05               2.15
#
#       (A+B+C)-X_atomic Radius  A-B_FirstIonization  A-C_FirstIonization  \
# 0                        2.55                544.6                239.8
# 1                        2.35                544.6                361.9
# 2                        2.50                294.9                462.9
# 3                        2.25                294.9                 28.6
# 4                        2.65                294.9                387.5
# ...                       ...                  ...                  ...
# 9081                     3.50                546.0                320.7
# 9082                     3.85                570.4                320.7
# 9083                     3.50                574.0                348.7
# 9084                     3.30                673.2                447.9
# 9085                     3.30                686.6                461.3
#
#       (A+B+C)-X_FirstIonization  A-B_number of Valence Electrons  \
# 0                        7749.2                                1
# 1                        7147.5                                1
# 2                        7722.6                                9
# 3                        7288.3                                9
# 4                        7647.2                                9
# ...                         ...                              ...
# 9081                     7754.1                                5
# 9082                     7778.5                                5
# 9083                     7726.1                                5
# 9084                     7626.9                                5
# 9085                     7613.5                                5
#
#       A-C_number of Valence Electrons  (A+B+C)-X_number of Valence Electrons  \
# 0                                   1                                     36
# 1                                   3                                     34
# 2                                   1                                     26
# 3                                   3                                     24
# 4                                   4                                     23
# ...                               ...                                    ...
# 9081                                5                                     24
# 9082                                5                                     24
# 9083                                5                                     24
# 9084                                5                                     24
# 9085                                5                                     24
#
#       A-B_number  A-C_number  (A+B+C)-X_number  A-B_Period  A-C_Period  \
# 0              5           1                32           1           2
# 1              5           1                30           1           2
# 2             23           7                 6           0           1
# 3             23           9                 4           0           1
# 4             23          18                 5           0           0
# ...          ...         ...               ...         ...         ...
# 9081         117          91                98          10           8
# 9082         109          91               106           9           8
# 9083         123          97               104          10           8
# 9084         135         109               116          10           8
# 9085         137         111               118          10           8
#
#       (A+B+C)-X_Period  A-B_Electronegativity  A-C_Electronegativity  \
# 0                    3                   1.03                   0.08
# 1                    3                   1.03                   1.08
# 2                    1                   0.06                   0.35
# 3                    1                   0.06                   0.23
# 4                    0                   0.06                   0.30
# ...                ...                    ...                    ...
# 9081                 6                   1.30                   0.38
# 9082                 7                   1.35                   0.38
# 9083                 6                   1.42                   0.50
# 9084                 6                   1.52                   0.60
# 9085                 6                   1.22                   0.30
#
#       (A+B+C)-X_Electronegativity  A-B_number of s+p Electrons  \
# 0                           18.95                            1
# 1                           17.95                            1
# 2                           18.41                            1
# 3                           17.83                            1
# 4                           18.36                            1
# ...                           ...                          ...
# 9081                        18.72                            3
# 9082                        18.77                            3
# 9083                        18.60                            3
# 9084                        18.50                            3
# 9085                        18.80                            3
#
#       A-C_number of s+p Electrons  (A+B+C)-X_number of s+p Electrons  \
# 0                               1                                 36
# 1                               3                                 34
# 2                               1                                 36
# 3                               3                                 34
# 4                               1                                 38
# ...                           ...                                ...
# 9081                            3                                 36
# 9082                            3                                 36
# 9083                            3                                 36
# 9084                            3                                 36
# 9085                            3                                 36
#
#       A-B_number of d Electrons  A-C_number of d Electrons  \
# 0                             0                          0
# 1                             0                          0
# 2                            10                          0
# 3                            10                          0
# 4                            10                          5
# ...                         ...                        ...
# 9081                          0                         10
# 9082                          0                         10
# 9083                          0                         10
# 9084                          0                         10
# 9085                          0                         10
#
#       (A+B+C)-X_number of d Electrons  A-B_Mulliken EN  A-C_Mulliken EN  \
# 0                                   0             3.17             1.73
# 1                                   0             3.17             1.28
# 2                                  10             1.54             2.79
# 3                                  10             1.54             0.40
# 4                                  15             1.54             2.30
# ...                               ...              ...              ...
# 9081                               10             3.19             1.72
# 9082                               10             3.35             1.72
# 9083                               10             3.19             1.72
# 9084                               10             3.19             1.72
# 9085                               10             3.19             1.72
#
#       (A+B+C)-X_Mulliken EN
# 0                     49.30
# 1                     46.29
# 2                     48.73
# 3                     46.34
# 4                     48.24
# ...                     ...
# 9081                  48.77
# 9082                  48.93
# 9083                  48.77
# 9084                  48.77
# 9085                  48.77
#
# [9086 rows x 86 columns]

# %%
screen2 = pd.read_csv('./data/screen_slme.csv')
screen2
# Out:
#          formula  number
# 0      Li2CuAlF6       1
# 1       Li2CuPF6       1
# 2      Li2CuCrF6       1
# 3      Li2CuGaF6       1
# 4      Li2CuAsF6       1
# ...          ...     ...
# 2455  Tl2CaYbBr6       2
# 2456   Hg2LiCuF6       3
# 2457   Pb2LiNaF6       3
# 2458   Tm2LiCuF6       3
# 2459   Yb2LiCuF6       3
#
# [2460 rows x 2 columns]

# %%
screen2 = pd.merge(screen2, data, on=['formula', 'number'], how='left')
screen2
# Out:
#          formula  number  A_Density  B_Density  C_Density  X_Density  \
# 0      Li2CuAlF6       1      1.068      8.960      2.700     0.0102
# 1       Li2CuPF6       1      1.068      8.960      1.820     0.0102
# 2      Li2CuCrF6       1      1.068      8.960      7.150     0.0102
# 3      Li2CuGaF6       1      1.068      8.960      5.910     0.0102
# 4      Li2CuAsF6       1      1.068      8.960      5.780     0.0102
# ...          ...     ...        ...        ...        ...        ...
# 2455  Tl2CaYbBr6       2     23.800      1.540      6.970    18.7200
# 2456   Hg2LiCuF6       3     27.000      0.534      8.960     0.0102
# 2457   Pb2LiNaF6       3     22.600      0.534      0.971     0.0102
# 2458   Tm2LiCuF6       3     18.640      0.534      8.960     0.0102
# 2459   Yb2LiCuF6       3     13.940      0.534      8.960     0.0102
#
#       A_dipole Polarizability  B_dipole Polarizability  \
# 0                     328.225                  46.5000
# 1                     328.225                  46.5000
# 2                     328.225                  46.5000
# 3                     328.225                  46.5000
# 4                     328.225                  46.5000
# ...                       ...                      ...
# 2455                  100.000                 160.8000
# 2456                   67.820                 164.1125
# 2457                   94.000                 164.1125
# 2458                  288.000                 164.1125
# 2459                  278.000                 164.1125
#
#       C_dipole Polarizability  X_dipole Polarizability  A_covalent Radius  \
# 0                        57.8                    22.44                266
# 1                        25.0                    22.44                266
# 2                        83.0                    22.44                266
# 3                        50.0                    22.44                266
# 4                        30.0                    22.44                266
# ...                       ...                      ...                ...
# 2455                    139.0                   126.00                288
# 2456                     46.5                    22.44                266
# 2457                    162.7                    22.44                288
# 2458                     46.5                    22.44                328
# 2459                     46.5                    22.44                340
#
#       B_covalent Radius  C_covalent Radius  X_covalent Radius  \
# 0                   112                126                384
# 1                   112                111                384
# 2                   112                122                384
# 3                   112                124                384
# 4                   112                121                384
# ...                 ...                ...                ...
# 2455                171                170                684
# 2456                133                112                384
# 2457                133                155                384
# 2458                133                112                384
# 2459                133                112                384
#
#       A_atomic Radius  B_atomic Radius  C_atomic Radius  X_atomic Radius  \
# 0                 2.9             1.35             1.25              3.0
# 1                 2.9             1.35             1.00              3.0
# 2                 2.9             1.35             1.40              3.0
# 3                 2.9             1.35             1.30              3.0
# 4                 2.9             1.35             1.15              3.0
# ...               ...              ...              ...              ...
# 2455              3.8             1.80             1.75              6.9
# 2456              3.0             1.45             1.35              3.0
# 2457              3.6             1.45             1.80              3.0
# 2458              3.5             1.45             1.35              3.0
# 2459              3.5             1.45             1.35              3.0
#
#       A_FirstIonization  B_FirstIonization  C_FirstIonization  \
# 0                1040.4              745.5              577.5
# 1                1040.4              745.5             1011.8
# 2                1040.4              745.5              652.9
# 3                1040.4              745.5              578.8
# 4                1040.4              745.5              947.0
# ...                 ...                ...                ...
# 2455             1178.8              589.8              603.4
# 2456             2014.2              520.2              745.5
# 2457             1431.2              520.2              495.8
# 2458             1193.4              520.2              745.5
# 2459             1206.8              520.2              745.5
#
#       X_FirstIonization  A_number of Valence Electrons  \
# 0               10086.0                              2
# 1               10086.0                              2
# 2               10086.0                              2
# 3               10086.0                              2
# 4               10086.0                              2
# ...                 ...                            ...
# 2455             6839.4                              6
# 2456            10086.0                             24
# 2457            10086.0                              8
# 2458            10086.0                              6
# 2459            10086.0                              6
#
#       B_number of Valence Electrons  C_number of Valence Electrons  \
# 0                                11                              3
# 1                                11                              5
# 2                                11                              6
# 3                                11                              3
# 4                                11                              5
# ...                             ...                            ...
# 2455                              2                              3
# 2456                              1                             11
# 2457                              1                              1
# 2458                              1                             11
# 2459                              1                             11
#
#       X_number of Valence Electrons  A_number  B_number  C_number  X_number  \
# 0                                42         6        29        13        54
# 1                                42         6        29        15        54
# 2                                42         6        29        24        54
# 3                                42         6        29        31        54
# 4                                42         6        29        33        54
# ...                             ...       ...       ...       ...       ...
# 2455                             42       162        20        70       210
# 2456                             42       160         3        29        54
# 2457                             42       164         3        11        54
# 2458                             42       138         3        29        54
# 2459                             42       140         3        29        54
#
#       ...  A-B_covalent Radius  A-C_covalent Radius  \
# 0     ...                  154                  140
# 1     ...                  154                  155
# 2     ...                  154                  144
# 3     ...                  154                  142
# 4     ...                  154                  145
# ...   ...                  ...                  ...
# 2455  ...                  117                  118
# 2456  ...                  133                  154
# 2457  ...                  155                  133
# 2458  ...                  195                  216
# 2459  ...                  207                  228
#
#       (A+B+C)-X_covalent Radius  A-B_atomic Radius  A-C_atomic Radius  \
# 0                           120               1.55               1.65
# 1                           105               1.55               1.90
# 2                           116               1.55               1.50
# 3                           118               1.55               1.60
# 4                           115               1.55               1.75
# ...                         ...                ...                ...
# 2455                         55               2.00               2.05
# 2456                        127               1.55               1.65
# 2457                        192               2.15               1.80
# 2458                        189               2.05               2.15
# 2459                        201               2.05               2.15
#
#       (A+B+C)-X_atomic Radius  A-B_FirstIonization  A-C_FirstIonization  \
# 0                        2.50                294.9                462.9
# 1                        2.25                294.9                 28.6
# 2                        2.65                294.9                387.5
# 3                        2.55                294.9                461.6
# 4                        2.40                294.9                 93.4
# ...                       ...                  ...                  ...
# 2455                     0.45                589.0                575.4
# 2456                     2.80               1494.0               1268.7
# 2457                     3.85                911.0                935.4
# 2458                     3.30                673.2                447.9
# 2459                     3.30                686.6                461.3
#
#       (A+B+C)-X_FirstIonization  A-B_number of Valence Electrons  \
# 0                        7722.6                                9
# 1                        7288.3                                9
# 2                        7647.2                                9
# 3                        7721.3                                9
# 4                        7353.1                                9
# ...                         ...                              ...
# 2455                     4467.4                                4
# 2456                     6806.1                               23
# 2457                     7638.8                                7
# 2458                     7626.9                                5
# 2459                     7613.5                                5
#
#       A-C_number of Valence Electrons  (A+B+C)-X_number of Valence Electrons  \
# 0                                   1                                     26
# 1                                   3                                     24
# 2                                   4                                     23
# 3                                   1                                     26
# 4                                   3                                     24
# ...                               ...                                    ...
# 2455                                3                                     31
# 2456                               13                                      6
# 2457                                7                                     32
# 2458                                5                                     24
# 2459                                5                                     24
#
#       A-B_number  A-C_number  (A+B+C)-X_number  A-B_Period  A-C_Period  \
# 0             23           7                 6           0           1
# 1             23           9                 4           0           1
# 2             23          18                 5           0           0
# 3             23          25                12           0           0
# 4             23          27                14           0           0
# ...          ...         ...               ...         ...         ...
# 2455         142          92                42           8           6
# 2456         157         131               138          10           8
# 2457         161         153               124          10           9
# 2458         135         109               116          10           8
# 2459         137         111               118          10           8
#
#       (A+B+C)-X_Period  A-B_Electronegativity  A-C_Electronegativity  \
# 0                    1                   0.06                   0.35
# 1                    1                   0.06                   0.23
# 2                    0                   0.06                   0.30
# 3                    0                   0.06                   0.15
# 4                    0                   0.06                   0.22
# ...                ...                    ...                    ...
# 2455                 2                   3.08                   2.98
# 2456                 6                   3.02                   2.10
# 2457                 5                   3.68                   3.73
# 2458                 6                   1.52                   0.60
# 2459                 6                   1.22                   0.30
#
#       (A+B+C)-X_Electronegativity  A-B_number of s+p Electrons  \
# 0                           18.41                            1
# 1                           17.83                            1
# 2                           18.36                            1
# 3                           18.21                            1
# 4                           17.84                            1
# ...                           ...                          ...
# 2455                        11.58                            4
# 2456                        17.00                            3
# 2457                        17.31                            7
# 2458                        18.50                            3
# 2459                        18.80                            3
#
#       A-C_number of s+p Electrons  (A+B+C)-X_number of s+p Electrons  \
# 0                               1                                 36
# 1                               3                                 34
# 2                               1                                 38
# 3                               1                                 36
# 4                               3                                 34
# ...                           ...                                ...
# 2455                            4                                 32
# 2456                            3                                 36
# 2457                            7                                 32
# 2458                            3                                 36
# 2459                            3                                 36
#
#       A-B_number of d Electrons  A-C_number of d Electrons  \
# 0                            10                          0
# 1                            10                          0
# 2                            10                          5
# 3                            10                          0
# 4                            10                          0
# ...                         ...                        ...
# 2455                         20                         20
# 2456                         20                         10
# 2457                         20                         20
# 2458                          0                         10
# 2459                          0                         10
#
#       (A+B+C)-X_number of d Electrons  A-B_Mulliken EN  A-C_Mulliken EN  \
# 0                                  10             1.54             2.79
# 1                                  10             1.54             0.40
# 2                                  15             1.54             2.30
# 3                                  10             1.54             2.82
# 4                                  10             1.54             0.72
# ...                               ...              ...              ...
# 2455                               20             4.20             3.30
# 2456                               30             6.81             5.34
# 2457                               20             4.79             4.95
# 2458                               10             3.19             1.72
# 2459                               10             3.19             1.72
#
#       (A+B+C)-X_Mulliken EN
# 0                     48.73
# 1                     46.34
# 2                     48.24
# 3                     48.76
# 4                     46.66
# ...                     ...
# 2455                  33.84
# 2456                  45.15
# 2457                  48.80
# 2458                  48.77
# 2459                  48.77
#
# [2460 rows x 86 columns]

# %%
X1 =  pd.DataFrame()
X1 = screen2[feature_xgb]
X1
# Out:
#       B_Density  C_dipole Polarizability  A_number of Valence Electrons  \
# 0         8.960                     57.8                              2
# 1         8.960                     25.0                              2
# 2         8.960                     83.0                              2
# 3         8.960                     50.0                              2
# 4         8.960                     30.0                              2
# ...         ...                      ...                            ...
# 2455      1.540                    139.0                              6
# 2456      0.534                     46.5                             24
# 2457      0.534                    162.7                              8
# 2458      0.534                     46.5                              6
# 2459      0.534                     46.5                              6
#
#       C_Period  A_Electronegativity  A_number of s+p Electrons  \
# 0            3                 1.96                          2
# 1            3                 1.96                          2
# 2            4                 1.96                          2
# 3            4                 1.96                          2
# 4            4                 1.96                          2
# ...        ...                  ...                        ...
# 2455         6                 4.08                          6
# 2456         4                 4.00                          4
# 2457         3                 4.66                          8
# 2458         4                 2.50                          4
# 2459         4                 2.20                          4
#
#       B_number of s+p Electrons  X_number of s+p Electrons  C_Mulliken EN  \
# 0                             1                         42           3.23
# 1                             1                         42           5.62
# 2                             1                         42           3.72
# 3                             1                         42           3.20
# 4                             1                         42           5.30
# ...                         ...                        ...            ...
# 2455                          2                         42           3.10
# 2456                          1                         42           4.48
# 2457                          1                         42           2.85
# 2458                          1                         42           4.48
# 2459                          1                         42           4.48
#
#       X_Mulliken EN  (A+B+C)-X_number of Valence Electrons  \
# 0             62.46                                     26
# 1             62.46                                     24
# 2             62.46                                     23
# 3             62.46                                     26
# 4             62.46                                     24
# ...             ...                                    ...
# 2455          45.54                                     31
# 2456          62.46                                      6
# 2457          62.46                                     32
# 2458          62.46                                     24
# 2459          62.46                                     24
#
#       A-B_Electronegativity  A-B_number of s+p Electrons  \
# 0                      0.06                            1
# 1                      0.06                            1
# 2                      0.06                            1
# 3                      0.06                            1
# 4                      0.06                            1
# ...                     ...                          ...
# 2455                   3.08                            4
# 2456                   3.02                            3
# 2457                   3.68                            7
# 2458                   1.52                            3
# 2459                   1.22                            3
#
#       A-C_number of d Electrons  (A+B+C)-X_number of d Electrons
# 0                             0                               10
# 1                             0                               10
# 2                             5                               15
# 3                             0                               10
# 4                             0                               10
# ...                         ...                              ...
# 2455                         20                               20
# 2456                         10                               30
# 2457                         20                               20
# 2458                         10                               10
# 2459                         10                               10
#
# [2460 rows x 15 columns]

# %%
from joblib import load

best_model = load('./model/bgclass_xgb_cn.joblib')

# %%
# %%time
screen = pd.DataFrame(columns=['formula','number'])
screen['formula'] = screen2['formula']
screen['number'] = screen2['number']

y_pred_ensemble = np.array([model.predict(X1) for model in best_model]).T
screen['is_gap_direct']  = np.apply_along_axis(lambda x: np.argmax(np.bincount(x)), axis=1, arr=y_pred_ensemble)   
screen
# Out:
# CPU times: user 5.71 s, sys: 0 ns, total: 5.71 s
# Wall time: 78.9 ms
#          formula  number  is_gap_direct
# 0      Li2CuAlF6       1              0
# 1       Li2CuPF6       1              0
# 2      Li2CuCrF6       1              0
# 3      Li2CuGaF6       1              0
# 4      Li2CuAsF6       1              0
# ...          ...     ...            ...
# 2455  Tl2CaYbBr6       2              1
# 2456   Hg2LiCuF6       3              0
# 2457   Pb2LiNaF6       3              0
# 2458   Tm2LiCuF6       3              0
# 2459   Yb2LiCuF6       3              0
#
# [2460 rows x 3 columns]

# %%
screen['is_gap_direct'].value_counts()
# Out:
# is_gap_direct
# 0    1597
# 1     863
# Name: count, dtype: int64

# %%
screen_3 = screen[screen['is_gap_direct']==1]
screen_3
# Out:
#          formula  number  is_gap_direct
# 8      Na2LiAuF6       1              1
# 9      Na2LiYbF6       1              1
# 24     K2LiInCl6       1              1
# 26      K2LiAuF6       1              1
# 27      K2LiYbF6       1              1
# ...          ...     ...            ...
# 2441  Tl2CaCrBr6       2              1
# 2447  Tl2CaGeBr6       2              1
# 2448  Tl2CaNbBr6       2              1
# 2454  Tl2CaTmBr6       2              1
# 2455  Tl2CaYbBr6       2              1
#
# [863 rows x 3 columns]

# %%
screen_3 = screen_3.drop(columns=['is_gap_direct'])
screen_3
# Out:
#          formula  number
# 8      Na2LiAuF6       1
# 9      Na2LiYbF6       1
# 24     K2LiInCl6       1
# 26      K2LiAuF6       1
# 27      K2LiYbF6       1
# ...          ...     ...
# 2441  Tl2CaCrBr6       2
# 2447  Tl2CaGeBr6       2
# 2448  Tl2CaNbBr6       2
# 2454  Tl2CaTmBr6       2
# 2455  Tl2CaYbBr6       2
#
# [863 rows x 2 columns]

# %%
screen_3.to_csv('./data/screen_bandgaptype.csv',index=False)
